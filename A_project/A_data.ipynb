# %%
# !pip install dart-fss
# Out:
# Collecting dart-fss
#   Downloading dart_fss-0.3.16-py3-none-any.whl (125 kB)
# Requirement already satisfied: appdirs in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (1.4.4)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Requirement already satisfied: tqdm in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (4.62.3)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: xmltodict in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (0.12.0)
# Requirement already satisfied: urllib3 in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (1.26.7)
# Requirement already satisfied: python-dateutil in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (2.8.2)
# Collecting halo
#   Downloading halo-0.0.31.tar.gz (11 kB)
# Requirement already satisfied: pytz in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (2021.3)
# Requirement already satisfied: openpyxl in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (3.0.9)
# Requirement already satisfied: pickleshare in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (0.7.5)
# Requirement already satisfied: traitlets in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (5.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (4.10.0)
# Requirement already satisfied: ipython-genutils in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (0.2.0)
# Requirement already satisfied: html5lib in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (1.1)
# Collecting arelle
#   Downloading arelle-2.2.tar.gz (1.9 MB)
# Requirement already satisfied: py in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (1.10.0)
# Collecting pandas<1.3.0,>=1.1.5
#   Downloading pandas-1.2.5-cp39-cp39-win_amd64.whl (9.3 MB)
# Requirement already satisfied: chardet in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (4.0.0)
# Requirement already satisfied: attrs in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (21.2.0)
# Requirement already satisfied: backcall in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (0.2.5)
# Requirement already satisfied: decorator in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (5.1.0)
# Requirement already satisfied: six in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (1.16.0)
# Requirement already satisfied: requests in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (2.26.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (1.22.1)
# Requirement already satisfied: soupsieve in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (2.2.1)
# Requirement already satisfied: lxml in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (4.6.3)
# Requirement already satisfied: certifi in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (2021.10.8)
# Requirement already satisfied: idna>=3.0 in c:\users\bitcamp\anaconda3\lib\site-packages (from dart-fss) (3.2)
# Collecting log_symbols>=0.0.14
#   Downloading log_symbols-0.0.14-py3-none-any.whl (3.1 kB)
# Collecting spinners>=0.0.24
#   Downloading spinners-0.0.24-py3-none-any.whl (5.5 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\bitcamp\anaconda3\lib\site-packages (from halo->dart-fss) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\bitcamp\anaconda3\lib\site-packages (from html5lib->dart-fss) (0.5.1)
# Requirement already satisfied: et-xmlfile in c:\users\bitcamp\anaconda3\lib\site-packages (from openpyxl->dart-fss) (1.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bitcamp\anaconda3\lib\site-packages (from requests->dart-fss) (2.0.4)
# Building wheels for collected packages: arelle, fake-useragent, halo, termcolor
#   Building wheel for arelle (setup.py): started
#   Building wheel for arelle (setup.py): finished with status 'done'
#   Created wheel for arelle: filename=arelle-2.2-py3-none-any.whl size=2060307 sha256=9597ba8caa9f9beb6b47245fccea23aa3cd4fdfd9ef1e44c976a763fad0933dd
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\ae\ea\80\69a7c9134cb71ed0d6d427cbba1918e8a20be166b616558bd1
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=9b7b863296e39adca66ea39891d3b2fece0dcb5e6eda2b9cd2326645f40229f2
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\ae\e7\76\7dd44644d065268ab0e1b4fa2e802fa4bb0157717b7d6c6d92
#   Building wheel for halo (setup.py): started
#   Building wheel for halo (setup.py): finished with status 'done'
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11260 sha256=f446ec96276d97281051cdf290bfcb023c5a11193c37c65a5250d7f97929c7b6
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\bb\85\47\b7c7338ab52808105f937bd8c04aec5d98a543311ac2c8bed2
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=57ce5984122d0ef39f37506084851bfcad37a57ba43e77613e5e65dde59d7097
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built arelle fake-useragent halo termcolor
# Installing collected packages: termcolor, spinners, log-symbols, pandas, isodate, halo, fake-useragent, arelle, dart-fss
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
# Successfully installed arelle-2.2 dart-fss-0.3.16 fake-useragent-0.1.11 halo-0.0.31 isodate-0.6.1 log-symbols-0.0.14 pandas-1.2.5 spinners-0.0.24 termcolor-1.1.0

# %%
import dart_fss as dart

# Open DART API KEY 설정
api_key='219faaef4df1cb36473c496e20e9e28a8baf8d7f'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자 검색
samsung = corp_list.find_by_corp_name('삼성전자', exactly=True)[0]

# 2012년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20100101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
fs.save('./data/samsung.xml')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31032/121178972.py in <module>
# ----> 1 import dart_fss as dart
#       2
#       3 # Open DART API KEY 설정
#       4 api_key='219faaef4df1cb36473c496e20e9e28a8baf8d7f'
#       5 dart.set_api_key(api_key=api_key)
#
# ModuleNotFoundError: No module named 'dart_fss'

# %%
import dart_fss as dart

# 삼성전자 code
corp_code = '00126380'

# 모든 상장된 기업 리스트 불러오기
crp_list = get_corp_list()

# 삼성전자
samsung = corp_list.find_by_corp_name(corp_code=corp_code)

# 2012년 01월 01일 부터 연결재무제표 검색
# fs = samsung.extract_fs(bgn_de='20120101') 와 동일
fs = dart.fs.extract(corp_code=corp_code, bgn_de='20120101')

# 연결재무상태표
df_fs = fs['bs'] # 또는 df = fs[0] 또는 df = fs.show('bs')
# 연결재무상태표 추출에 사용된 Label 정보
labels_fs = fs.labels['bs']

# 연결손익계산서
df_is = fs['is'] # 또는 df = fs[1] 또는 df = fs.show('is')
# 연결손익계산서 추출에 사용된 Label 정보
labels_is = fs.labels['is']

# 연결포괄손익계산서
df_ci = fs['cis'] # 또는 df = fs[2] 또는 df = fs.show('cis')
# 연결포괄손익계산서 추출에 사용된 Label 정보
labels_ci = fs.labels['cis']

# 현금흐름표
df_cf = fs['cf'] # 또는 df = fs[3] 또는 df = fs.show('cf')
# 현금흐름표 추출에 사용된 Label 정보
labels_cf = fs.labels['cf']

# 재무제표 일괄저장 (default: 실행폴더/fsdata/{corp_code}_{report_tp}.xlsx)
fs.save()

# 재무제표 일괄저장
filename = '삼성전자'
path = '/User/xxxxx/Desktop/'
fs.save(filename=filename, path=path)

# %%
import dart_fss as dart
import pandas as pd

# %%
df = pd.read_csv('./data/data_3322_20220211.csv', encoding='euckr')
inds = df[df['한글 종목명'].str.contains('우선주')].index
dfn = df.drop(inds)
names = dfn['한글 종목약명']

# %%
for name in names[1660:]:
    try:
        company = corp_list.find_by_corp_name(name, exactly=True)[0]
        fs = company.extract_fs(bgn_de='20100101')
        filename = f'{name}.xlsx'
        path = ''
        fs.save(filename=filename)
    except:
        pass
# Out:
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110331002126', 'corp_code': '00242378', 'corp_name': '이지홀딩스', 'stock_code': '035810', 'corp_cls': 'K', 'report_nm': '[첨부추가]사업보고서 (2010.12)', 'flr_nm': '이지홀딩스', 'rcept_dt': '20110331', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100331001000', 'corp_code': '00242378', 'corp_name': '이지홀딩스', 'stock_code': '035810', 'corp_cls': 'K', 'report_nm': '[첨부추가]사업보고서 (2009.12)', 'flr_nm': '이지홀딩스', 'rcept_dt': '20100331', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/8 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1236, in analyze_report
#     xbrl = report.xbrl
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 377, in xbrl
#     self.load_xbrl()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 389, in load_xbrl
#     xbrl_attached = self._get_xbrl()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 406, in _get_xbrl
#     attached_files = self.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 360, in attached_files
#     def attached_files(): return [x for x in self.attached_files if determinant(x.filename)]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 214, in attached_files
#     self.extract_attached_files()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 227, in extract_attached_files
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20200918000484', 'corp_code': '00818472', 'corp_name': '이큐셀', 'stock_code': '160600', 'corp_cls': 'K', 'report_nm': '사업보고서제출기한연장신고서 (2020.06)', 'flr_nm': '이큐셀', 'rcept_dt': '20200918', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20111229000112', 'corp_code': '00634728', 'corp_name': '이크레더블', 'stock_code': '092130', 'corp_cls': 'K', 'report_nm': '사업보고서 (2011.09)', 'flr_nm': '이크레더블', 'rcept_dt': '20111229', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20101229000022', 'corp_code': '00634728', 'corp_name': '이크레더블', 'stock_code': '092130', 'corp_cls': 'K', 'report_nm': '사업보고서 (2010.09)', 'flr_nm': '이크레더블', 'rcept_dt': '20101229', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20190401003676', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '사업보고서 (2018.12)', 'flr_nm': '이트론', 'rcept_dt': '20190401', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20180330002598', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '사업보고서 (2017.12)', 'flr_nm': '이트론', 'rcept_dt': '20180330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20170331003778', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '사업보고서 (2016.12)', 'flr_nm': '이트론', 'rcept_dt': '20170331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20160516001153', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '[기재정정]사업보고서 (2015.12)', 'flr_nm': '이트론', 'rcept_dt': '20160516', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20150520000160', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '[기재정정]사업보고서 (2014.12)', 'flr_nm': '이트론', 'rcept_dt': '20150520', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110331000945', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '사업보고서 (2010.12)', 'flr_nm': '이트론', 'rcept_dt': '20110331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100331000731', 'corp_code': '00480756', 'corp_name': '이트론', 'stock_code': '096040', 'corp_cls': 'K', 'report_nm': '사업보고서 (2009.12)', 'flr_nm': '이트론', 'rcept_dt': '20100331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/10 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20210322000752', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '[기재정정]사업보고서 (2020.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20210322', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20200330001621', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '사업보고서 (2019.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20200330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20190329000967', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '사업보고서 (2018.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20190329', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20180330000965', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '사업보고서 (2017.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20180330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20170330000640', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '사업보고서 (2016.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20170330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20160330000702', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '사업보고서 (2015.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20160330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20150331000514', 'corp_code': '00788737', 'corp_name': '이퓨쳐', 'stock_code': '134060', 'corp_cls': 'K', 'report_nm': '사업보고서 (2014.12)', 'flr_nm': '이퓨쳐', 'rcept_dt': '20150331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
# ...
#     def attached_files(): return [x for x in self.attached_files if determinant(x.filename)]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 214, in attached_files
#     self.extract_attached_files()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 227, in extract_attached_files
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130703000225', 'corp_code': '00548519', 'corp_name': '에스엔피제네틱스', 'stock_code': '086460', 'corp_cls': 'N', 'report_nm': '사업보고서 (2012.12)', 'flr_nm': '에스엔피제네틱스', 'rcept_dt': '20130703', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/6 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20210323000653', 'corp_code': '01082348', 'corp_name': '오스테오닉', 'stock_code': '226400', 'corp_cls': 'K', 'report_nm': '사업보고서 (2020.12)', 'flr_nm': '오스테오닉', 'rcept_dt': '20210323', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20200330004233', 'corp_code': '01082348', 'corp_name': '오스테오닉', 'stock_code': '226400', 'corp_cls': 'K', 'report_nm': '사업보고서 (2019.12)', 'flr_nm': '오스테오닉', 'rcept_dt': '20200330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20190329003496', 'corp_code': '01082348', 'corp_name': '오스테오닉', 'stock_code': '226400', 'corp_cls': 'K', 'report_nm': '사업보고서 (2018.12)', 'flr_nm': '오스테오닉', 'rcept_dt': '20190329', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20180330001576', 'corp_code': '01082348', 'corp_name': '오스테오닉', 'stock_code': '226400', 'corp_cls': 'K', 'report_nm': '사업보고서 (2017.12)', 'flr_nm': '오스테오닉', 'rcept_dt': '20180330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1236, in analyze_report
#     xbrl = report.xbrl
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 377, in xbrl
#     self.load_xbrl()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 389, in load_xbrl
#     xbrl_attached = self._get_xbrl()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 406, in _get_xbrl
#     attached_files = self.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 360, in attached_files
#     def attached_files(): return [x for x in self.attached_files if determinant(x.filename)]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 214, in attached_files
#     self.extract_attached_files()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 227, in extract_attached_files
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20170331001635', 'corp_code': '01082348', 'corp_name': '오스테오닉', 'stock_code': '226400', 'corp_cls': 'K', 'report_nm': '사업보고서 (2016.12)', 'flr_nm': '오스테오닉', 'rcept_dt': '20170331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\Anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1236, in analyze_report
#     xbrl = report.xbrl
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 377, in xbrl
#     self.load_xbrl()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 389, in load_xbrl
#     xbrl_attached = self._get_xbrl()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 406, in _get_xbrl
#     attached_files = self.find_all(**query)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 360, in attached_files
#     def attached_files(): return [x for x in self.attached_files if determinant(x.filename)]
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 214, in attached_files
#     self.extract_attached_files()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 227, in extract_attached_files
#     self._get_report()
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\Anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\Anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20160331000018', 'corp_code': '01082348', 'corp_name': '오스테오닉', 'stock_code': '226400', 'corp_cls': 'K', 'report_nm': '사업보고서 (2015.12)', 'flr_nm': '오스테오닉', 'rcept_dt': '20160331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/6 [00:00<?, ?report/s]

# %%
import pandas as pd

df = pd.read_csv('data_3322_20220211.csv', encoding='euckr')
inds = df[df['한글 종목명'].str.contains('우선주')].index
dfn = df.drop(inds)
names = dfn['한글 종목약명']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31032/1993067970.py in <module>
# ----> 1 import dart_fss as dart
#       2 import pandas as pd
#       3
#       4 df = pd.read_csv('data_3322_20220211.csv', encoding='euckr')
#       5 inds = df[df['한글 종목명'].str.contains('우선주')].index
#
# ModuleNotFoundError: No module named 'dart_fss'

# %%
# !pip install dart-fss
# Out:
# Collecting dart-fss
#   Downloading dart_fss-0.3.16-py3-none-any.whl (125 kB)
# Collecting halo
#   Downloading halo-0.0.31.tar.gz (11 kB)
# Requirement already satisfied: requests in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (4.10.0)
# Requirement already satisfied: pickleshare in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (0.7.5)
# Requirement already satisfied: py in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (1.10.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (1.20.3)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: six in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (1.16.0)
# Requirement already satisfied: lxml in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (4.6.3)
# Requirement already satisfied: urllib3 in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (1.26.7)
# Requirement already satisfied: ipython-genutils in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (0.2.0)
# Requirement already satisfied: soupsieve in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (2.2.1)
# Requirement already satisfied: wcwidth in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (0.2.5)
# Requirement already satisfied: attrs in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (21.2.0)
# Requirement already satisfied: openpyxl in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (3.0.9)
# Requirement already satisfied: chardet in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (4.0.0)
# Requirement already satisfied: backcall in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (0.2.0)
# Requirement already satisfied: appdirs in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (1.4.4)
# Collecting arelle
#   Downloading arelle-2.2.tar.gz (1.9 MB)
# Requirement already satisfied: pytz in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (2021.3)
# Requirement already satisfied: html5lib in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (1.1)
# Requirement already satisfied: traitlets in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (5.1.0)
# Requirement already satisfied: idna>=3.0 in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (3.2)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting pandas<1.3.0,>=1.1.5
#   Downloading pandas-1.2.5-cp39-cp39-win_amd64.whl (9.3 MB)
# Requirement already satisfied: decorator in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (5.1.0)
# Requirement already satisfied: python-dateutil in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (2.8.2)
# Requirement already satisfied: certifi in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (2021.10.8)
# Requirement already satisfied: tqdm in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (4.62.3)
# Requirement already satisfied: xmltodict in c:\users\goejt\anaconda3\lib\site-packages (from dart-fss) (0.12.0)
# Collecting log_symbols>=0.0.14
#   Downloading log_symbols-0.0.14-py3-none-any.whl (3.1 kB)
# Collecting spinners>=0.0.24
#   Downloading spinners-0.0.24-py3-none-any.whl (5.5 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\goejt\anaconda3\lib\site-packages (from halo->dart-fss) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\goejt\anaconda3\lib\site-packages (from html5lib->dart-fss) (0.5.1)
# Requirement already satisfied: et-xmlfile in c:\users\goejt\anaconda3\lib\site-packages (from openpyxl->dart-fss) (1.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\goejt\anaconda3\lib\site-packages (from requests->dart-fss) (2.0.4)
# Building wheels for collected packages: arelle, fake-useragent, halo, termcolor
#   Building wheel for arelle (setup.py): started
#   Building wheel for arelle (setup.py): finished with status 'done'
#   Created wheel for arelle: filename=arelle-2.2-py3-none-any.whl size=2060307 sha256=5c9cb1457f1e0c2aaf37ea374c6a149c0df1233b250aec21c9b4a79d6e010349
#   Stored in directory: c:\users\goejt\appdata\local\pip\cache\wheels\ae\ea\80\69a7c9134cb71ed0d6d427cbba1918e8a20be166b616558bd1
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=e4c826655dffa73f67f4bcaaf3dacd06e264b8b18286179eee134b810153c647
#   Stored in directory: c:\users\goejt\appdata\local\pip\cache\wheels\ae\e7\76\7dd44644d065268ab0e1b4fa2e802fa4bb0157717b7d6c6d92
#   Building wheel for halo (setup.py): started
#   Building wheel for halo (setup.py): finished with status 'done'
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11260 sha256=e071a2901de040e107d1bd5ff720e5b39661cede4a1da95f3c6609d1aa9279e3
#   Stored in directory: c:\users\goejt\appdata\local\pip\cache\wheels\bb\85\47\b7c7338ab52808105f937bd8c04aec5d98a543311ac2c8bed2
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=dc970fa20cc0227c2dcee3f7659e6b218949c650f28eb081a348fdefb5dd9ff7
#   Stored in directory: c:\users\goejt\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built arelle fake-useragent halo termcolor
# Installing collected packages: termcolor, spinners, log-symbols, pandas, isodate, halo, fake-useragent, arelle, dart-fss
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.0
#     Uninstalling pandas-1.4.0:
#       Successfully uninstalled pandas-1.4.0
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\goejt\\anaconda3\\Lib\\site-packages\\~-ndas\\_libs\\algos.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import dart_fss as dart

api_key='219faaef4df1cb36473c496e20e9e28a8baf8d7f'
dart.set_api_key(api_key=api_key)

for name in names:
    try:
        company = corp_list.find_by_corp_name(name, exactly=True)[0]
        fs = company.extract_fs(bgn_de='20100101')
        filename = f'{name}.xlsx'
        path = ''
        fs.save(filename=filename)
    except:
        pass
