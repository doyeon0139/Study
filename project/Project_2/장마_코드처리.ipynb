# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import datetime

# %%
# 우리나라 기후

# %%
df_k = pd.read_csv('./기상청ASOS관측.csv', index_col=0)
df_k.head(50)
# Out:
#     지점 번호 관측지점          시간  평균 기온  최저 기온  최저 기온 시각  최고 기온  최대 기온 시각  \
# 0     105   강릉  1980-01-01    3.0   -0.4       714    7.0    1549.0
# 1     105   강릉  1980-01-02    6.0    3.5       207    8.4    1500.0
# 2     105   강릉  1980-01-03    7.5    4.1      1810   12.8    1330.0
# 3     105   강릉  1980-01-04    4.1   -0.8      2356    6.8    1206.0
# 4     105   강릉  1980-01-05   -0.8   -3.9       746    4.3    1224.0
# 5     105   강릉  1980-01-06    1.0   -4.3      2400    4.8    1322.0
# 6     105   강릉  1980-01-07   -6.3   -9.8       741   -3.3    1449.0
# 7     105   강릉  1980-01-08   -0.2   -5.4         8    4.8    1444.0
# 8     105   강릉  1980-01-09    2.9   -1.1       207    7.2    1213.0
# 9     105   강릉  1980-01-10   -1.6   -7.6      2356    3.0       9.0
# 10    105   강릉  1980-01-11   -3.9   -8.8       318    3.1    1312.0
# 11    105   강릉  1980-01-12   -0.4   -6.1       742    4.8    1458.0
# 12    105   강릉  1980-01-13    0.7   -3.1       821    6.5    1414.0
# 13    105   강릉  1980-01-14   -2.6   -6.8       754    2.1    1303.0
# 14    105   강릉  1980-01-15   -2.2   -6.7       808    2.9    1452.0
# 15    105   강릉  1980-01-16   -2.9   -6.5       640    1.5    1304.0
# 16    105   강릉  1980-01-17   -8.2  -12.5       843   -3.4       0.0
# 17    105   강릉  1980-01-18   -4.8  -11.6       537    3.2    1310.0
# 18    105   강릉  1980-01-19    0.1   -2.4        30    4.0    1357.0
# 19    105   강릉  1980-01-20   -1.4   -4.1      2355    1.2    1350.0
# 20    105   강릉  1980-01-21   -4.2   -7.8       815   -0.2    1410.0
# 21    105   강릉  1980-01-22   -3.9   -9.4       654    3.2    1518.0
# 22    105   강릉  1980-01-23    1.6   -3.7       455    6.5    1447.0
# 23    105   강릉  1980-01-24    0.4   -2.8       736    5.8    1223.0
# 24    105   강릉  1980-01-25    0.5   -3.4       757    6.8    1508.0
# 25    105   강릉  1980-01-26    3.7   -2.2       756   11.9    1508.0
# 26    105   강릉  1980-01-27    9.0    3.6       335   14.8    1528.0
# 27    105   강릉  1980-01-28    5.9    2.3       506    8.5    1509.0
# 28    105   강릉  1980-01-29    2.0    0.1      2325    3.8      10.0
# 29    105   강릉  1980-01-30   -6.1  -11.8      2344    2.7     456.0
# 30    105   강릉  1980-01-31  -10.0  -13.6       740   -5.2    1552.0
# 31    105   강릉  1980-02-01   -7.6  -12.0       818   -3.7    1615.0
# 32    105   강릉  1980-02-02   -4.1   -7.4       744   -1.1    1322.0
# 33    105   강릉  1980-02-03   -3.3   -5.5      2356   -0.7    1202.0
# 34    105   강릉  1980-02-04   -6.2   -8.7       730   -1.3    1205.0
# 35    105   강릉  1980-02-05   -7.8  -11.0       718   -3.9    1203.0
# 36    105   강릉  1980-02-06   -7.5  -10.7       510   -3.1    1420.0
# 37    105   강릉  1980-02-07   -7.0  -11.6       723   -1.2    1456.0
# 38    105   강릉  1980-02-08   -7.2  -10.3       758   -3.6    1505.0
# 39    105   강릉  1980-02-09   -4.7   -9.8       623    1.1    1506.0
# 40    105   강릉  1980-02-10   -1.4   -5.2       646    3.3    1454.0
# 41    105   강릉  1980-02-11    1.0   -3.2       610    5.5    1504.0
# 42    105   강릉  1980-02-12   -0.4   -3.5       738    4.1    1345.0
# 43    105   강릉  1980-02-13   -2.4   -6.0       640    3.1    1505.0
# 44    105   강릉  1980-02-14   -3.1   -6.6       730    1.6    1434.0
# 45    105   강릉  1980-02-15   -1.8   -5.9       654    3.3    1404.0
# 46    105   강릉  1980-02-16   -0.6   -6.3       730    6.3    1209.0
# 47    105   강릉  1980-02-17   -0.1   -4.4       727    5.0    1554.0
# 48    105   강릉  1980-02-18    2.0   -4.0        55    7.5    1350.0
# 49    105   강릉  1980-02-19    3.9   -1.1       718   10.4    1340.0
#
#     10분 최다 강수량  10분 최다강수량 시각  ...  0.5m 지중온도  1.0m 지중온도  1.5m 지중온도  3.0m 지중온도  \
# 0          NaN           NaN  ...        6.1        9.1       11.4       15.0
# 1          NaN           NaN  ...        6.7        9.0       11.1       14.8
# 2          NaN           NaN  ...        6.8        9.0       11.0       14.8
# 3          NaN           NaN  ...        7.0        9.1       11.0       14.7
# 4          NaN           NaN  ...        7.3        9.1       10.8       14.7
# 5          NaN           NaN  ...        6.7        9.0       10.8       14.5
# 6          NaN           NaN  ...        5.3        9.0        9.9       14.5
# 7          NaN           NaN  ...        5.4        8.9       10.0       14.5
# 8          NaN           NaN  ...        5.3        8.7       10.0       14.3
# 9          NaN           NaN  ...        5.1        8.5       10.0       14.4
# 10         NaN           NaN  ...        4.9        8.3       10.3       14.2
# 11         NaN           NaN  ...        4.7        8.1       10.2       14.2
# 12         NaN           NaN  ...        4.6        8.0       10.2       14.2
# 13         NaN           NaN  ...        3.6        7.7        9.6       14.0
# 14         NaN           NaN  ...        3.4        7.5        8.0       13.9
# 15         NaN           NaN  ...        3.3        7.5        8.0       13.9
# 16         NaN           NaN  ...        3.8        7.3        8.3       13.8
# 17         NaN           NaN  ...        3.8        7.2        8.3       13.8
# 18         NaN           NaN  ...        3.9        7.1        8.3       13.7
# 19         NaN           NaN  ...        3.6        6.9        8.3       13.6
# 20         NaN           NaN  ...        3.5        6.8        8.1       13.6
# 21         NaN           NaN  ...        3.5        7.0        8.6       13.4
# 22         NaN           NaN  ...        3.4        6.6        9.0       13.4
# 23         NaN           NaN  ...        3.4        6.5        8.9       13.4
# 24         NaN           NaN  ...        3.6        6.4        8.3       13.3
# 25         NaN           NaN  ...        3.4        6.4        8.5       13.3
# 26         NaN           NaN  ...        3.4        6.2        8.5       13.1
# 27         NaN           NaN  ...        3.7        6.2        8.6       13.2
# 28         NaN           NaN  ...        4.1        6.2        8.4       13.0
# 29         NaN           NaN  ...        4.1        6.2        8.2       13.0
# 30         NaN           NaN  ...        4.0        6.2        7.6       12.8
# 31         NaN           NaN  ...        3.7        6.3        8.4       12.7
# 32         NaN           NaN  ...        3.4        6.1        8.1       12.7
# 33         NaN           NaN  ...        3.4        6.0        8.1       12.7
# 34         NaN           NaN  ...        3.1        5.8        7.8       12.6
# 35         NaN           NaN  ...        3.0        5.8        8.0       12.7
# 36         NaN           NaN  ...        2.6        5.6        7.6       12.5
# 37         NaN           NaN  ...        2.6        5.6        7.4       12.4
# 38         NaN           NaN  ...        2.5        5.5        7.1       12.3
# 39         NaN           NaN  ...        2.4        5.3        7.1       12.3
# 40         NaN           NaN  ...        2.3        5.2        7.2       12.2
# 41         NaN           NaN  ...        2.2        5.1        6.9       12.1
# 42         NaN           NaN  ...        2.2        5.0        6.7       12.0
# 43         NaN           NaN  ...        2.4        5.0        6.8       12.0
# 44         NaN           NaN  ...        2.1        4.8        7.1       12.0
# 45         NaN           NaN  ...        2.0        4.7        6.5       11.8
# 46         NaN           NaN  ...        2.0        4.8        6.8       11.8
# 47         NaN           NaN  ...        2.0        4.7        7.1       11.9
# 48         NaN           NaN  ...        2.1        4.6        6.7       11.8
# 49         NaN           NaN  ...        2.0        4.5        6.4       11.5
#
#     5.0m 지중온도  합계 대형증발량  합계 소형증발량  9-9강수  \
# 0        15.4       NaN       0.9    2.6
# 1        15.5       NaN       1.5    1.4
# 2        15.3       NaN       2.2    NaN
# 3        15.5       NaN       1.8    1.5
# 4        15.4       NaN       2.0    NaN
# 5        15.3       NaN       2.3    1.3
# 6        15.2       NaN       1.2    NaN
# 7        15.2       NaN       5.3    NaN
# 8        15.2       NaN       1.8    NaN
# 9        15.3       NaN       2.5    NaN
# 10       15.3       NaN       3.0    NaN
# 11       15.2       NaN       1.7    NaN
# 12       15.2       NaN       2.8    NaN
# 13       15.2       NaN       2.2    NaN
# 14       15.2       NaN       2.5    0.0
# 15       15.2       NaN       2.5    NaN
# 16       15.1       NaN       2.2    NaN
# 17       15.0       NaN       3.4    NaN
# 18       15.0       NaN       2.7    NaN
# 19       15.0       NaN       2.8    NaN
# 20       15.0       NaN       2.3    NaN
# 21       14.8       NaN       3.0    NaN
# 22       14.8       NaN       2.6    NaN
# 23       14.8       NaN       2.7    NaN
# 24       14.8       NaN       3.1    NaN
# 25       14.6       NaN       2.8    NaN
# 26       14.6       NaN       2.3    NaN
# 27       14.6       NaN       0.3   14.7
# 28       14.5       NaN       0.8   36.6
# 29       14.5       NaN       1.5    NaN
# 30       14.5       NaN       2.0    NaN
# 31       14.4       NaN       2.5    NaN
# 32       14.4       NaN       1.4    NaN
# 33       14.5       NaN       2.3    NaN
# 34       14.5       NaN       2.1    NaN
# 35       14.4       NaN       2.1    NaN
# 36       14.3       NaN       2.5    NaN
# 37       14.3       NaN       2.6    NaN
# 38       14.5       NaN       2.4    NaN
# 39       14.3       NaN       2.8    NaN
# 40       14.2       NaN       2.6    NaN
# 41       14.2       NaN       3.6    NaN
# 42       14.8       NaN       3.3    NaN
# 43       14.8       NaN       3.4    NaN
# 44       14.6       NaN       3.5    NaN
# 45       14.1       NaN       2.9    NaN
# 46       13.9       NaN       3.8    NaN
# 47       14.2       NaN       3.2    NaN
# 48       14.0       NaN       2.1    NaN
# 49       13.8       NaN       3.7    NaN
#
#                                                  일기현상  안개 계속 시간
# 0                               {비}2218-{비}{강도0}2400-       NaN
# 1   -{비}-{비}{강도0}0300-{비}{강도0}0600-{비}{강도0}0900-{비...       NaN
# 2                                                 NaN       NaN
# 3   {비}1406-{싸락눈}1437-{진눈깨비}1450-{진눈깨비}{강도0}1500-{...       NaN
# 4                                                 NaN       NaN
# 5   {눈}1627-1640.  {눈}1742-{눈}{강도0}1800-2024.  {달무...       NaN
# 6                                                 NaN       NaN
# 7                                                 NaN       NaN
# 8                                                 NaN       NaN
# 9                                                 NaN       NaN
# 10                                                NaN       NaN
# 11                                                NaN       NaN
# 12                                                NaN       NaN
# 13                                                NaN       NaN
# 14                     {소낙눈}2045-{소낙눈}{강도0}2100-2139.       NaN
# 15                                                NaN       NaN
# 16                                                NaN       NaN
# 17                                                NaN       NaN
# 18                                                NaN       NaN
# 19                                                NaN       NaN
# 20                                                NaN       NaN
# 21                                                NaN       NaN
# 22                                                NaN       NaN
# 23                                                NaN       NaN
# 24                                                NaN       NaN
# 25                                                NaN       NaN
# 26                                         {달무리}1900-       NaN
# 27  {비}1442-{비}{강도0}1500-{비}{강도0}1800-{비}{강도0}2100...       NaN
# 28  -{비}-{비}{강도0}0300-{비}{강도0}0600-{진눈깨비}0747-{진눈깨...       NaN
# 29                         -{눈}-0130.  {폭풍}1032-1108.       NaN
# 30                                                NaN       NaN
# 31                                                NaN       NaN
# 32                                                NaN       NaN
# 33                                                NaN       NaN
# 34                                                NaN       NaN
# 35                                                NaN       NaN
# 36                                                NaN       NaN
# 37                                                NaN       NaN
# 38                                                NaN       NaN
# 39                                                NaN       NaN
# 40                                                NaN       NaN
# 41                                                NaN       NaN
# 42                                                NaN       NaN
# 43                                                NaN       NaN
# 44                                                NaN       NaN
# 45                                                NaN       NaN
# 46                                                NaN       NaN
# 47                                                NaN       NaN
# 48                                                NaN       NaN
# 49                                                NaN       NaN
#
# [50 rows x 62 columns]

# %%
df_k.columns
# Out:
# Index(['지점 번호', '관측지점', '시간', '평균 기온', '최저 기온', '최저 기온 시각', '최고 기온',
#        '최대 기온 시각', '10분 최다 강수량', '10분 최다강수량 시각', '1시간 최다강수량', '1시간 최다 강수량 시각',
#        'sumRnDur', '일강수량', '최대 순간풍속', '최대 순간 풍속 풍향', '최대 순간풍속 시간', '최대 풍속',
#        '최대 풍속 풍향', '최대 풍속 시각', '평균 풍속', '풍정합', '최대 풍향', '평균 이슬점온도', '최소 상대습도',
#        '평균 상대습도 시각', '평균 상대습도', '평균 증기압', '평균 현지기압', '최고 해면 기압', '최고 해면기압 시각',
#        '최저 해면기압', '최저 해면기압 시각', '평균 해면기압', '가조시간', '합계 일조 시간', '1시간 최다 일사량 시각',
#        '1시간 최다 일사량', '합계 일사', '일 최심신적설', '일 최심신적설 시각', '일 최심적설', '일 최심적설 시각',
#        '합계 3시간 신적설', '평균 전운량', '평균 중하층운량', '평균 지면온도', '최저 초상온도', '평균 5cm 지중온도',
#        '평균10cm 지중온도', '평균 20cm 지중온도', '평균 30cm 지중온도', '0.5m 지중온도', '1.0m 지중온도',
#        '1.5m 지중온도', '3.0m 지중온도', '5.0m 지중온도', '합계 대형증발량', '합계 소형증발량', '9-9강수',
#        '일기현상', '안개 계속 시간'],
#       dtype='object')

# %%
df_w = pd.read_csv('./주변국_기후_도시명.csv', index_col=0)
# df_w.drop('index', axis=1, inplace=True)
df_w
# Out:
#          도시명          일시      평균기온  최고기온  최저기온         습도     풍향         풍속  \
# 0         선봉  1996-01-01 -6.542857  -1.5  -9.8  47.000000  330.0  47.000000
# 1         선봉  1996-01-02 -4.687500   1.5 -10.4  75.500000  360.0  75.500000
# 2         선봉  1996-01-03 -7.400000  -1.1 -11.6  57.625000  320.0  57.625000
# 3         선봉  1996-01-04 -8.862500  -5.0 -12.0  48.375000  330.0  48.375000
# 4         선봉  1996-01-05 -6.300000  -0.8 -10.5  79.625000   20.0  79.625000
# ...      ...         ...       ...   ...   ...        ...    ...        ...
# 420345  히로시마  2021-12-27  3.295833   5.3   0.6  60.487500  320.0  60.487500
# 420346  히로시마  2021-12-28  5.887500   9.5   3.2  62.079167  350.0  62.079167
# 420347  히로시마  2021-12-29  7.162500   9.2   4.3  72.129167   80.0  72.129167
# 420348  히로시마  2021-12-30  4.291667   8.8   0.4  59.554167  280.0  59.554167
# 420349  히로시마  2021-12-31  1.300000   1.3   1.3  75.200000   10.0  75.200000
#
#          강수량       해면기압     이슬점 온도  군집
# 0        0.0  47.000000 -16.400000  n2
# 1        0.0  75.500000  -8.625000  n2
# 2        0.0  57.625000 -14.600000  n2
# 3        0.0  48.375000 -18.237500  n2
# 4        0.0  79.625000  -9.425000  n2
# ...      ...        ...        ...  ..
# 420345   0.5  60.487500  -3.920833  n5
# 420346 -99.8  62.079167  -1.250000  n5
# 420347 -98.8  72.129167   2.329167  n5
# 420348 -97.8  59.554167  -3.316667  n5
# 420349   2.0  75.200000  -2.600000  n5
#
# [420350 rows x 12 columns]

# %%
df_w['일시'] = pd.to_datetime(df_w['일시'], format='%Y-%m-%d')

# %%
df_w['일시'].dt.year
# Out:
# 0         1996
# 1         1996
# 2         1996
# 3         1996
# 4         1996
#           ...
# 420345    2021
# 420346    2021
# 420347    2021
# 420348    2021
# 420349    2021
# Name: 일시, Length: 420350, dtype: int64

# %%
df_r = pd.read_csv('./장마.csv', encoding='euckr')
df_r
# Out:
#       지점번호  지점명         시작일         종료일  장마일수  강수일수  합계강수량
# 0       90   속초  1980-06-16  1980-07-30    45    24  330.5
# 1       95   철원  1980-06-16  1980-07-30    45     0    NaN
# 2      100  대관령  1980-06-16  1980-07-30    45    27  512.9
# 3      101   춘천  1980-06-16  1980-07-30    45    26  365.9
# 4      105   강릉  1980-06-16  1980-07-30    45    24  378.3
# ...    ...  ...         ...         ...   ...   ...    ...
# 2767   285   합천  2021-07-03  2021-07-19    17    11  226.4
# 2768   288   밀양  2021-07-03  2021-07-19    17    12  308.0
# 2769   289   산청  2021-07-03  2021-07-19    17    10  205.1
# 2770   294   거제  2021-07-03  2021-07-19    17    10  447.6
# 2771   295   남해  2021-07-03  2021-07-19    17     8  503.0
#
# [2772 rows x 7 columns]

# %%
df_r.columns
# Out:
# Index(['지점번호', '지점명', '시작일', '종료일', '장마일수', '강수일수', '합계강수량'], dtype='object')

# %%
df_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지점번호    2772 non-null   int64
#  1   지점명     2772 non-null   object
#  2   시작일     2772 non-null   object
#  3   종료일     2772 non-null   object
#  4   장마일수    2772 non-null   int64
#  5   강수일수    2772 non-null   int64
#  6   합계강수량   2726 non-null   float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 151.7+ KB

# %%
df_r['시작일'] = pd.to_datetime(df_r['시작일'], format='%Y-%m-%d')

# %%
df_r = df_r[df_r['시작일'].dt.year > 1995]
df_r = df_r.reset_index()
df_r.drop('index', axis=1, inplace=True)

# %%
df_r
# Out:
#       지점번호  지점명        시작일         종료일  장마일수  강수일수  합계강수량
# 0      184   제주 1996-06-19  1996-07-16    28    21  241.3
# 1      185   고산 1996-06-19  1996-07-16    28    20  222.2
# 2      188   성산 1996-06-19  1996-07-16    28    19  375.5
# 3      189  서귀포 1996-06-19  1996-07-16    28    19  359.8
# 4       90   속초 1996-06-24  1996-07-22    29    14  142.5
# ...    ...  ...        ...         ...   ...   ...    ...
# 1711   285   합천 2021-07-03  2021-07-19    17    11  226.4
# 1712   288   밀양 2021-07-03  2021-07-19    17    12  308.0
# 1713   289   산청 2021-07-03  2021-07-19    17    10  205.1
# 1714   294   거제 2021-07-03  2021-07-19    17    10  447.6
# 1715   295   남해 2021-07-03  2021-07-19    17     8  503.0
#
# [1716 rows x 7 columns]

# %%
df_r.isna().sum()
# Out:
# 지점번호     0
# 지점명      0
# 시작일      0
# 종료일      0
# 장마일수     0
# 강수일수     0
# 합계강수량    0
# dtype: int64
