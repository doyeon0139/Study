# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./북한 기후 시간단위/북한 1996(시간).csv', encoding='euckr')
df.head(2)
# Out:
#    지점                일시  전운량(할)  최저운고(할)  중하층운량(할)  하층운형  중층운형  상층운형  기온(°C)  \
# 0   3  1996-01-01 03:00       0      NaN       NaN   NaN   NaN   NaN    -9.8
# 1   3  1996-01-01 06:00       0      NaN       NaN   NaN   NaN   NaN    -9.2
#
#    풍향(36방위)  풍속(m/s)  해면기압(hPa)  현지기압(hPa)  12시간강수량(mm)  상대습도(%)  이슬점온도(°C)  \
# 0      32.0      5.0     1017.4        NaN          NaN     44.0      -19.9
# 1      32.0      3.0     1019.0        NaN          NaN     42.0      -19.8
#
#    시정(10m)
# 0   2000.0
# 1   2000.0

# %%
df.rename(columns={'지점':'지점번호'}, inplace=True)

# %%
df.head(10)
# Out:
#    지점번호                일시  전운량(할)  최저운고(할)  중하층운량(할)  하층운형  중층운형  상층운형  \
# 0     3  1996-01-01 03:00       0      NaN       NaN   NaN   NaN   NaN
# 1     3  1996-01-01 06:00       0      NaN       NaN   NaN   NaN   NaN
# 2     3  1996-01-01 09:00       0      NaN       NaN   NaN   NaN   NaN
# 3     3  1996-01-01 12:00       0      NaN       NaN   NaN   NaN   NaN
# 4     3  1996-01-01 15:00       0      NaN       NaN   NaN   NaN   NaN
# 5     3  1996-01-01 18:00       0      NaN       NaN   NaN   NaN   NaN
# 6     3  1996-01-01 21:00       0      NaN       NaN   NaN   NaN   NaN
# 7     3  1996-01-02 00:00      10      9.0       8.0   3.0   1.0   NaN
# 8     3  1996-01-02 03:00       0      9.0       NaN   NaN   NaN   NaN
# 9     3  1996-01-02 06:00      10      6.0      10.0   5.0   0.0   0.0
#
#    기온(°C)  풍향(36방위)  풍속(m/s)  해면기압(hPa)  현지기압(hPa)  12시간강수량(mm)  상대습도(%)  \
# 0    -9.8      32.0      5.0     1017.4        NaN          NaN     44.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71928 entries, 0 to 71927
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   지점번호         71928 non-null  int64
#  1   일시           71928 non-null  object
#  2   전운량(할)       71928 non-null  int64
#  3   최저운고(할)      69784 non-null  float64
#  4   중하층운량(할)     45032 non-null  float64
#  5   하층운형         45138 non-null  float64
#  6   중층운형         36168 non-null  float64
#  7   상층운형         25371 non-null  float64
#  8   기온(°C)       71727 non-null  float64
#  9   풍향(36방위)     71916 non-null  float64
#  10  풍속(m/s)      71901 non-null  float64
#  11  해면기압(hPa)    63993 non-null  float64
#  12  현지기압(hPa)    481 non-null    float64
#  13  12시간강수량(mm)  3906 non-null   float64
#  14  상대습도(%)      71333 non-null  float64
#  15  이슬점온도(°C)    71769 non-null  float64
#  16  시정(10m)      71845 non-null  float64
# dtypes: float64(14), int64(2), object(1)
# ...

# %%
df['지점번호'].unique()
# Out:
# array([ 3,  5,  8, 14, 16, 20, 22, 25, 28, 31, 35, 37, 39, 41, 46, 50, 52,
#        55, 58, 60, 61, 65, 67, 68, 69, 70, 75], dtype=int64)

# %%
li_a = [3,  5,  8, 14, 16, 20, 22, 25, 28, 31, 35, 37, 39, 41, 46, 50, 52, 55, 58, 60, 61, 65, 67, 68, 69, 70, 75]

# %%
no = [5, 22, 16, 20, 14, 39, 46, 31, 41, 25, 3, 8]

# %%
li_b=[]

for i in df['지점번호']:
    if i in no:
        li_b.append('north')
    else:
        li_b.append('south')
        
li_b
# Out:
# ['north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
#  'north',
# ...

# %%
len(li_b)
# Out:
# 71928

# %%
df['지점구분'] = li_b

# %%
df.head(2)
# Out:
#    지점번호                일시  전운량(할)  최저운고(할)  중하층운량(할)  하층운형  중층운형  상층운형  \
# 0     3  1996-01-01 03:00       0      NaN       NaN   NaN   NaN   NaN
# 1     3  1996-01-01 06:00       0      NaN       NaN   NaN   NaN   NaN
#
#    기온(°C)  풍향(36방위)  풍속(m/s)  해면기압(hPa)  현지기압(hPa)  12시간강수량(mm)  상대습도(%)  \
# 0    -9.8      32.0      5.0     1017.4        NaN          NaN     44.0
# 1    -9.2      32.0      3.0     1019.0        NaN          NaN     42.0
#
#    이슬점온도(°C)  시정(10m)   지점구분
# 0      -19.9   2000.0  north
# 1      -19.8   2000.0  north

# %%
df['전운량(할)'].sort_values(ascending=False)
# Out:
# 71927    10
# 61512    10
# 29404    10
# 29405    10
# 29407    10
#          ..
# 36000     0
# 36001     0
# 36002     0
# 36003     0
# 35964     0
# Name: 전운량(할), Length: 71928, dtype: int64

# %%
df['일시'] = df['일시'].apply(lambda x:x.split()[0])

# %%
df_tt = df.groupby(['지점번호', '일시']).agg({'기온(°C)':['mean','max','min'], '상대습도(%)':'mean', 
                                        '풍향(36방위)':'mean','풍속(m/s)':'mean', '12시간강수량(mm)':'sum','해면기압(hPa)':'mean',
                                        '이슬점온도(°C)':'mean'})

df_tt.columns = ['평균기온','최고기온','최저기온','습도','풍향','풍속','강수량','해면기압','이슬점 온도']
df_city_b = df_tt.reset_index()

# %%
df_city_b
# Out:
#       지점번호          일시       평균기온  최고기온  최저기온      습도         풍향        풍속  \
# 0        3  1996-01-01  -6.542857  -1.5  -9.8  47.000  20.857143  2.571429
# 1        3  1996-01-02  -4.687500   1.5 -10.4  75.500  10.250000  0.500000
# 2        3  1996-01-03  -7.400000  -1.1 -11.6  57.625  32.250000  8.250000
# 3        3  1996-01-04  -8.862500  -5.0 -12.0  48.375  18.250000  2.375000
# 4        3  1996-01-05  -6.300000  -0.8 -10.5  79.625   5.125000  0.500000
# ...    ...         ...        ...   ...   ...     ...        ...       ...
# 9740    75  1996-12-15  -3.600000  -3.6  -3.6  89.000   0.000000  0.000000
# 9741    75  1996-12-17  -0.050000   3.7  -3.8  73.500  31.500000  3.500000
# 9742    75  1996-12-18  -8.550000  -5.6 -11.3  55.750  20.750000  2.500000
# 9743    75  1996-12-19 -11.500000 -11.5 -11.5  91.000   0.000000  0.000000
# 9744    75  1996-12-21  -0.900000  -0.9  -0.9  98.000   0.000000  0.000000
#
#       강수량         해면기압   이슬점 온도
# 0     0.0  1018.785714 -16.4000
# ...

# %%
li_c=[]

for i in df_city_b['지점번호']:
    if i in no:
        li_c.append('n2')
    else:
        li_c.append('n1')
        
li_c
# Out:
# ['n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
# ...

# %%
df_city_b['지점구분'] = li_c

# %%
df_city_b
# Out:
#       지점번호          일시       평균기온  최고기온  최저기온      습도         풍향        풍속  \
# 0        3  1996-01-01  -6.542857  -1.5  -9.8  47.000  20.857143  2.571429
# 1        3  1996-01-02  -4.687500   1.5 -10.4  75.500  10.250000  0.500000
# 2        3  1996-01-03  -7.400000  -1.1 -11.6  57.625  32.250000  8.250000
# 3        3  1996-01-04  -8.862500  -5.0 -12.0  48.375  18.250000  2.375000
# 4        3  1996-01-05  -6.300000  -0.8 -10.5  79.625   5.125000  0.500000
# ...    ...         ...        ...   ...   ...     ...        ...       ...
# 9740    75  1996-12-15  -3.600000  -3.6  -3.6  89.000   0.000000  0.000000
# 9741    75  1996-12-17  -0.050000   3.7  -3.8  73.500  31.500000  3.500000
# 9742    75  1996-12-18  -8.550000  -5.6 -11.3  55.750  20.750000  2.500000
# 9743    75  1996-12-19 -11.500000 -11.5 -11.5  91.000   0.000000  0.000000
# 9744    75  1996-12-21  -0.900000  -0.9  -0.9  98.000   0.000000  0.000000
#
#       강수량         해면기압   이슬점 온도 지점구분
# ...
