# %%
import pandas as pd
import numpy as np
import os
import FinanceDataReader as fdr
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')
import datetime as dt

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('151860','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
df_stock
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2016-06-01  3125  3190  3110   3130  113988  0.001600
# 2016-06-02  3130  3170  3120   3150   69486  0.006390
# 2016-06-03  3150  3160  3080   3140   97361 -0.003175
# 2016-06-07  3145  3145  3075   3085  111989 -0.017516
# 2016-06-08  3085  3100  3050   3060  107063 -0.008104
# 2016-06-09  3045  3075  3025   3060  118659  0.000000
# 2016-06-10  3085  3085  3035   3065   43216  0.001634
# 2016-06-13  3060  3060  2950   2980  169103 -0.027732
# 2016-06-14  2955  3000  2940   2995   79111  0.005034
# 2016-06-15  2995  2995  2930   2975   64202 -0.006678
# 2016-06-16  2990  2990  2900   2910  111542 -0.021849
# 2016-06-17  2955  2955  2885   2895   70420 -0.005155
# 2016-06-20  2895  2995  2880   2960   76916  0.022453
# 2016-06-21  2975  2990  2915   2940   51630 -0.006757
# 2016-06-22  2955  2955  2895   2945   68619  0.001701
# 2016-06-23  2945  2950  2900   2915   58800 -0.010187
# ...

# %%
# KG ETS
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('151860','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('151860','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('060150','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('060150','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_stock = pd.DataFrame()
for i in range(6,8):
    df_stock_a = fdr.DataReader('060150','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#2016

# %%
# 진바이오 2016
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('086060','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 우성 2016
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('006980','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 한일사료 2016
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('005860','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 신라에스지 2016
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('030720','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 동원수산 2016
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('025870','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 파루 2016
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('043200','2016','2017').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 진바이오 2017
df_stock = pd.DataFrame()
for i in range(1,7):
    df_stock_a = fdr.DataReader('086060','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 우성 2017
df_stock = pd.DataFrame()
for i in range(1,7):
    df_stock_a = fdr.DataReader('006980','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 한일사료 2017
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('005860','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 신라에스지 2017
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('030720','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 파루 2017
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('043200','2017','2018').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 진바이오 2018
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('086060','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 우성 2018
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('006980','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 한일사료 2018
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('005860','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 동원 2018
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('030720','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 신라에스지 2018
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('025870','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 파루 2017
df_stock = pd.DataFrame()
for i in range(2,5):
    df_stock_a = fdr.DataReader('043200','2018','2019').query(('Date.dt.month == {}'.format(i)))
    df_stock = pd.concat([df_stock, df_stock_a])
# df_stock
df_stock['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
