# %%
import pandas as pd
import numpy as np
import os

# %%
file_list = os.listdir('./Project_csv')
file_list
# Out:
# ['3S.xlsx.csv',
#  'AJ네트웍스.xlsx.csv',
#  'AK홀딩스.xlsx.csv',
#  'APS홀딩스.xlsx.csv',
#  'AP시스템.xlsx.csv',
#  'BGF.xlsx.csv',
#  'BNGT.xlsx.csv',
#  'BNK금융지주.xlsx.csv',
#  'BYC.xlsx.csv',
#  'CJ CGV.xlsx.csv',
#  'CJ ENM.xlsx.csv',
#  'CJ 바이오사이언스.xlsx.csv',
#  'CJ.xlsx.csv',
#  'CJ씨푸드.xlsx.csv',
#  'CJ제일제당.xlsx.csv',
#  'CJ프레시웨이.xlsx.csv',
#  'CMG제약.xlsx.csv',
#  'CS홀딩스.xlsx.csv',
#  'DB.xlsx.csv',
#  'DB하이텍.xlsx.csv',
#  'DL.xlsx.csv',
#  'DMS.xlsx.csv',
#  'DRB동일.xlsx.csv',
#  'DSR.xlsx.csv',
#  'E1.xlsx.csv',
#  'EDGC.xlsx.csv',
#  'EG.xlsx.csv',
#  'EMB.xlsx.csv',
#  'EMW.xlsx.csv',
#  'ES큐브.xlsx.csv',
#  'FSN.xlsx.csv',
#  'GH신소재.xlsx.csv',
#  'GS.xlsx.csv',
#  'GS건설.xlsx.csv',
#  'GS글로벌.xlsx.csv',
#  'GS리테일.xlsx.csv',
#  'HB솔루션.xlsx.csv',
#  'HB테크놀러지.xlsx.csv',
#  'HDC.xlsx.csv',
#  'HDC랩스.xlsx.csv',
#  'HDC현대EP.xlsx.csv',
#  'HJ중공업.xlsx.csv',
#  'HLB.xlsx.csv',
#  'HLB생명과학.xlsx.csv',
#  'HLB제약.xlsx.csv',
#  'HLB테라퓨틱스.xlsx.csv',
#  'HMM.xlsx.csv',
#  'HRS.xlsx.csv',
# ...

# %%
file_name = []
for i in file_list:
    a = i.split('.')[0]
    file_name.append(a)
    
len(file_name)
# Out:
# 1461

# %%
file_name[0]
# Out:
# '3S'

# %%
a = file_name[14]
dataset = pd.read_csv("./Project_csv/{}.xlsx.csv".format(a))
dataset
# Out:
#        name            2020            2019            2018            2017  \
# 0      자본총계     81908095000     81908095000     81908095000     72520905000
# 1      자산총계  25611892185000  26280632351000  19497022884000  16868123895000
# 2     당기순이익    786425538000    191028303000    925388625000    412797743000
# 3  영업활동현금흐름   2001752173000   2143095681000    471425123000   1180837049000
# 4      영업이익   1359551440000    896857873000    832709680000    776575241000
# 5       매출액  24245725654000  22352462296000  18670059989000  16477174023000
#
#              2016            2015            2014            2013  \
# 0     72446655000     72428155000     72328655000     72137155000
# 1  15766238539000  13751265058000  13382531013000  13004490092000
# 2    353548750000    253666762000    137851320000     71061595000
# 3    800141934000   1154573133000    688561505000    590904368000
# 4    843638184000    751413820000    579930251000    345479026000
# ...

# %%
total = os.listdir('./krx_12')
total
# Out:
# ['20091230.csv',
#  '20101230.csv',
#  '20111229.csv',
#  '20121228.csv',
#  '20131230.csv',
#  '20141230.csv',
#  '20151230.csv',
#  '20161229.csv',
#  '20171228.csv',
#  '20181228.csv',
#  '20191230.csv',
#  '20201230.csv',
#  '20211230.csv']

# %%
stock_total = []
for a in total:
    x = a.split('.')[0][:4]
    stock_total.append(x)
    
stock_total
# Out:
# ['2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
c = pd.read_csv("./krx_12/20091230.csv", encoding='euckr')

# %%
a = file_name[500]

# %%
stock_close = pd.DataFrame()


for i,j in enumerate(total):
    close = pd.read_csv("./krx_12/{}".format(j), encoding='euckr')
    print(close)
    print('-'*100)
    stock_close[stock_total[i]] = close[close['종목명']== a]['종가']
#     stock_close[stock_total[i]] = close[close['종목명']== a]['시가총액']
#     stock_close[stock_total[i]] = close[close['종목명']== a]['상장주식수']
#     print(close[close['종목명']== a]['종가'])


#     print(i,j)



#  stock_close
# Out:
#         종목코드      종목명    시장구분  소속부     종가   대비    등락률     시가     고가     저가  \
# 0     069110       3H  KOSDAQ  NaN   1020   25   2.51   1010   1070    970
# 1     060310       3S  KOSDAQ  NaN   1175  145  14.08   1005   1175   1005
# 2     900010   3노드디지탈  KOSDAQ  NaN   2125    5   0.24   2120   2160   2115
# 3     013340      AJS  KOSDAQ  NaN   2820   35   1.26   2750   2910   2740
# 4     054620    AP시스템  KOSDAQ  NaN   4275  130   3.14   4190   4275   4085
# ...      ...      ...     ...  ...    ...  ...    ...    ...    ...    ...
# 1956  000540     흥국화재   KOSPI  NaN   6500  210   3.34   6380   6540   6320
# 1957  000547  흥국화재2우B   KOSPI  NaN   4800  180   3.90   4955   5070   4630
# 1958  000545    흥국화재우   KOSPI  NaN   2135    0   0.00   2025   2160   2025
# 1959  003280     흥아해운   KOSPI  NaN    690  -10  -1.43    700    705    685
# 1960  037440       희림  KOSDAQ  NaN  11000  650   6.28  10300  11000  10300
#
#           거래량        거래대금          시가총액     상장주식수
# ...

# %%
close[close['종목명']==a]['종가']
# Out:
# 934    47350
# Name: 종가, dtype: int64

# %%
 stock_close
# Out:
#       2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# 735  30200   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2021
# 735   NaN

# %%
a
# Out:
# 500

# %%
c
# Out:
#         종목코드      종목명    시장구분  소속부     종가   대비    등락률     시가     고가     저가  \
# 0     069110       3H  KOSDAQ  NaN   1020   25   2.51   1010   1070    970
# 1     060310       3S  KOSDAQ  NaN   1175  145  14.08   1005   1175   1005
# 2     900010   3노드디지탈  KOSDAQ  NaN   2125    5   0.24   2120   2160   2115
# 3     013340      AJS  KOSDAQ  NaN   2820   35   1.26   2750   2910   2740
# 4     054620    AP시스템  KOSDAQ  NaN   4275  130   3.14   4190   4275   4085
# ...      ...      ...     ...  ...    ...  ...    ...    ...    ...    ...
# 1956  000540     흥국화재   KOSPI  NaN   6500  210   3.34   6380   6540   6320
# 1957  000547  흥국화재2우B   KOSPI  NaN   4800  180   3.90   4955   5070   4630
# 1958  000545    흥국화재우   KOSPI  NaN   2135    0   0.00   2025   2160   2025
# 1959  003280     흥아해운   KOSPI  NaN    690  -10  -1.43    700    705    685
# 1960  037440       희림  KOSDAQ  NaN  11000  650   6.28  10300  11000  10300
#
#           거래량        거래대금          시가총액     상장주식수
# ...

# %%
c = pd.read_csv("./krx_12/20091230.csv", encoding='euckr')
a = pd.DataFrame()
c['종가'],['시가총액'],['상장주식수']
# Out:
# (0        1020
#  1        1175
#  2        2125
#  3        2820
#  4        4275
#          ...
#  1956     6500
#  1957     4800
#  1958     2135
#  1959      690
#  1960    11000
#  Name: 종가, Length: 1961, dtype: int64,
#  ['시가총액'],
#  ['상장주식수'])
