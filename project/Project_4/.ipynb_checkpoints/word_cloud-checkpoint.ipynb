# %%
import pandas as pd
import nltk 
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer 
from nltk.corpus import stopwords

from wordcloud import WordCloud
from collections import Counter

# %%
# nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bitcamp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('./investing.com_news/commodities-news/news_commodities-news_00002.csv', encoding='utf-8', index_col=0)
news = ""
for n in df.iloc[:10,3]:
    news += n

tokenizer = RegexpTokenizer('[\w]+')
words = news.lower()
tokens = tokenizer.tokenize(words) 

stop = stopwords.words('english')
stopped = [i for i in list(tokens) if not i in stop]

stopped_token = [i for i in stopped if len(i) > 1]  

from wordcloud import WordCloud
from collections import Counter
font_path = 'C:\Windows\Fonts\ALGER.TTF'

im = './ss.png'
mask = 

wordcloud = WordCloud(
font_path = font_path,
    width = 1000,
    height= 1000,
    background_color= 'white',
    mask=mask
)

count = Counter(stopped_token)

wordcloud = wordcloud.generate_from_frequencies(count)

def __array__(self):
    return self.to_array()

def to_array(self):
    return np.array(self.to_image())

array = wordcloud.to_array()

plt.imshow(array, interpolation='bilinear')
plt.show()

# %%
word_count = pd.Series(stopped_token).value_counts()
word_count.head(10)
# Out:
# said       48
# oil        41
# prices     32
# barrels    29
# crude      26
# million    26
# release    25
# energy     23
# opec       23
# supply     18
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
word_count[:20].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# !pip install wordcloud
