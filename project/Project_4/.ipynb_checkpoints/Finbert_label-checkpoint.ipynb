# %%
import pandas as pd
import re
import os

# %%
open_path = 'E:/Study/project/Project_4/dataset_summarization/'
fold_list = os.listdir(open_path)
stock_path = 'E:/Study/project/Project_4/stock_data/stock/'
stock_list = os.listdir(stock_path)

for sto in stock_list:
#     print(s)
    data_concat = pd.DataFrame()
    stock = pd.read_csv(stock_path+sto,index_col=0)
    stock['label'] = stock['전일비'].apply(lambda x : 1 if x > 3 else (0 if x >= -3 else -1))
    for folder in fold_list:
        file_list = os.listdir(open_path+folder)
        for file in file_list:
            df = pd.read_csv(open_path+folder+'/'+file, index_col=0)
            df.dropna(inplace=True)
            df['date'] = df['date'].astype(str).str.strip('<span>').str.strip('</span>')
            df['date'] = df['date'].str.replace('\n','').str.replace('—','')
            df['date'] = df['date'].apply(lambda x: re.findall('\(([^)]+)',x)[0] if re.findall('\(([^)]+)',x) else x )
            df['date'] = pd.to_datetime(df['date'].astype(str),utc=True)#.astype(str).apply(lambda x: x[:10]).astype('datetime64')
            df['content'] = df['content'].apply(lambda x : x.split(' - ')[1] if len(x.split(' - '))>1 else x.split(' - ')[0])
            df['labeldate'] = (df['date'] + np.timedelta64(13,'h')).apply(lambda x : x+ np.timedelta64(1,'D') if x.hour >= 7 else x).apply(lambda x:str(x)[:10])      

            temp = pd.merge(df, stock[['Date','label']], how = 'left', left_on = 'labeldate', right_on = 'Date')
            
            temp.dropna(inplace=True)
            data_concat = pd.concat([data_concat,temp], ignore_index=True)
    data_concat.drop_duplicates(inplace=True)
    data_concat.to_csv('E:/Study/project/Project_4/stock_data/dataset_summarization/'+sto)
# Out:
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
# ...
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bitcamp\Anaconda3\envs\nlp\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)

# %%
df_tt = pd.read_csv('E:/Study/project/Project_4/stock_data/dataset_Text_Rank/광고_지수.csv', index_col=0)
df_tt
# Out:
#                  company                       date  \
# 0             By Reuters  2022-04-17 05:31:00+00:00
# 1       By Investing.com  2022-04-17 03:32:00+00:00
# 2             By Reuters  2022-04-17 00:41:00+00:00
# 3             By Reuters  2022-04-16 18:05:00+00:00
# 4             By Reuters  2022-04-16 12:15:00+00:00
# ...                  ...                        ...
# 289212        By Reuters  2019-01-10 00:27:00+00:00
# 289213        By Reuters  2019-01-09 23:24:00+00:00
# 289214        By Reuters  2019-01-09 23:19:00+00:00
# 289215        By Reuters  2019-01-09 22:35:00+00:00
# 289216        By Reuters  2019-01-09 22:04:00+00:00
#
#                                                     title  \
# 0       Tunisia says countries offer help to tackle im...
# 1       Energy & Precious Metals - Weekly Review and O...
# 2       Mexico's Pemex says fire under control at Sali...
# 3       New bird flu cases identified in Pennsylvania ...
# 4       Eyeing green vote, Macron vows to exit oil, co...
# ...                                                   ...
# 289212  Australian police charge man over hazardous pa...
# 289213  South Korea's Moon urges Japan leaders not to ...
# 289214  Philippine court orders jail for former bank m...
# 289215  Vietnam arrests former BIDV banker amid graft ...
# 289216  Opposition leader Felix Tshisekedi wins Congo'...
#
#                                                   content   labeldate  \
# 0       Some countries have offered to help Tunisia pr...  2022-04-18
# 1       Following that, the Fed’s most hawkish policy-...  2022-04-18
# 2       MEXICO CITY (Reuters) -Mexican state oil compa...  2022-04-18
# 3       New bird flu cases were detected in a commerci...  2022-04-18
# 4       President Emmanuel Macron promised on Saturday...  2022-04-17
# ...                                                   ...         ...
# 289212  Australian police on Thursday charged a 49-yea...  2019-01-11
# 289213  South Korean President Moon Jae-in said on Thu...  2019-01-11
# 289214  A Philippine court on Thursday held a former b...  2019-01-11
# 289215  Police in Vietnam have arrested a former senio...  2019-01-11
# 289216  But vote tallies compiled by Congo's Catholic ...  2019-01-11
#
#               Date  label
# 0       2022-04-18    0.0
# 1       2022-04-18    0.0
# 2       2022-04-18    0.0
# 3       2022-04-18    0.0
# 4              NaN    NaN
# ...            ...    ...
# 289212  2019-01-11   -1.0
# 289213  2019-01-11   -1.0
# 289214  2019-01-11   -1.0
# 289215  2019-01-11   -1.0
# 289216  2019-01-11   -1.0
#
# [289217 rows x 7 columns]

# %%
df[df['content'].apply(lambda x : type(x) == float)]
# Out:
#               company                      date  \
# 343  By Investing.com 2020-05-14 21:41:00+00:00
#
#                                                  title content
# 343  Oil Mixed Again With Continuous Second Wave Fears     NaN

# %%
# Out:
# 1437

# %%
drop_path = 'E:/Study/project/Project_4/stock_data/dataset_Text_Rank/'
drop_list = os.listdir(drop_path)

for drop in drop_list:
    df_drop = pd.read_csv(drop_path+drop)

    df_drop.drop_duplicates(inplace=True)
    df_drop.dropna(inplace=True)
    
    df_drop.to_csv(drop_path+drop)

# %%
drop_list
# Out:
# ['광고_지수.csv',
#  '반도체와반도체장비_지수.csv',
#  '석유와가스_지수.csv',
#  '자동차_지수.csv',
#  '조선_지수.csv',
#  '철강_지수.csv']
