# %%
import warnings
warnings.filterwarnings('ignore') # to avoid warnings

import random
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

from transformers import BertTokenizer,  AutoModelForSequenceClassification, AdamW, get_linear_schedule_with_warmup

import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from torch.utils.data import TensorDataset

# %%
# 데이터 불러오기
financial_data = pd.read_csv("./financial_phrase_bank_pt_br.csv/financial_phrase_bank_pt_br.csv", 
                             encoding='utf-8', skiprows=1,
                             names=['sentiment', 'NewsHeadline', 'drop'])
financial_data.drop('drop', axis=1, inplace=True)
financial_data
# Out:
#      sentiment                                       NewsHeadline
# 0      neutral  Technopolis plans to develop in stages an area...
# 1     negative  The international electronic industry company ...
# 2     positive  With the new production plant the company woul...
# 3     positive  According to the company 's updated strategy f...
# 4     positive  FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# ...        ...                                                ...
# 4840  negative  LONDON MarketWatch -- Share prices ended lower...
# 4841   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4842  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4843  negative  Net sales of the Paper segment decreased to EU...
# 4844  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4845 rows x 2 columns]

# %%
financial_data.shape
# Out:
# (4845, 2)

# %%
financial_data.sentiment.value_counts()
# Out:
# neutral     2878
# positive    1363
# negative     604
# Name: sentiment, dtype: int64

# %%
# Configure the plot size
plt.figure(figsize = (15,8))

sns.set(style='darkgrid')
    
# Increase information on the figure
sns.set(font_scale=1.3)
sns.countplot(x='sentiment', data = financial_data)
plt.title('News Sentiment Distribution')
plt.xlabel('News Polarity')
plt.ylabel('Number of News')
# Out:
# Text(0, 0.5, 'Number of News')

# %%
def show_random_headlines(total_number, df):
    
    # Get the random number of reviews
    n_reviews = df.sample(total_number)
#     return n_reviews
    # Print each one of the reviews
    for val in list(n_reviews.index):
        print("Reviews #°{}".format(val))
        print(" - Sentiment: {}".format(df.iloc[val]["sentiment"]))
        print(" - News Headline: {}".format(df.iloc[val]["NewsHeadline"]))
        print("")
        
# Show 5 random headlines
# 5개 랜덤으로 뽑아서 내용 확인
show_random_headlines(5, financial_data)
# Out:
# Reviews #°574
#  - Sentiment: positive
#  - News Headline: To prove the efficiency of the China Mobile system , Rod Baber , an English climber , climbed to the Mount Everest summit and successfully made calls .
#
# Reviews #°4654
#  - Sentiment: negative
#  - News Headline: Finnish plumbing and heating systems supplier Uponor 's net sales from continuing operations decreased by 9.4 % in 2008 to EUR 949.2 mn from EUR 1,047.4 mn in 2007 .
#
# Reviews #°500
#  - Sentiment: neutral
#  - News Headline: Rental of building equipment accounted for 88 percent of the operating income .
#
# Reviews #°3245
#  - Sentiment: neutral
#  - News Headline: The financial details of the acquisition were not disclosed .
#
# Reviews #°1357
#  - Sentiment: neutral
#  - News Headline: The center offers a comprehensive range of device design services spanning from electronics , mechanics and software design to a full range of testing laboratory services .

# %%
def get_headlines_len(df):
    
    headlines_sequence_lengths = []
    
    print("Encoding in progress...")
    for headline in tqdm(df.NewsHeadline):
        encoded_headline = finbert_tokenizer.encode(headline, 
                                         add_special_tokens = True)
        
        # record the length of the encoded review
        headlines_sequence_lengths.append(len(encoded_headline))
    print("End of Task.")
    
    return headlines_sequence_lengths

# %%
def encode_sentiments_values(df):
    
    possible_sentiments = df.sentiment.unique()
    sentiment_dict = {}
    
    for index, possible_sentiment in enumerate(possible_sentiments):
        sentiment_dict[possible_sentiment] = index
    
    # Encode all the sentiment values
    df['label'] = df.sentiment.replace(sentiment_dict)
    
    return df, sentiment_dict
 
# Perform the encoding task on the data set
# label값 지정 newtral = 0, negative, = 1, positive
financial_data, sentiment_dict = encode_sentiments_values(financial_data)

# %%
financial_data.head()
# Out:
#   sentiment                                       NewsHeadline  label
# 0   neutral  Technopolis plans to develop in stages an area...      0
# 1  negative  The international electronic industry company ...      1
# 2  positive  With the new production plant the company woul...      2
# 3  positive  According to the company 's updated strategy f...      2
# 4  positive  FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...      2

# %%
# Create training and validation data
# train, test 나누기
X_train, X_val, y_train, y_val = train_test_split(financial_data.index.values, 
                                                  financial_data.label.values, 
                                                  test_size = 0.15, 
                                                  random_state = 2022, 
                                                  stratify = financial_data.label.values)

# %%
# Create the data type columns
financial_data.loc[X_train, 'data_type'] = 'train'
financial_data.loc[X_val, 'data_type'] = 'val'

# Vizualiez the number of sentiment occurence on each type of data
financial_data.groupby(['sentiment', 'label', 'data_type']).count()
# Out:
#                            NewsHeadline
# sentiment label data_type
# negative  1     train               513
#                 val                  91
# neutral   0     train              2446
#                 val                 432
# positive  2     train              1159
#                 val                 204

# %%
# Get the FinBERT Tokenizer
finbert_tokenizer = BertTokenizer.from_pretrained("ProsusAI/finbert", do_lower_case=True)

# Encode the Training and Validation Data
encoded_data_train = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='train'].NewsHeadline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)

encoded_data_val = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='val'].NewsHeadline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(financial_data[financial_data.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
sentiments_val = torch.tensor(financial_data[financial_data.data_type=='val'].label.values)


dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, sentiments_val)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
len(sentiment_dict)
# Out:
# 3

# %%
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)

# %%
headlines_sequence_lengths = get_headlines_len(financial_data)
# Out:
# Encoding in progress...
# 100%|████████████████████████████████████████████████████████████████████████████| 4845/4845 [00:02<00:00, 1997.62it/s]
# End of Task.

# %%
plt.figure(figsize = (15,8))
plt.hist(headlines_sequence_lengths, bins=30)
# Out:
# (array([ 34., 238., 629., 762., 849., 664., 469., 320., 285., 232., 128.,
#         105.,  73.,  35.,  10.,   7.,   0.,   0.,   1.,   1.,   0.,   1.,
#           0.,   1.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  4.        ,   8.86666667,  13.73333333,  18.6       ,
#          23.46666667,  28.33333333,  33.2       ,  38.06666667,
#          42.93333333,  47.8       ,  52.66666667,  57.53333333,
#          62.4       ,  67.26666667,  72.13333333,  77.        ,
#          81.86666667,  86.73333333,  91.6       ,  96.46666667,
#         101.33333333, 106.2       , 111.06666667, 115.93333333,
#         120.8       , 125.66666667, 130.53333333, 135.4       ,
#         140.26666667, 145.13333333, 150.        ]),
#  <BarContainer object of 30 artists>)

# %%
batch_size = 5

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5, 
                  eps=1e-8)

epochs = 3

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in sentiment_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
seed_val = 2022
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)


def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_finBERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                                                 | 0/824 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                            | 0/824 [00:02<?, ?it/s, training_loss=0.762]
# Epoch 1:   0%|                                                    | 1/824 [00:02<31:34,  2.30s/it, training_loss=0.762]
# Epoch 1:   0%|                                                    | 1/824 [00:04<31:34,  2.30s/it, training_loss=0.914]
# Epoch 1:   0%|▏                                                   | 2/824 [00:04<30:58,  2.26s/it, training_loss=0.914]
# Epoch 1:   0%|▏                                                   | 2/824 [00:06<30:58,  2.26s/it, training_loss=0.911]
# Epoch 1:   0%|▏                                                   | 3/824 [00:06<30:36,  2.24s/it, training_loss=0.911]
# Epoch 1:   0%|▏                                                   | 3/824 [00:08<30:36,  2.24s/it, training_loss=0.907]
# Epoch 1:   0%|▎                                                   | 4/824 [00:08<30:30,  2.23s/it, training_loss=0.907]
# Epoch 1:   0%|▎                                                   | 4/824 [00:11<30:30,  2.23s/it, training_loss=0.648]
# Epoch 1:   1%|▎                                                   | 5/824 [00:11<30:44,  2.25s/it, training_loss=0.648]
# Epoch 1:   1%|▎                                                   | 5/824 [00:13<30:44,  2.25s/it, training_loss=0.491]
# Epoch 1:   1%|▍                                                   | 6/824 [00:13<31:04,  2.28s/it, training_loss=0.491]
# Epoch 1:   1%|▍                                                   | 6/824 [00:15<31:04,  2.28s/it, training_loss=0.698]
# Epoch 1:   1%|▍                                                   | 7/824 [00:15<31:07,  2.29s/it, training_loss=0.698]
# Epoch 1:   1%|▍                                                   | 7/824 [00:18<31:07,  2.29s/it, training_loss=0.416]
# Epoch 1:   1%|▌                                                   | 8/824 [00:18<31:09,  2.29s/it, training_loss=0.416]
# Epoch 1:   1%|▌                                                   | 8/824 [00:20<31:09,  2.29s/it, training_loss=0.546]
# Epoch 1:   1%|▌                                                   | 9/824 [00:20<32:11,  2.37s/it, training_loss=0.546]
# Epoch 1:   1%|▌                                                   | 9/824 [00:23<32:11,  2.37s/it, training_loss=0.262]
# Epoch 1:   1%|▌                                                  | 10/824 [00:23<32:40,  2.41s/it, training_loss=0.262]
# Epoch 1:   1%|▌                                                  | 10/824 [00:25<32:40,  2.41s/it, training_loss=0.087]
# Epoch 1:   1%|▋                                                  | 11/824 [00:25<33:14,  2.45s/it, training_loss=0.087]
# Epoch 1:   1%|▋                                                  | 11/824 [00:28<33:14,  2.45s/it, training_loss=0.506]
# Epoch 1:   1%|▋                                                  | 12/824 [00:28<33:50,  2.50s/it, training_loss=0.506]
# Epoch 1:   1%|▋                                                  | 12/824 [00:30<33:50,  2.50s/it, training_loss=0.512]
# Epoch 1:   2%|▊                                                  | 13/824 [00:30<33:52,  2.51s/it, training_loss=0.512]
# Epoch 1:   2%|▊                                                  | 13/824 [00:33<33:52,  2.51s/it, training_loss=0.276]
# Epoch 1:   2%|▊                                                  | 14/824 [00:33<33:45,  2.50s/it, training_loss=0.276]
# Epoch 1:   2%|▊                                                  | 14/824 [00:35<33:45,  2.50s/it, training_loss=0.249]
# Epoch 1:   2%|▉                                                  | 15/824 [00:35<33:42,  2.50s/it, training_loss=0.249]
# Epoch 1:   2%|▉                                                  | 15/824 [00:38<33:42,  2.50s/it, training_loss=0.253]
# Epoch 1:   2%|▉                                                  | 16/824 [00:38<33:30,  2.49s/it, training_loss=0.253]
# Epoch 1:   2%|▉                                                  | 16/824 [00:40<33:30,  2.49s/it, training_loss=0.444]
# Epoch 1:   2%|█                                                  | 17/824 [00:40<33:25,  2.48s/it, training_loss=0.444]
# Epoch 1:   2%|█                                                  | 17/824 [00:43<33:25,  2.48s/it, training_loss=0.427]
# Epoch 1:   2%|█                                                  | 18/824 [00:43<33:22,  2.48s/it, training_loss=0.427]
# Epoch 1:   2%|█                                                  | 18/824 [00:45<33:22,  2.48s/it, training_loss=0.289]
# Epoch 1:   2%|█▏                                                 | 19/824 [00:45<33:32,  2.50s/it, training_loss=0.289]
# Epoch 1:   2%|█▏                                                 | 19/824 [00:48<33:32,  2.50s/it, training_loss=0.208]
# Epoch 1:   2%|█▏                                                 | 20/824 [00:48<33:24,  2.49s/it, training_loss=0.208]
# Epoch 1:   2%|█▏                                                 | 20/824 [00:50<33:24,  2.49s/it, training_loss=0.280]
# Epoch 1:   3%|█▎                                                 | 21/824 [00:50<33:21,  2.49s/it, training_loss=0.280]
# Epoch 1:   3%|█▎                                                 | 21/824 [00:53<33:21,  2.49s/it, training_loss=0.351]
# Epoch 1:   3%|█▎                                                 | 22/824 [00:53<33:12,  2.48s/it, training_loss=0.351]
# Epoch 1:   3%|█▎                                                 | 22/824 [00:55<33:12,  2.48s/it, training_loss=0.319]
# Epoch 1:   3%|█▍                                                 | 23/824 [00:55<33:05,  2.48s/it, training_loss=0.319]
# Epoch 1:   3%|█▍                                                 | 23/824 [00:58<33:05,  2.48s/it, training_loss=0.062]
# Epoch 1:   3%|█▍                                                 | 24/824 [00:58<33:00,  2.48s/it, training_loss=0.062]
# Epoch 1:   3%|█▍                                                 | 24/824 [01:00<33:00,  2.48s/it, training_loss=0.377]
# Epoch 1:   3%|█▌                                                 | 25/824 [01:00<33:00,  2.48s/it, training_loss=0.377]
# Epoch 1:   3%|█▌                                                 | 25/824 [01:03<33:00,  2.48s/it, training_loss=0.568]
# Epoch 1:   3%|█▌                                                 | 26/824 [01:03<32:48,  2.47s/it, training_loss=0.568]
# Epoch 1:   3%|█▌                                                 | 26/824 [01:05<32:48,  2.47s/it, training_loss=0.468]
# Epoch 1:   3%|█▋                                                 | 27/824 [01:05<32:48,  2.47s/it, training_loss=0.468]
# Epoch 1:   3%|█▋                                                 | 27/824 [01:08<32:48,  2.47s/it, training_loss=0.402]
# Epoch 1:   3%|█▋                                                 | 28/824 [01:08<32:47,  2.47s/it, training_loss=0.402]
# Epoch 1:   3%|█▋                                                 | 28/824 [01:10<32:47,  2.47s/it, training_loss=0.394]
# Epoch 1:   4%|█▊                                                 | 29/824 [01:10<32:42,  2.47s/it, training_loss=0.394]
# Epoch 1:   7%|███▋                                               | 59/824 [02:28<31:56,  2.50s/it, training_loss=0.205]
# Epoch 1:   7%|███▋                                               | 60/824 [02:28<31:52,  2.50s/it, training_loss=0.205]
# Epoch 1:   7%|███▋                                               | 60/824 [02:30<31:52,  2.50s/it, training_loss=0.060]
# Epoch 1:   7%|███▊                                               | 61/824 [02:30<31:52,  2.51s/it, training_loss=0.060]
# Epoch 1:   7%|███▊                                               | 61/824 [02:33<31:52,  2.51s/it, training_loss=0.161]
# Epoch 1:   8%|███▊                                               | 62/824 [02:33<31:48,  2.50s/it, training_loss=0.161]
# Epoch 1:   8%|███▊                                               | 62/824 [02:35<31:48,  2.50s/it, training_loss=0.533]
# Epoch 1:   8%|███▉                                               | 63/824 [02:35<31:55,  2.52s/it, training_loss=0.533]
# Epoch 1:   8%|███▉                                               | 63/824 [02:38<31:55,  2.52s/it, training_loss=0.249]
# Epoch 1:   8%|███▉                                               | 64/824 [02:38<31:49,  2.51s/it, training_loss=0.249]
# Epoch 1:   8%|███▉                                               | 64/824 [02:40<31:49,  2.51s/it, training_loss=0.385]
# Epoch 1:   8%|████                                               | 65/824 [02:40<31:46,  2.51s/it, training_loss=0.385]
# Epoch 1:   8%|████                                               | 65/824 [02:43<31:46,  2.51s/it, training_loss=0.240]
# Epoch 1:   8%|████                                               | 66/824 [02:43<31:45,  2.51s/it, training_loss=0.240]
# Epoch 1:   8%|████                                               | 66/824 [02:45<31:45,  2.51s/it, training_loss=0.388]
# Epoch 1:   8%|████▏                                              | 67/824 [02:45<31:41,  2.51s/it, training_loss=0.388]
# Epoch 1:   8%|████▏                                              | 67/824 [02:48<31:41,  2.51s/it, training_loss=0.250]
# Epoch 1:   8%|████▏                                              | 68/824 [02:48<31:36,  2.51s/it, training_loss=0.250]
# Epoch 1:   8%|████▏                                              | 68/824 [02:50<31:36,  2.51s/it, training_loss=0.086]
# Epoch 1:   8%|████▎                                              | 69/824 [02:50<31:35,  2.51s/it, training_loss=0.086]
# Epoch 1:   8%|████▎                                              | 69/824 [02:53<31:35,  2.51s/it, training_loss=0.244]
# Epoch 1:   8%|████▎                                              | 70/824 [02:53<31:32,  2.51s/it, training_loss=0.244]
# Epoch 1:   8%|████▎                                              | 70/824 [02:55<31:32,  2.51s/it, training_loss=0.139]
# Epoch 1:   9%|████▍                                              | 71/824 [02:55<31:28,  2.51s/it, training_loss=0.139]
# Epoch 1:   9%|████▍                                              | 71/824 [02:58<31:28,  2.51s/it, training_loss=0.301]
# Epoch 1:   9%|████▍                                              | 72/824 [02:58<31:27,  2.51s/it, training_loss=0.301]
# Epoch 1:   9%|████▍                                              | 72/824 [03:00<31:27,  2.51s/it, training_loss=0.207]
# Epoch 1:   9%|████▌                                              | 73/824 [03:00<31:30,  2.52s/it, training_loss=0.207]
# Epoch 1:   9%|████▌                                              | 73/824 [03:03<31:30,  2.52s/it, training_loss=0.198]
# Epoch 1:   9%|████▌                                              | 74/824 [03:03<31:30,  2.52s/it, training_loss=0.198]
# Epoch 1:   9%|████▌                                              | 74/824 [03:06<31:30,  2.52s/it, training_loss=0.286]
# Epoch 1:   9%|████▋                                              | 75/824 [03:06<31:27,  2.52s/it, training_loss=0.286]
# Epoch 1:   9%|████▋                                              | 75/824 [03:08<31:27,  2.52s/it, training_loss=0.179]
# Epoch 1:   9%|████▋                                              | 76/824 [03:08<31:12,  2.50s/it, training_loss=0.179]
# Epoch 1:   9%|████▋                                              | 76/824 [03:10<31:12,  2.50s/it, training_loss=0.211]
# Epoch 1:   9%|████▊                                              | 77/824 [03:10<31:07,  2.50s/it, training_loss=0.211]
# Epoch 1:   9%|████▊                                              | 77/824 [03:13<31:07,  2.50s/it, training_loss=0.171]
# Epoch 1:   9%|████▊                                              | 78/824 [03:13<31:04,  2.50s/it, training_loss=0.171]
# Epoch 1:   9%|████▊                                              | 78/824 [03:15<31:04,  2.50s/it, training_loss=0.211]
# Epoch 1:  10%|████▉                                              | 79/824 [03:15<31:06,  2.51s/it, training_loss=0.211]
# Epoch 1:  10%|████▉                                              | 79/824 [03:18<31:06,  2.51s/it, training_loss=0.101]
# Epoch 1:  10%|████▉                                              | 80/824 [03:18<30:58,  2.50s/it, training_loss=0.101]
# Epoch 1:  10%|████▉                                              | 80/824 [03:20<30:58,  2.50s/it, training_loss=0.400]
# Epoch 1:  10%|█████                                              | 81/824 [03:20<30:45,  2.48s/it, training_loss=0.400]
# Epoch 1:  10%|█████                                              | 81/824 [03:23<30:45,  2.48s/it, training_loss=0.150]
# Epoch 1:  10%|█████                                              | 82/824 [03:23<30:50,  2.49s/it, training_loss=0.150]
# Epoch 1:  10%|█████                                              | 82/824 [03:25<30:50,  2.49s/it, training_loss=0.410]
# Epoch 1:  10%|█████▏                                             | 83/824 [03:25<30:55,  2.50s/it, training_loss=0.410]
# Epoch 1:  10%|█████▏                                             | 83/824 [03:28<30:55,  2.50s/it, training_loss=0.346]
# Epoch 1:  10%|█████▏                                             | 84/824 [03:28<30:57,  2.51s/it, training_loss=0.346]
# Epoch 1:  10%|█████▏                                             | 84/824 [03:30<30:57,  2.51s/it, training_loss=0.175]
# Epoch 1:  10%|█████▎                                             | 85/824 [03:30<30:53,  2.51s/it, training_loss=0.175]
# Epoch 1:  10%|█████▎                                             | 85/824 [03:33<30:53,  2.51s/it, training_loss=0.087]
# Epoch 1:  10%|█████▎                                             | 86/824 [03:33<30:52,  2.51s/it, training_loss=0.087]
# Epoch 1:  10%|█████▎                                             | 86/824 [03:35<30:52,  2.51s/it, training_loss=0.091]
# Epoch 1:  11%|█████▍                                             | 87/824 [03:35<30:47,  2.51s/it, training_loss=0.091]
# Epoch 1:  11%|█████▍                                             | 87/824 [03:38<30:47,  2.51s/it, training_loss=0.144]
# Epoch 1:  11%|█████▍                                             | 88/824 [03:38<30:46,  2.51s/it, training_loss=0.144]
# Epoch 1:  11%|█████▍                                             | 88/824 [03:41<30:46,  2.51s/it, training_loss=0.109]
# Epoch 1:  18%|████████▉                                         | 147/824 [06:09<28:20,  2.51s/it, training_loss=0.181]
# Epoch 1:  18%|████████▉                                         | 148/824 [06:09<28:22,  2.52s/it, training_loss=0.181]
# Epoch 1:  18%|████████▉                                         | 148/824 [06:11<28:22,  2.52s/it, training_loss=0.177]
# Epoch 1:  18%|█████████                                         | 149/824 [06:11<28:18,  2.52s/it, training_loss=0.177]
# Epoch 1:  18%|█████████                                         | 149/824 [06:14<28:18,  2.52s/it, training_loss=0.079]
# Epoch 1:  18%|█████████                                         | 150/824 [06:14<28:10,  2.51s/it, training_loss=0.079]
# Epoch 1:  18%|█████████                                         | 150/824 [06:16<28:10,  2.51s/it, training_loss=0.140]
# Epoch 1:  18%|█████████▏                                        | 151/824 [06:16<28:08,  2.51s/it, training_loss=0.140]
# Epoch 1:  18%|█████████▏                                        | 151/824 [06:19<28:08,  2.51s/it, training_loss=0.090]
# Epoch 1:  18%|█████████▏                                        | 152/824 [06:19<28:07,  2.51s/it, training_loss=0.090]
# Epoch 1:  18%|█████████▏                                        | 152/824 [06:21<28:07,  2.51s/it, training_loss=0.105]
# Epoch 1:  19%|█████████▎                                        | 153/824 [06:21<28:03,  2.51s/it, training_loss=0.105]
# Epoch 1:  19%|█████████▎                                        | 153/824 [06:24<28:03,  2.51s/it, training_loss=0.212]
# Epoch 1:  19%|█████████▎                                        | 154/824 [06:24<28:00,  2.51s/it, training_loss=0.212]
# Epoch 1:  19%|█████████▎                                        | 154/824 [06:26<28:00,  2.51s/it, training_loss=0.426]
# Epoch 1:  19%|█████████▍                                        | 155/824 [06:26<27:58,  2.51s/it, training_loss=0.426]
# Epoch 1:  19%|█████████▍                                        | 155/824 [06:29<27:58,  2.51s/it, training_loss=0.135]
# Epoch 1:  19%|█████████▍                                        | 156/824 [06:29<27:55,  2.51s/it, training_loss=0.135]
# Epoch 1:  19%|█████████▍                                        | 156/824 [06:31<27:55,  2.51s/it, training_loss=0.244]
# Epoch 1:  19%|█████████▌                                        | 157/824 [06:31<27:53,  2.51s/it, training_loss=0.244]
# Epoch 1:  19%|█████████▌                                        | 157/824 [06:34<27:53,  2.51s/it, training_loss=0.080]
# Epoch 1:  19%|█████████▌                                        | 158/824 [06:34<27:53,  2.51s/it, training_loss=0.080]
# Epoch 1:  19%|█████████▌                                        | 158/824 [06:36<27:53,  2.51s/it, training_loss=0.172]
# Epoch 1:  19%|█████████▋                                        | 159/824 [06:36<27:50,  2.51s/it, training_loss=0.172]
# Epoch 1:  19%|█████████▋                                        | 159/824 [06:39<27:50,  2.51s/it, training_loss=0.160]
# Epoch 1:  19%|█████████▋                                        | 160/824 [06:39<27:46,  2.51s/it, training_loss=0.160]
# Epoch 1:  19%|█████████▋                                        | 160/824 [06:41<27:46,  2.51s/it, training_loss=0.375]
# Epoch 1:  20%|█████████▊                                        | 161/824 [06:41<27:34,  2.50s/it, training_loss=0.375]
# Epoch 1:  20%|█████████▊                                        | 161/824 [06:44<27:34,  2.50s/it, training_loss=0.171]
# Epoch 1:  23%|███████████▌                                      | 190/824 [07:56<26:28,  2.51s/it, training_loss=0.042]
# Epoch 1:  23%|███████████▌                                      | 191/824 [07:56<26:24,  2.50s/it, training_loss=0.042]
# Epoch 1:  23%|███████████▌                                      | 191/824 [07:59<26:24,  2.50s/it, training_loss=0.085]
# Epoch 1:  23%|███████████▋                                      | 192/824 [07:59<26:21,  2.50s/it, training_loss=0.085]
# Epoch 1:  23%|███████████▋                                      | 192/824 [08:01<26:21,  2.50s/it, training_loss=0.276]
# Epoch 1:  23%|███████████▋                                      | 193/824 [08:01<26:16,  2.50s/it, training_loss=0.276]
# Epoch 1:  23%|███████████▋                                      | 193/824 [08:04<26:16,  2.50s/it, training_loss=0.053]
# Epoch 1:  24%|███████████▊                                      | 194/824 [08:04<26:18,  2.51s/it, training_loss=0.053]
# Epoch 1:  24%|███████████▊                                      | 194/824 [08:06<26:18,  2.51s/it, training_loss=0.231]
# Epoch 1:  24%|███████████▊                                      | 195/824 [08:06<26:17,  2.51s/it, training_loss=0.231]
# Epoch 1:  24%|███████████▊                                      | 195/824 [08:09<26:17,  2.51s/it, training_loss=0.032]
# Epoch 1:  24%|███████████▉                                      | 196/824 [08:09<26:22,  2.52s/it, training_loss=0.032]
# Epoch 1:  24%|███████████▉                                      | 196/824 [08:11<26:22,  2.52s/it, training_loss=0.214]
# Epoch 1:  24%|███████████▉                                      | 197/824 [08:11<26:15,  2.51s/it, training_loss=0.214]
# Epoch 1:  24%|███████████▉                                      | 197/824 [08:14<26:15,  2.51s/it, training_loss=0.039]
# Epoch 1:  24%|████████████                                      | 198/824 [08:14<26:09,  2.51s/it, training_loss=0.039]
# Epoch 1:  24%|████████████                                      | 198/824 [08:16<26:09,  2.51s/it, training_loss=0.087]
# Epoch 1:  24%|████████████                                      | 199/824 [08:16<26:05,  2.51s/it, training_loss=0.087]
# ...
# Epoch 3:  92%|██████████████████████████████████████████████    | 759/824 [30:35<02:40,  2.47s/it, training_loss=0.001]
# Epoch 3:  92%|██████████████████████████████████████████████    | 760/824 [30:35<02:37,  2.46s/it, training_loss=0.001]
# Epoch 3:  92%|██████████████████████████████████████████████    | 760/824 [30:37<02:37,  2.46s/it, training_loss=0.027]
# Epoch 3:  92%|██████████████████████████████████████████████▏   | 761/824 [30:37<02:34,  2.46s/it, training_loss=0.027]
# Epoch 3:  92%|██████████████████████████████████████████████▏   | 761/824 [30:40<02:34,  2.46s/it, training_loss=0.001]
# Epoch 3:  92%|██████████████████████████████████████████████▏   | 762/824 [30:40<02:32,  2.46s/it, training_loss=0.001]
# Epoch 3:  92%|██████████████████████████████████████████████▏   | 762/824 [30:42<02:32,  2.46s/it, training_loss=0.237]
# Epoch 3:  93%|██████████████████████████████████████████████▎   | 763/824 [30:42<02:29,  2.46s/it, training_loss=0.237]
# Epoch 3:  93%|██████████████████████████████████████████████▎   | 763/824 [30:44<02:29,  2.46s/it, training_loss=0.001]
# Epoch 3:  93%|██████████████████████████████████████████████▎   | 764/824 [30:44<02:27,  2.46s/it, training_loss=0.001]
# Epoch 3:  93%|██████████████████████████████████████████████
/it, training_loss=0.001]
# Epoch 3:  95%|███████████████████████████████████████████████▌  | 783/824 [31:33<01:40,  2.45s/it, training_loss=0.023]
# Epoch 3:  95%|███████████████████████████████████████████████▌  | 784/824 [31:33<01:37,  2.44s/it, training_loss=0.023]
# Epoch 3:  95%|███████████████████████████████████████████████▌  | 784/824 [31:36<01:37,  2.44s/it, training_loss=0.171]
# Epoch 3:  95%|███████████████████████████████████████████████▋  | 785/824 [31:36<01:35,  2.45s/it, training_loss=0.171]
# Epoch 3:  95%|███████████████████████████████████████████████▋  | 785/824 [31:38<01:35,  2.45s/it, training_loss=0.001]
# Epoch 3:  95%|███████████████████████████████████████████████▋  | 786/824 [31:38<01:32,  2.44s/it, training_loss=0.001]
# Epoch 3:  95%|███████████████████████████████████████████████▋  | 786/824 [31:41<01:32,  2.44s/it, training_loss=0.001]
# Epoch 3:  96%|███████████████████████████████████████████████▊  | 787/824 [31:41<01:30,  2.45s/it, training_loss=0.001]
# Epoch 3:  96%|███████████████████████████████████████████████▊  | 787/824 [31:43<01:30,  2.45s/it, training_loss=0.001]
# Epoch 3:  96%|███████████████████████████████████████████████▊  | 788/824 [31:43<01:27,  2.44s/it, training_loss=0.001]
# Epoch 3:  96%|███████████████████████████████████████████████▊  | 788/824 [31:46<01:27,  2.44s/it, training_loss=0.001]
# Epoch 3:  96%|███████████████████████████████████████████████▉  | 789/824 [31:46<01:25,  2.46s/it, training_loss=0.001]
# Epoch 3:  96%|███████████████████████████████████████████████▉  | 789/824 [31:48<01:25,  2.46s/it, training_loss=0.003]
# Epoch 3:  96%|███████████████████████████████████████████████▉  | 790/824 [31:48<01:23,  2.44s/it, training_loss=0.003]
# Epoch 3:  96%|███████████████████████████████████████████████▉  | 790/824 [31:51<01:23,  2.44s/it, training_loss=0.003]
# Epoch 3:  96%|███████████████████████████████████████████████▉  | 791/824 [31:51<01:21,  2.46s/it, training_loss=0.003]
# Epoch 3:  96%|███████████████████████████████████████████████▉  | 791/824 [31:53<01:21,  2.46s/it, training_loss=0.285]
# Epoch 3:  96%|████████████████████████████████████████████████  | 792/824 [31:53<01:18,  2.46s/it, training_loss=0.285]
# Epoch 3:  96%|████████████████████████████████████████████████  | 792/824 [31:56<01:18,  2.46s/it, training_loss=0.186]
# Epoch 3:  96%|████████████████████████████████████████████████  | 793/824 [31:56<01:16,  2.47s/it, training_loss=0.186]
# Epoch 3:  96%|████████████████████████████████████████████████  | 793/824 [31:58<01:16,  2.47s/it, training_loss=0.046]
# Epoch 3:  96%|████████████████████████████████████████████████▏ | 794/824 [31:58<01:13,  2.46s/it, training_loss=0.046]
# Epoch 3:  96%|████████████████████████████████████████████████▏ | 794/824 [32:00<01:13,  2.46s/it, training_loss=0.003]
# Epoch 3:  96%|████████████████████████████████████████████████▏ | 795/824 [32:00<01:11,  2.46s/it, training_loss=0.003]
# Epoch 3:  96%|████████████████████████████████████████████████▏ | 795/824 [32:03<01:11,  2.46s/it, training_loss=0.001]
# Epoch 3:  97%|████████████████████████████████████████████████▎ | 796/824 [32:03<01:08,  2.45s/it, training_loss=0.001]
# Epoch 3:  97%|████████████████████████████████████████████████▎ | 796/824 [32:05<01:08,  2.45s/it, training_loss=0.013]
# Epoch 3:  97%|████████████████████████████████████████████████▎ | 797/824 [32:05<01:06,  2.45s/it, training_loss=0.013]
# Epoch 3:  97%|████████████████████████████████████████████████▎ | 797/824 [32:08<01:06,  2.45s/it, training_loss=0.010]
# Epoch 3:  97%|████████████████████████████████████████████████▍ | 798/824 [32:08<01:03,  2.46s/it, training_loss=0.010]
# Epoch 3:  97%|████████████████████████████████████████████████▍ | 798/824 [32:10<01:03,  2.46s/it, training_loss=0.443]
# Epoch 3:  97%|████████████████████████████████████████████████▍ | 799/824 [32:10<01:01,  2.45s/it, training_loss=0.443]
# Epoch 3:  97%|████████████████████████████████████████████████▍ | 799/824 [32:13<01:01,  2.45s/it, training_loss=0.002]
# Epoch 3:  97%|████████████████████████████████████████████████▌ | 800/824 [32:13<00:58,  2.45s/it, training_loss=0.002]
# Epoch 3:  97%|████████████████████████████████████████████████▌ | 800/824 [32:15<00:58,  2.45s/it, training_loss=0.002]
# Epoch 3:  97%|████████████████████████████████████████████████▌ | 801/824 [32:15<00:56,  2.45s/it, training_loss=0.002]
# Epoch 3:  97%|████████████████████████████████████████████████▌ | 801/824 [32:18<00:56,  2.45s/it, training_loss=0.001]
# Epoch 3:  97%|████████████████████████████████████████████████▋ | 802/824 [32:18<00:53,  2.45s/it, training_loss=0.001]
# Epoch 3:  97%|████████████████████████████████████████████████▋ | 802/824 [32:20<00:53,  2.45s/it, training_loss=0.001]
# Epoch 3:  97%|████████████████████████████████████████████████▋ | 803/824 [32:20<00:51,  2.45s/it, training_loss=0.001]
# Epoch 3:  97%|████████████████████████████████████████████████▋ | 803/824 [32:23<00:51,  2.45s/it, training_loss=0.001]
# Epoch 3:  98%|████████████████████████████████████████████████▊ | 804/824 [32:23<00:49,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|████████████████████████████████████████████████▊ | 804/824 [32:25<00:49,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|████████████████████████████████████████████████▊ | 805/824 [32:25<00:46,  2.45s/it, training_loss=0.001]
# Epoch 3:  98%|████████████████████████████████████████████████▊ | 805/824 [32:27<00:46,  2.45s/it, training_loss=0.002]
# Epoch 3:  98%|████████████████████████████████████████████████▉ | 806/824 [32:27<00:44,  2.46s/it, training_loss=0.002]
# Epoch 3:  98%|████████████████████████████████████████████████▉ | 806/824 [32:30<00:44,  2.46s/it, training_loss=0.016]
# Epoch 3:  98%|████████████████████████████████████████████████▉ | 807/824 [32:30<00:41,  2.45s/it, training_loss=0.016]
# Epoch 3:  98%|████████████████████████████████████████████████▉ | 807/824 [32:32<00:41,  2.45s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████ | 808/824 [32:32<00:39,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████ | 808/824 [32:35<00:39,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████ | 809/824 [32:35<00:36,  2.45s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████ | 809/824 [32:37<00:36,  2.45s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████▏| 810/824 [32:37<00:34,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████▏| 810/824 [32:40<00:34,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████▏| 811/824 [32:40<00:31,  2.46s/it, training_loss=0.001]
# Epoch 3:  98%|█████████████████████████████████████████████████▏| 811/824 [32:42<00:31,  2.46s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▎| 812/824 [32:42<00:29,  2.47s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▎| 812/824 [32:45<00:29,  2.47s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▎| 813/824 [32:45<00:27,  2.45s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▎| 813/824 [32:47<00:27,  2.45s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▍| 814/824 [32:47<00:24,  2.45s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▍| 814/824 [32:50<00:24,  2.45s/it, training_loss=0.189]
# Epoch 3:  99%|█████████████████████████████████████████████████▍| 815/824 [32:50<00:22,  2.45s/it, training_loss=0.189]
# Epoch 3:  99%|█████████████████████████████████████████████████▍| 815/824 [32:52<00:22,  2.45s/it, training_loss=0.017]
# Epoch 3:  99%|█████████████████████████████████████████████████▌| 816/824 [32:52<00:19,  2.45s/it, training_loss=0.017]
# Epoch 3:  99%|█████████████████████████████████████████████████▌| 816/824 [32:54<00:19,  2.45s/it, training_loss=0.406]
# Epoch 3:  99%|█████████████████████████████████████████████████▌| 817/824 [32:54<00:17,  2.46s/it, training_loss=0.406]
# Epoch 3:  99%|█████████████████████████████████████████████████▌| 817/824 [32:57<00:17,  2.46s/it, training_loss=0.000]
# Epoch 3:  99%|█████████████████████████████████████████████████▋| 818/824 [32:57<00:14,  2.45s/it, training_loss=0.000]
# Epoch 3:  99%|█████████████████████████████████████████████████▋| 818/824 [32:59<00:14,  2.45s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▋| 819/824 [32:59<00:12,  2.46s/it, training_loss=0.001]
# Epoch 3:  99%|█████████████████████████████████████████████████▋| 819/824 [33:02<00:12,  2.46s/it, training_loss=0.001]
# Epoch 3: 100%|█████████████████████████████████████████████████▊| 820/824 [33:02<00:09,  2.46s/it, training_loss=0.001]
# Epoch 3: 100%|█████████████████████████████████████████████████▊| 820/824 [33:04<00:09,  2.46s/it, training_loss=0.116]
# Epoch 3: 100%|█████████████████████████████████████████████████▊| 821/824 [33:04<00:07,  2.46s/it, training_loss=0.116]
# Epoch 3: 100%|█████████████████████████████████████████████████▊| 821/824 [33:07<00:07,  2.46s/it, training_loss=0.001]
# Epoch 3: 100%|█████████████████████████████████████████████████▉| 822/824 [33:07<00:04,  2.45s/it, training_loss=0.001]
# Epoch 3: 100%|█████████████████████████████████████████████████▉| 822/824 [33:09<00:04,  2.45s/it, training_loss=0.295]
# Epoch 3: 100%|█████████████████████████████████████████████████▉| 823/824 [33:09<00:02,  2.46s/it, training_loss=0.295]
# Epoch 3: 100%|█████████████████████████████████████████████████▉| 823/824 [33:11<00:02,  2.46s/it, training_loss=0.001]
# Epoch 3: 100%|██████████████████████████████████████████████████| 824/824 [33:11<00:00,  2.24s/it, training_loss=0.001]
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:45:23<36:10, 2170.65s/it]
# Epoch 3
# Training loss: 0.14498883653239988
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:47:12<00:00, 2144.19s/it]
# Validation loss: 0.46312193814999975
# F1 Score (Weighted): 0.8912643716032562

# %%
# Load the best model & Make Predictions

model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('finetuned_finBERT_epoch_1.model', 
                                 map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)

accuracy_per_class(predictions, true_vals)
# Out:
# Class: neutral
# Accuracy: 393/432
#
# Class: negative
# Accuracy: 75/91
#
# Class: positive
# Accuracy: 171/204

# %%
# 데이터 불러오기
financial_data = pd.read_csv("./financial_phrase_bank_pt_br.csv/financial_phrase_bank_pt_br.csv", 
                             encoding='utf-8', skiprows=1,
                             names=['sentiment', 'NewsHeadline', 'drop'])
financial_data.drop('drop', axis=1, inplace=True)

def get_headlines_len(df):
    
    headlines_sequence_lengths = []
    
    print("Encoding in progress...")
    for headline in tqdm(df.NewsHeadline):
        encoded_headline = finbert_tokenizer.encode(headline, 
                                         add_special_tokens = True)
        
        # record the length of the encoded review
        headlines_sequence_lengths.append(len(encoded_headline))
    print("End of Task.")
    
    return headlines_sequence_lengths


def encode_sentiments_values(df):
    
    possible_sentiments = df.sentiment.unique()
    sentiment_dict = {}
    
    for index, possible_sentiment in enumerate(possible_sentiments):
        sentiment_dict[possible_sentiment] = index
    
    # Encode all the sentiment values
    df['label'] = df.sentiment.replace(sentiment_dict)
    
    return df, sentiment_dict
 
# Perform the encoding task on the data set
# label값 지정 newtral = 0, negative, = 1, positive
financial_data, sentiment_dict = encode_sentiments_values(financial_data)

# Create training and validation data
# train, test 나누기
X_train, X_val, y_train, y_val = train_test_split(financial_data.index.values, 
                                                  financial_data.label.values, 
                                                  test_size = 0.15, 
                                                  random_state = 2022, 
                                                  stratify = financial_data.label.values)


# Create the data type columns
financial_data.loc[X_train, 'data_type'] = 'train'
financial_data.loc[X_val, 'data_type'] = 'val'


# Get the FinBERT Tokenizer
finbert_tokenizer = BertTokenizer.from_pretrained("ProsusAI/finbert", do_lower_case=True)

# 파이터치지옥
# Encode the Training and Validation Data
encoded_data_train = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='train'].NewsHeadline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)

encoded_data_val = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='val'].NewsHeadline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(financial_data[financial_data.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
sentiments_val = torch.tensor(financial_data[financial_data.data_type=='val'].label.values)


dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, sentiments_val)


model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)

headlines_sequence_lengths = get_headlines_len(financial_data)

batch_size = 5
dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)


optimizer = AdamW(model.parameters(),lr=1e-5, eps=1e-8)

epochs = 3
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)


def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in sentiment_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')
        

seed_val = 2022
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)


def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_finBERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')

# %%
# Vizualiez the number of sentiment occurence on each type of data
# financial_data.groupby(['sentiment', 'label', 'data_type']).count()

# %%
# Load the best model & Make Predictions

model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('finetuned_finBERT_epoch_1.model', 
                                 map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)

accuracy_per_class(predictions, true_vals)

# %%
financial_data = pd.read_csv("./stock_data/dataset_Text_Rank/철강_지수.csv", index_col=0)
