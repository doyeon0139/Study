# %%
import pandas as pd
import numpy as np
import os

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/')
files
# Out:
# ['000040.csv',
#  '000050.csv',
#  '000080.csv',
#  '000100.csv',
#  '000120.csv',
#  '000150.csv',
#  '000180.csv',
#  '000210.csv',
#  '000230.csv',
#  '000240.csv',
#  '000270.csv',
#  '000300.csv',
#  '000320.csv',
#  '000390.csv',
#  '000430.csv',
#  '000480.csv',
#  '000490.csv',
#  '000500.csv',
#  '000520.csv',
#  '000590.csv',
#  '000640.csv',
#  '000660.csv',
#  '000670.csv',
#  '000680.csv',
#  '000700.csv',
#  '000720.csv',
#  '000850.csv',
#  '000860.csv',
#  '000880.csv',
#  '000890.csv',
#  '000910.csv',
#  '000950.csv',
#  '000990.csv',
#  '001020.csv',
#  '001040.csv',
#  '001060.csv',
#  '001070.csv',
#  '001120.csv',
#  '001130.csv',
#  '001210.csv',
#  '001230.csv',
#  '001250.csv',
#  '001260.csv',
#  '001380.csv',
#  '001390.csv',
#  '001430.csv',
#  '001440.csv',
#  '001460.csv',
#  '001470.csv',
#  '001520.csv',
#  '001530.csv',
#  '001560.csv',
#  '001570.csv',
#  '001620.csv',
#  '001630.csv',
#  '001740.csv',
#  '001780.csv',
#  '001790.csv',
# ...

# %%
df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/000120.csv', index_col=0)
df
# Out:
#             date      시가      고가      저가      종가     거래량         거래대금   등락률  \
# 0     2016-01-04  189000  190500  185000  185000   31606   5883434000 -3.14
# 1     2016-01-05  185000  201000  183500  200000  101763  19640862000  8.11
# 2     2016-01-06  200500  209000  200500  204500   63583  12996296500  2.25
# 3     2016-01-07  203500  203500  196500  197500   52582  10483729000 -3.42
# 4     2016-01-08  199500  202000  195000  201500   35066   7002846500  2.03
# ...          ...     ...     ...     ...     ...     ...          ...   ...
# 1529  2022-03-25  132000  132000  127000  127500   58671   7559389000 -3.41
# 1530  2022-03-28  127000  130500  126000  130000   27455   3540703500  1.96
# 1531  2022-03-29  131000  131500  129000  130500   33944   4414571000  0.38
# 1532  2022-03-30  131500  131500  130500  131000   22188   2901850500  0.38
# 1533  2022-03-31  131500  132000  128000  129500   38131   4930677500 -1.15
#
# ...

# %%
df.isna().sum().sum()
# Out:
# 368

# %%
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/{file}', index_col=0)
    nan = df.isna().sum().sum()
    print(file[:7]+' : '+str(nan))
# Out:
# 000040. : 0
# 000050. : 368
# 000080. : 0
# 000100. : 1534
# 000120. : 368
# 000150. : 0
# 000180. : 368
# 000210. : 736
# 000230. : 736
# 000240. : 736
# 000270. : 1717
# 000300. : 0
# 000320. : 368
# 000390. : 0
# 000430. : 368
# 000480. : 368
# 000490. : 0
# 000500. : 736
# 000520. : 368
# 000590. : 736
# 000640. : 428
# 000660. : 368
# 000670. : 368
# 000680. : 0
# 000700. : 0
# 000720. : 736
# 000850. : 0
# 000860. : 368
# 000880. : 736
# 000890. : 0
# 000910. : 368
# 000950. : 0
# 000990. : 0
# 001020. : 0
# 001040. : 0
# 001060. : 368
# 001070. : 368
# 001120. : 368
# 001130. : 368
# 001210. : 0
# 001230. : 0
# 001250. : 368
# 001260. : 736
# 001380. : 368
# 001390. : 368
# 001430. : 368
# 001440. : 736
# 001460. : 0
# 001470. : 0
# 001520. : 0
# 001530. : 368
# 001560. : 736
# 001570. : 368
# 001620. : 368
# 001630. : 736
# 001740. : 736
# 001780. : 368
# 001790. : 60
# 001800. : 0
# 001820. : 736
# 001940. : 0
# 002020. : 0
# 002030. : 0
# 002070. : 368
# 002100. : 368
# ...

# %%
ya_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/102460.csv', index_col=0)
ya_df.isna().sum()
# Out:
# date            0
# 시가              0
# 고가              0
# 저가              0
# 종가              0
# 거래량             0
# 거래대금            0
# 등락률             0
# 종목명             0
# 시가총액            0
# 상장주식수           0
# 수정종가            0
# BPS             0
# PER             0
# PBR             0
# EPS             0
# DIV             0
# DPS             0
# month           0
# quarter         0
# 유동자산          368
# 비유동자산         368
# 자산총계          368
# 유동부채          368
# 비유동부채         368
# 부채총계          368
# 이익잉여금         432
# 자본총계          368
# 매출액           368
# 영업이익          368
# 법인세차감전 순이익    368
# 당기순이익         368
# 자본금           432
# dtype: int64

# %%
ya_df
# Out:
#             date     시가     고가     저가     종가     거래량        거래대금   등락률  \
# 0     2016-01-04  38900  39150  37050  37450   69107  2637699100 -1.19
# 1     2016-01-05  36200  38200  36200  38000   61569  2288818150  1.47
# 2     2016-01-06  38300  39400  37550  39400  112540  4362017350  3.68
# 3     2016-01-07  39400  39850  37700  38300   57219  2203780350 -2.79
# 4     2016-01-08  37000  39550  36400  39150   95534  3638190950  2.22
# ...          ...    ...    ...    ...    ...     ...         ...   ...
# 1529  2022-03-25  29550  30300  29050  29750   70835  2105697100  1.19
# 1530  2022-03-28  30100  30250  29000  29000   54983  1610502550 -2.52
# 1531  2022-03-29  29050  29300  28850  29050   26124   758794550  0.17
# 1532  2022-03-30  29200  31200  29200  29500  201472  6095947350  1.55
# 1533  2022-03-31  29500  30550  29500  29900   92703  2793363750  1.36
#
#          종목명          시가총액  ...          유동부채         비유동부채          부채총계  \
# ...

# %%
ya_df[360:400]
# Out:
#            date     시가     고가     저가     종가    거래량       거래대금   등락률     종목명  \
# 360  2017-06-21  30400  30400  29700  29700   7032  209636000 -2.14  102460
# 361  2017-06-22  29750  30150  29650  29900  12234  365886000  0.67  102460
# 362  2017-06-23  30250  30250  29550  29550  11545  343778900 -1.17  102460
# 363  2017-06-26  29950  29950  28800  28900  10663  309965300 -2.20  102460
# 364  2017-06-27  28900  29400  28500  28800   9682  279073300 -0.35  102460
# 365  2017-06-28  28550  28950  28400  28500   9756  278414200 -1.04  102460
# 366  2017-06-29  28600  28950  28500  28900   4817  138396250  1.40  102460
# 367  2017-06-30  28900  28950  28600  28750   5240  150590300 -0.52  102460
# 368  2017-07-03  28550  28650  28350  28550   6372  181748500 -0.70  102460
# 369  2017-07-04  28300  28750  28300  28400   5213  148813750 -0.53  102460
# 370  2017-07-05  28200  28600  28200  28200   7171  203231200 -0.70  102460
# ...

# %%
len(files)
# Out:
# 511

# %% [markdown]
# # 511리스트 만들기

# %%
stock_codes = []
for file in files:
    stock_codes.append(file[:6])
stock_codes
# Out:
# ['000040',
#  '000050',
#  '000080',
#  '000100',
#  '000120',
#  '000150',
#  '000180',
#  '000210',
#  '000230',
#  '000240',
#  '000270',
#  '000300',
#  '000320',
#  '000390',
#  '000430',
#  '000480',
#  '000490',
#  '000500',
#  '000520',
#  '000590',
#  '000640',
#  '000660',
#  '000670',
#  '000680',
#  '000700',
#  '000720',
#  '000850',
#  '000860',
#  '000880',
#  '000890',
#  '000910',
#  '000950',
#  '000990',
#  '001020',
#  '001040',
#  '001060',
#  '001070',
#  '001120',
#  '001130',
#  '001210',
#  '001230',
#  '001250',
#  '001260',
#  '001380',
#  '001390',
#  '001430',
#  '001440',
#  '001460',
#  '001470',
#  '001520',
#  '001530',
#  '001560',
#  '001570',
#  '001620',
#  '001630',
#  '001740',
#  '001780',
#  '001790',
#  '001800',
#  '001820',
#  '001940',
#  '002020',
#  '002030',
#  '002070',
#  '002100',
#  '002140',
#  '002150',
#  '002170',
#  '002200',
#  '002220',
#  '002240',
#  '002310',
#  '002320',
#  '002350',
#  '002390',
#  '002410',
# ...

# %%
df = pd.DataFrame({'stock_code':stock_codes})
df
# Out:
#     stock_code
# 0       000040
# 1       000050
# 2       000080
# 3       000100
# 4       000120
# ..         ...
# 506     214330
# 507     214420
# 508     226320
# 509     227840
# 510     900140
#
# [511 rows x 1 columns]

# %%
df.to_csv('c:/Users/bitcamp/Desktop/final_data/DB_list_stock_code.csv')

# %% [markdown]
# # 재무비율 삭제

# %%
stock_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/000040.csv', index_col=0)
stock_df.head(2)
# Out:
#          date    시가    고가    저가    종가      거래량         거래대금   등락률  종목명  \
# 0  2016-01-04  1295  1325  1255  1305  6053163   7839874495  2.76   40
# 1  2016-01-05  1285  1350  1280  1310  9674168  12787405175  0.38   40
#
#            시가총액  ...          유동부채         비유동부채          부채총계         이익잉여금  \
# 0  228776632020  ...  6.620836e+10  1.466770e+10  8.087606e+10 -3.186228e+10
# 1  229653170840  ...  6.620836e+10  1.466770e+10  8.087606e+10 -3.186228e+10
#
#            자본총계           매출액          영업이익    법인세차감전 순이익         당기순이익  \
# 0  6.502035e+10  1.979041e+10 -2.729799e+09 -3.476061e+09 -3.476061e+09
# 1  6.502035e+10  1.979041e+10 -2.729799e+09 -3.476061e+09 -3.476061e+09
#
#             자본금
# 0  8.765388e+10
# 1  8.765388e+10
#
# [2 rows x 33 columns]

# %%
stock_df.columns
# Out:
# Index(['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
stock_df.drop(['BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month'], axis=1, inplace=True)

# %%
stock_df.columns
# Out:
# Index(['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채',
#        '부채총계', '이익잉여금', '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/')

# %%
for file in files:
    stock_df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/{file}', index_col=0)
    stock_df.drop(['BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month'], axis=1, inplace=True)
    stock_df.to_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/{file}')

# %% [markdown]
# # nan값 확인

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/')

# %%
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/{file}', index_col=0)
    nan = df.isna().sum().sum()
    print(file[:7]+' : '+str(nan))
# Out:
# 000040. : 0
# 000050. : 368
# 000080. : 0
# 000100. : 1534
# 000120. : 368
# 000150. : 0
# 000180. : 368
# 000210. : 736
# 000230. : 736
# 000240. : 736
# 000270. : 1717
# 000300. : 0
# 000320. : 368
# 000390. : 0
# 000430. : 368
# 000480. : 368
# 000490. : 0
# 000500. : 736
# 000520. : 368
# 000590. : 736
# 000640. : 428
# 000660. : 368
# 000670. : 368
# 000680. : 0
# 000700. : 0
# 000720. : 736
# 000850. : 0
# 000860. : 368
# 000880. : 736
# 000890. : 0
# 000910. : 368
# 000950. : 0
# 000990. : 0
# 001020. : 0
# 001040. : 0
# 001060. : 368
# 001070. : 368
# 001120. : 368
# 001130. : 368
# 001210. : 0
# 001230. : 0
# 001250. : 368
# 001260. : 736
# 001380. : 368
# 001390. : 368
# 001430. : 368
# 001440. : 736
# 001460. : 0
# 001470. : 0
# 001520. : 0
# 001530. : 368
# 001560. : 736
# 001570. : 368
# 001620. : 368
# 001630. : 736
# 001740. : 736
# 001780. : 368
# 001790. : 60
# 001800. : 0
# 001820. : 736
# 001940. : 0
# 002020. : 0
# 002030. : 0
# 002070. : 368
# 002100. : 368
# ...

# %%
stock_nan_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/000270.csv', index_col=0)
stock_nan_df.head(2)
# Out:
#          date     시가     고가     저가     종가      거래량         거래대금   등락률  종목명  \
# 0  2016-01-04  51700  51800  50600  50800  1016680  51802223300 -3.42  270
# 1  2016-01-05  50100  51300  50000  50700   989919  50189461600 -0.20  270
#
#              시가총액  ...          유동부채         비유동부채          부채총계  이익잉여금  \
# 0  20592458027600  ...  1.636467e+13  7.321833e+12  2.368650e+13    NaN
# 1  20551921692900  ...  1.636467e+13  7.321833e+12  2.368650e+13    NaN
#
#            자본총계           매출액          영업이익    법인세차감전 순이익         당기순이익  자본금
# 0  2.459700e+13  1.264937e+13  6.336220e+11  1.046704e+12  9.445840e+11  NaN
# 1  2.459700e+13  1.264937e+13  6.336220e+11  1.046704e+12  9.445840e+11  NaN
#
# [2 rows x 26 columns]

# %%
stock_nan_df.isna().sum()
# Out:
# date             0
# 시가               0
# 고가               0
# 저가               0
# 종가               0
# 거래량              0
# 거래대금             0
# 등락률              0
# 종목명              0
# 시가총액             0
# 상장주식수            0
# 수정종가             0
# quarter          0
# 유동자산             0
# 비유동자산            0
# 자산총계             0
# 유동부채             0
# 비유동부채            0
# 부채총계             0
# 이익잉여금          183
# 자본총계             0
# 매출액              0
# 영업이익             0
# 법인세차감전 순이익       0
# 당기순이익            0
# 자본금           1534
# dtype: int64

# %% [markdown]
# # 전체 nan값 확인

# %%
stock_nan_df[-1:].isna().sum().sum()
# Out:
# 1

# %%
for file in files:
    stock_nan_df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/{file}', index_col=0)
    if stock_nan_df[-1:].isna().sum().sum() > 0:
        print(file[:6]+' : '+str(stock_nan_df[-1:].isna().sum().sum()))
# Out:
# 000100 : 1
# 000270 : 1
# 002390 : 1
# 008500 : 1
# 014280 : 1
# 025000 : 1
# 085310 : 1
# 204320 : 2

# %% [markdown]
# # nan값 이유 확인

# %%
yabal_df = pd.read_excel('c:/Users/bitcamp/Desktop/final_data/재무제표/000270.xlsx')
yabal_df.iloc[46,28:33]
# Out:
# 20170331    23794398000000
# 20161231    23465759000000
# 20160930    22837121000000
# 20160630    22194359000000
# 20160331    21447074000000
# Name: 46, dtype: object

# %%
nan_li = []
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/{file}', index_col=0)
    nan = df.isna().sum().sum()
    if nan > 368:
        print(file[:7]+' : '+str(nan))
        nan_li.append(nan)
# Out:
# 000100. : 1534
# 000210. : 736
# 000230. : 736
# 000240. : 736
# 000270. : 1717
# 000500. : 736
# 000590. : 736
# 000640. : 428
# 000720. : 736
# 000880. : 736
# 001260. : 736
# 001440. : 736
# 001560. : 736
# 001630. : 736
# 001740. : 736
# 001820. : 736
# 002150. : 4784
# 002200. : 736
# 002240. : 736
# 002310. : 736
# 002390. : 1534
# 002620. : 2564
# 002710. : 736
# 002900. : 796
# 003030. : 736
# 003090. : 736
# 003160. : 736
# 003550. : 736
# 003560. : 736
# 003620. : 736
# 003670. : 736
# 003720. : 736
# 003850. : 3442
# 003920. : 736
# 004020. : 736
# 004170. : 736
# 004250. : 736
# 004720. : 736
# 004840. : 550
# 005320. : 796
# 005380. : 736
# 005430. : 736
# 005490. : 736
# 005610. : 736
# 005810. : 736
# 005960. : 736
# 006040. : 736
# 006060. : 736
# 006260. : 864
# 006360. : 736
# 006490. : 736
# 006650. : 736
# 006840. : 736
# 007070. : 736
# 007120. : 489
# 007160. : 736
# 007460. : 5616
# 007810. : 736
# 007860. : 736
# 008490. : 736
# 008500. : 1534
# 008930. : 616
# ...

# %%
len(nan_li)
# Out:
# 176

# %%
stock_nan_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/014680.csv', index_col=0)
stock_nan_df
# Out:
#             date      시가      고가      저가      종가     거래량         거래대금   등락률  \
# 0     2016-01-04   62200   63100   59100   59200   59486   3591797600 -4.67
# 1     2016-01-05   58000   59800   58000   59000   66616   3924365100 -0.34
# 2     2016-01-06   59600   64500   58900   64000   96302   5889894200  8.47
# 3     2016-01-07   64000   67500   63400   66600   96462   6374877700  4.06
# 4     2016-01-08   66600   67500   64900   65300   57553   3771771800 -1.95
# ...          ...     ...     ...     ...     ...     ...          ...   ...
# 1529  2022-03-25  230500  236500  228500  235000   92699  21686115000  3.30
# 1530  2022-03-28  235000  236000  229000  233000   52734  12307466500 -0.85
# 1531  2022-03-29  236000  238500  230000  232500   53985  12641681000 -0.21
# 1532  2022-03-30  235500  238500  233000  236000   51695  12172162500  1.51
# 1533  2022-03-31  235500  248000  234000  245500  100316  24410413500  4.03
#
# ...

# %%
stock_nan_df.isna().sum()
# Out:
# date            0
# 시가              0
# 고가              0
# 저가              0
# 종가              0
# 거래량             0
# 거래대금            0
# 등락률             0
# 종목명             0
# 시가총액            0
# 상장주식수           0
# 수정종가            0
# quarter         0
# 유동자산            0
# 비유동자산           0
# 자산총계            0
# 유동부채            0
# 비유동부채           0
# 부채총계            0
# 이익잉여금         368
# 자본총계            0
# 매출액             0
# 영업이익            0
# 법인세차감전 순이익      0
# 당기순이익           0
# 자본금           368
# dtype: int64

# %%
stock_nan_df[stock_nan_df['이익잉여금'].isna()]
# Out:
#            date     시가     고가     저가     종가    거래량        거래대금   등락률    종목명  \
# 0    2016-01-04  62200  63100  59100  59200  59486  3591797600 -4.67  14680
# 1    2016-01-05  58000  59800  58000  59000  66616  3924365100 -0.34  14680
# 2    2016-01-06  59600  64500  58900  64000  96302  5889894200  8.47  14680
# 3    2016-01-07  64000  67500  63400  66600  96462  6374877700  4.06  14680
# 4    2016-01-08  66600  67500  64900  65300  57553  3771771800 -1.95  14680
# ..          ...    ...    ...    ...    ...    ...         ...   ...    ...
# 363  2017-06-26  74000  74000  72100  73000  57682  4196600600 -1.48  14680
# 364  2017-06-27  72500  73600  71800  72200  45901  3319916200 -1.10  14680
# 365  2017-06-28  72300  72300  71000  71400  70265  5021771500 -1.11  14680
# 366  2017-06-29  71600  72000  70400  70400  65016  4593747100 -1.40  14680
# 367  2017-06-30  70100  71600  69800  71000  55902  3948915700  0.85  14680
#
# ...

# %%
stock_nan_df[stock_nan_df.date < '2016-03-31']['이익잉여금'] = 159835687858
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_14324/3441506112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_nan_df[stock_nan_df.date < '2016-03-31']['이익잉여금'] = 159835687858

# %%
yabal_df = pd.read_excel('c:/Users/bitcamp/Desktop/final_data/재무제표/014680.xlsx')
yabal_df.iloc[48,10:33]
# Out:
# 20210930    577006535013
# 20210630    534366670606
# 20210331    492072368606
# 20201231    470804267514
# 20200930    459232563718
# 20200630    419313066173
# 20200331    389740520207
# 20191231    371778414280
# 20190930    362183376639
# 20190630    336036268610
# 20190331    312005659718
# 20181231    302700808712
# 20180930    291847372207
# 20180630    268859624847
# 20180331    244365115672
# 20171231    236752514695
# 20170930    234195995596
# 20170630    212093063883
# 20170331    199024092967
# 20161231    194613240826
# 20160930    187837781218
# 20160630    170235244070
# 20160331    159835687858
# Name: 48, dtype: object

# %%
yabal_df = pd.read_excel('c:/Users/bitcamp/Desktop/final_data/재무제표/000270.xlsx')
yabal_df.iloc[46,28:33]

# %% [markdown]
# # 자본금+이익잉여금 버리기

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/')

# %%
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/{file}', index_col=0)
    df.drop(['자본금', '이익잉여금'], axis=1, inplace=True)
    df.to_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x/{file}')

# %%
nan_li = []
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x/{file}', index_col=0)
    nan = df.isna().sum().sum()
    if nan > 0:
        print(file[:7]+' : '+str(nan))
        nan_li.append(file)
# Out:
# 001790. : 60
# 002150. : 4048
# 002620. : 2013
# 002900. : 60
# 003850. : 2706
# 005320. : 60
# 007460. : 4752
# 011330. : 4752
# 011930. : 2013
# 044380. : 2013
# 071090. : 4752
# 077970. : 2013
# 089590. : 2013
# 101530. : 432
# 102460. : 4048
# 109070. : 2013
# 185750. : 4752
# 192080. : 660
# 194370. : 444
# 227840. : 2013

# %%
len(nan_li)
# Out:
# 20

# %%
stock_nan_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x/007460.csv', index_col=0)
stock_nan_df
# Out:
#             date    시가    고가    저가    종가      거래량        거래대금   등락률   종목명  \
# 0     2016-01-04  3070  3070  2920  2970    49703   148217520 -1.98  7460
# 1     2016-01-05  2885  2990  2870  2945    59743   175017315 -0.84  7460
# 2     2016-01-06  2920  3015  2840  2950    59020   170458285  0.17  7460
# 3     2016-01-07  2945  2945  2770  2825    73170   207136015 -4.24  7460
# 4     2016-01-08  2765  2875  2670  2820    70402   192218755 -0.18  7460
# ...          ...   ...   ...   ...   ...      ...         ...   ...   ...
# 1529  2022-03-25  1500  1525  1475  1485  1741663  2601229815 -1.00  7460
# 1530  2022-03-28  1450  1510  1450  1475  1888395  2797439965 -0.67  7460
# 1531  2022-03-29  1490  1500  1465  1480  1182915  1747407465  0.34  7460
# 1532  2022-03-30  1480  1505  1475  1495   888910  1325511695  1.01  7460
# 1533  2022-03-31  1490  1530  1485  1525   978595  1473205275  2.01  7460
#
#               시가총액  ...         비유동자산          자산총계          유동부채  \
# ...

# %% [markdown]
# # 490개^^

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x_20drop/')
for na in nan_li:
    os.remove(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x_20drop/{na}')

# %%
nan_li
# Out:
# ['001790.csv',
#  '002150.csv',
#  '002620.csv',
#  '002900.csv',
#  '003850.csv',
#  '005320.csv',
#  '007460.csv',
#  '011330.csv',
#  '011930.csv',
#  '044380.csv',
#  '071090.csv',
#  '077970.csv',
#  '089590.csv',
#  '101530.csv',
#  '102460.csv',
#  '109070.csv',
#  '185750.csv',
#  '192080.csv',
#  '194370.csv',
#  '227840.csv']

# %% [markdown]
# # last nan값 확인

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x_20drop/')
nan_li = []
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x/{file}', index_col=0)
    nan = df.isna().sum().sum()
    if nan > 0:
        print(file[:7]+' : '+str(nan))
        nan_li.append(file)

# %%
nan_zero = []
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/')
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511/{file}', index_col=0)
    if df.isna().sum().sum() == 0:
        df.to_csv(f'c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x_20drop/{file}')
        print(file[:7])
        nan_zero.append(file)
# Out:
# 000040.
# 000080.
# 000150.
# 000300.
# 000390.
# 000490.
# 000680.
# 000700.
# 000850.
# 000890.
# 000950.
# 000990.
# 001020.
# 001040.
# 001210.
# 001230.
# 001460.
# 001470.
# 001520.
# 001800.
# 001940.
# 002020.
# 002030.
# 002140.
# 002170.
# 002220.
# 002320.
# 002840.
# 003000.
# 003200.
# 003220.
# 003300.
# 003410.
# 003480.
# 003490.
# 003570.
# 003780.
# 003960.
# 004090.
# 004100.
# 004270.
# 004540.
# 004710.
# 004770.
# 004800.
# 004830.
# 004870.
# 004890.
# 004910.
# 004960.
# 004970.
# 004980.
# 005010.
# 005090.
# 005440.
# 005720.
# 005740.
# 005820.
# 006120.
# 006340.
# 006400.
# 006570.
# 006880.
# 007210.
# 007310.
# 007340.
# 007540.
# 007610.
# 007660.
# 007700.
# 007980.
# 008040.
# 009200.
# 009540.
# 009580.
# 009810.
# 009970.
# 010060.
# 010100.
# 010600.
# 010780.
# 011090.
# 011230.
# 011690.
# 011760.
# 011780.
# 011790.
# 012160.
# 012170.
# 012600.
# 012630.
# 013360.
# 013570.
# 013580.
# 013870.
# 014130.
# 014440.
# 014530.
# 014580.
# 014830.
# ...

# %%
len(nan_zero)
# Out:
# 167

# %%
df_nan_zero = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/머신러닝_재무데이터/종목별_511_자본금_이익잉여금_x_20drop/000040.csv', index_col=0)

# %%
df_nan_zero.isna().sum()
# Out:
# date          0
# 시가            0
# 고가            0
# 저가            0
# 종가            0
# 거래량           0
# 거래대금          0
# 등락률           0
# 종목명           0
# 시가총액          0
# 상장주식수         0
# 수정종가          0
# quarter       0
# 유동자산          0
# 비유동자산         0
# 자산총계          0
# 유동부채          0
# 비유동부채         0
# 부채총계          0
# 이익잉여금         0
# 자본총계          0
# 매출액           0
# 영업이익          0
# 법인세차감전 순이익    0
# 당기순이익         0
# 자본금           0
# dtype: int64
