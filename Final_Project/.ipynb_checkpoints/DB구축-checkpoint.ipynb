# %%
import pandas as pd
import numpy as np
import os

# %%
import OpenDartReader

api_key = '9ca2f170725d735b634acb1e71338844eaf45a5e'
dart = OpenDartReader(api_key)

# %%
df1 = dart.finstate(corp='140910', bsns_year=2016, reprt_code=11013)

# %%
df1
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div fs_nm  \
# 0   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 1   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 2   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 3   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 4   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 5   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 6   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 7   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 8   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 9   20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 10  20160516001941      11013      2016  00860730     140910    OFS  재무제표
# 11  20160516001941      11013      2016  00860730     140910    OFS  재무제표
# ...

# %%
df_nan = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/kospi재무데이터/제무제표_2/140910.csv', index_col=0)

# %%
df_nan.isna().sum().sum()
# Out:
# 300

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/미치겠다/재무데이터/')

# %%
sibal_li = []

for file in files:
    df_nan = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/미치겠다/재무데이터/{file}', index_col=0)
    if df_nan.isna().sum().sum() < 100:
        sibal_li.append(file[:6])
        print(file+' : '+str(df_nan.isna().sum().sum()))
# Out:
# 000040.csv : 24
# 000050.csv : 6
# 000080.csv : 0
# 000100.csv : 19
# 000120.csv : 6
# 000150.csv : 0
# 000180.csv : 6
# 000210.csv : 12
# 000230.csv : 12
# 000240.csv : 14
# 000270.csv : 5
# 000300.csv : 10
# 000320.csv : 6
# 000390.csv : 0
# 000430.csv : 10
# 000480.csv : 6
# 000490.csv : 0
# 000500.csv : 16
# 000520.csv : 6
# 000590.csv : 12
# 000640.csv : 7
# 000660.csv : 6
# 000670.csv : 6
# 000680.csv : 3
# 000700.csv : 13
# 000720.csv : 12
# 000850.csv : 0
# 000860.csv : 6
# 000880.csv : 12
# 000890.csv : 0
# 000910.csv : 30
# 000950.csv : 0
# 000990.csv : 0
# 001020.csv : 0
# 001040.csv : 0
# 001060.csv : 14
# 001070.csv : 11
# 001120.csv : 7
# 001130.csv : 6
# 001210.csv : 0
# 001230.csv : 0
# 001250.csv : 6
# 001260.csv : 12
# 001380.csv : 6
# 001390.csv : 7
# 001430.csv : 8
# 001440.csv : 12
# 001460.csv : 0
# 001470.csv : 0
# 001520.csv : 0
# 001530.csv : 6
# 001560.csv : 12
# 001570.csv : 6
# 001620.csv : 6
# 001630.csv : 12
# 001740.csv : 12
# 001780.csv : 6
# ...

# %%
df1 = dart.finstate(corp='035510', bsns_year=2016, reprt_code=11012)
df1
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div fs_nm  \
# 0   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 1   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 2   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 3   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 4   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 5   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 6   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 7   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 8   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 9   20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 10  20160816002027      11012      2016  00219486     035510    OFS  재무제표
# 11  20160816002027      11012      2016  00219486     035510    OFS  재무제표
# ...

# %%
df1 = df1[df1['fs_nm'] == '연결재무제표']
df_1 = df1[['account_nm','sj_div','thstrm_amount']]
df_1
# Out:
# Empty DataFrame
# Columns: [account_nm, sj_div, thstrm_amount]
# Index: []

# %%
len(sibal_li)
# Out:
# 511

# %%
sibal_li
# Out:
# ['000040',
#  '000050',
#  '000080',
#  '000100',
#  '000120',
#  '000150',
#  '000180',
#  '000210',
#  '000230',
#  '000240',
#  '000270',
#  '000300',
#  '000320',
#  '000390',
#  '000430',
#  '000480',
#  '000490',
#  '000500',
#  '000520',
#  '000590',
#  '000640',
#  '000660',
#  '000670',
#  '000680',
#  '000700',
#  '000720',
#  '000850',
#  '000860',
#  '000880',
#  '000890',
#  '000910',
#  '000950',
#  '000990',
#  '001020',
#  '001040',
#  '001060',
#  '001070',
#  '001120',
#  '001130',
#  '001210',
#  '001230',
#  '001250',
#  '001260',
#  '001380',
#  '001390',
#  '001430',
#  '001440',
#  '001460',
#  '001470',
#  '001520',
#  '001530',
#  '001560',
#  '001570',
#  '001620',
#  '001630',
#  '001740',
#  '001780',
#  '001790',
#  '001800',
#  '001820',
#  '001940',
#  '002020',
#  '002030',
#  '002070',
#  '002100',
#  '002140',
#  '002150',
#  '002170',
#  '002200',
#  '002220',
#  '002240',
#  '002310',
#  '002320',
#  '002350',
#  '002390',
#  '002410',
# ...

# %%
fs_nm = list(df1['fs_nm'].values)

# %%
fs_nm in '재무제표'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14348/2420299170.py in <module>
# ----> 1 fs_nm in '재무제표'
#
# TypeError: 'in <string>' requires string as left operand, not list

# %%
pd.read_csv('c:/Users/bitcamp/Desktop/final_data/미치겠다/재무데이터/001360.csv')
# Out:
#         Unnamed: 0 account_nm       2016-1       2016-2       2016-3  \
# 0                0       유동자산  64706486916  48954474798  80013950181
# 1                1       유동자산  64706486916  48954474798  80013950181
# 2                2       유동자산  64706486916  48954474798  80013950181
# 3                3       유동자산  64706486916  48954474798  80013950181
# 4                4       유동자산  64706486916  48954474798  80013950181
# ...            ...        ...          ...          ...          ...
# 393211      393211        자본금  14341913000  15356785000  19856785000
# 393212      393212        자본금  14341913000  15356785000  19856785000
# 393213      393213        자본금  14341913000  15356785000  19856785000
# 393214      393214        자본금  14341913000  15356785000  19856785000
# 393215      393215        자본금  14341913000  15356785000  19856785000
#
#              2016-4       2017-1       2017-2       2017-3       2017-4  ...  \
# ...

# %%
import shutil

# %%
for file in sibal_li:
    shutil.copy(f'c:/Users/bitcamp/Desktop/final_data/미치겠다/재무데이터/{file}.csv', f'c:/Users/bitcamp/Desktop/final_data/미치겠다/재무데이터_511/{file}.csv')

# %% [markdown]
# # 컬럼맞추기

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/')

# %%
files
# Out:
# ['000040.csv',
#  '000050.csv',
#  '000080.csv',
#  '000100.csv',
#  '000120.csv',
#  '000150.csv',
#  '000180.csv',
#  '000210.csv',
#  '000230.csv',
#  '000240.csv',
#  '000270.csv',
#  '000300.csv',
#  '000320.csv',
#  '000390.csv',
#  '000430.csv',
#  '000480.csv',
#  '000490.csv',
#  '000500.csv',
#  '000520.csv',
#  '000590.csv',
#  '000640.csv',
#  '000660.csv',
#  '000670.csv',
#  '000680.csv',
#  '000700.csv',
#  '000720.csv',
#  '000850.csv',
#  '000860.csv',
#  '000880.csv',
#  '000890.csv',
#  '000910.csv',
#  '000950.csv',
#  '000990.csv',
#  '001020.csv',
#  '001040.csv',
#  '001060.csv',
#  '001070.csv',
#  '001120.csv',
#  '001130.csv',
#  '001210.csv',
#  '001230.csv',
#  '001250.csv',
#  '001260.csv',
#  '001380.csv',
#  '001390.csv',
#  '001430.csv',
#  '001440.csv',
#  '001460.csv',
#  '001470.csv',
#  '001520.csv',
#  '001530.csv',
#  '001560.csv',
#  '001570.csv',
#  '001620.csv',
#  '001630.csv',
#  '001740.csv',
#  '001780.csv',
#  '001790.csv',
# ...

# %%
jebal_li = []
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/{file}')
    if len(df.columns) != 34:
        jebal_li.append(file)
        print(file+' : '+str(len(df.columns)))
# Out:
# 000100.csv : 33
# 000270.csv : 33
# 002390.csv : 33
# 008500.csv : 33
# 014280.csv : 33
# 085310.csv : 33
# 155900.csv : 28
# 204320.csv : 33
# 900140.csv : 28

# %%
df_005930 = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/005930.csv')
df_005930.columns
# Out:
# Index(['Unnamed: 0', 'date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률',
#        '종목명', '시가총액', '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV',
#        'DPS', 'month', 'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채',
#        '부채총계', '이익잉여금', '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
len(jebal_li)
# Out:
# 9

# %%
df_000100 = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/900140.csv')
df_000100.columns
# Out:
# Index(['Unnamed: 0', 'date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률',
#        '종목명', '시가총액', '상장주식수', '수정종가', 'month', 'quarter', '유동자산', '비유동자산',
#        '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금', '자본총계', '매출액', '영업이익',
#        '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
jebal_li
# Out:
# ['000100.csv',
#  '000270.csv',
#  '002390.csv',
#  '008500.csv',
#  '014280.csv',
#  '085310.csv',
#  '155900.csv',
#  '204320.csv',
#  '900140.csv']

# %%
df_000100['자본금'] = np.nan

# %%
df_000100
# Out:
#       Unnamed: 0        date      시가      고가      저가      종가     거래량  \
# 0              0  2016-01-04  276000  282500  271500  272000   59355
# 1              1  2016-01-05  270500  278000  270000  273500   36400
# 2              2  2016-01-06  274000  281500  272000  281000   68150
# 3              3  2016-01-07  281500  293000  281500  293000   57358
# 4              4  2016-01-08  290000  304000  286500  304000   58165
# ...          ...         ...     ...     ...     ...     ...     ...
# 1529        1529  2022-03-25   58500   59100   58300   58900  118649
# 1530        1530  2022-03-28   58800   59200   58400   59100  119838
# 1531        1531  2022-03-29   59300   59500   58800   58900  111248
# 1532        1532  2022-03-30   59000   59300   58600   59000  118236
# 1533        1533  2022-03-31   59000   59400   58300   58400  187687
#
#              거래대금   등락률  종목명  ...          유동부채         비유동부채          부채총계  \
# ...

# %%
# 자본금 추가
for je in jebal_li[:]:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/{je}', index_col=0)
    df['자본금'] = np.nan
    df.to_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/{je}')

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/')
jebal_li = []
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/{file}')
    if len(df.columns) != 34:
        jebal_li.append(file)
        print(file+' : '+str(len(df.columns)))
# Out:
# 155900.csv : 28
# 900140.csv : 28

# %%
df_900140 = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/900140.csv')
df_900140.columns
# Out:
# Index(['Unnamed: 0', 'date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률',
#        '종목명', '시가총액', '상장주식수', '수정종가', 'month', 'quarter', '유동자산', '비유동자산',
#        '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금', '자본총계', '매출액', '영업이익',
#        '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
len(df_900140.columns)  # 'BPS', 'PER', 'PBR', 'EPS', 'DIV','DPS'
# Out:
# 28

# %%
# 'BPS', 'PER', 'PBR', 'EPS', 'DIV','DPS' 추가
for je in jebal_li[:]:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511/{je}', index_col=0)
    df['BPS'] = np.nan
    df['PER'] = np.nan
    df['PBR'] = np.nan
    df['EPS'] = np.nan
    df['DIV'] = np.nan
    df['DPS'] = np.nan
    df.to_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/{je}')

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/')
jebal_li = []
for file in files:
    df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/{file}')
    if len(df.columns) != 34:
        jebal_li.append(file)
        print(file+' : '+str(len(df.columns)))

# %%
len(jebal_li)
# Out:
# 0

# %%
df = pd.read_csv('C:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/005930.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 33

# %%
df.head(2)
# Out:
#          date       시가       고가       저가       종가     거래량          거래대금   등락률  \
# 0  2016-01-04  1260000  1260000  1205000  1205000  306939  375331217000 -4.37
# 1  2016-01-05  1202000  1218000  1186000  1208000  216002  260737452839  0.25
#
#     종목명             시가총액  ...          유동부채         비유동부채          부채총계  \
# 0  5930  177495701085000  ...  4.904950e+13  1.386410e+13  6.291360e+13
# 1  5930  177937599096000  ...  4.904950e+13  1.386410e+13  6.291360e+13
#
#           이익잉여금          자본총계           매출액          영업이익    법인세차감전 순이익  \
# 0  1.832186e+14  1.783262e+14  4.978225e+13  6.675812e+12  7.122485e+12
# 1  1.832186e+14  1.783262e+14  4.978225e+13  6.675812e+12  7.122485e+12
#
#           당기순이익 자본금
# 0  5.252803e+12 NaN
# 1  5.252803e+12 NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# # 컬럼이름 바꾸기

# %%
stock_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/005930.csv', index_col=0)
stock_df.head(2)
# Out:
#          date       시가       고가       저가       종가     거래량          거래대금   등락률  \
# 0  2016-01-04  1260000  1260000  1205000  1205000  306939  375331217000 -4.37
# 1  2016-01-05  1202000  1218000  1186000  1208000  216002  260737452839  0.25
#
#     종목명             시가총액  ...          유동부채         비유동부채          부채총계  \
# 0  5930  177495701085000  ...  4.904950e+13  1.386410e+13  6.291360e+13
# 1  5930  177937599096000  ...  4.904950e+13  1.386410e+13  6.291360e+13
#
#           이익잉여금          자본총계           매출액          영업이익    법인세차감전 순이익  \
# 0  1.832186e+14  1.783262e+14  4.978225e+13  6.675812e+12  7.122485e+12
# 1  1.832186e+14  1.783262e+14  4.978225e+13  6.675812e+12  7.122485e+12
#
#           당기순이익 자본금
# 0  5.252803e+12 NaN
# 1  5.252803e+12 NaN
#
# [2 rows x 33 columns]

# %%
stock_df.columns
# Out:
# Index(['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
test_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_수정/155900.csv', index_col=0)
test_df.head(2)
# Out:
#          date    시가    고가    저가    종가   거래량     거래대금   등락률     종목명  \
# 0  2016-01-04  2810  2810  2790  2800  3317  9288020 -2.61  155900
# 1  2016-01-05  2800  2800  2790  2790   226   630770 -0.36  155900
#
#           시가총액  ...         영업이익   법인세차감전 순이익        당기순이익           자본금  BPS  \
# 0  42560011200  ...  591200277.0  329090033.0  329090033.0  7.600002e+10  NaN
# 1  42408011160  ...  591200277.0  329090033.0  329090033.0  7.600002e+10  NaN
#
#    PER  PBR  EPS DIV  DPS
# 0  NaN  NaN  NaN NaN  NaN
# 1  NaN  NaN  NaN NaN  NaN
#
# [2 rows x 33 columns]

# %%
test_df = test_df[['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
       '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
       'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
       '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금']]
test_df.head(2)
# Out:
#          date    시가    고가    저가    종가   거래량     거래대금   등락률     종목명  \
# 0  2016-01-04  2810  2810  2790  2800  3317  9288020 -2.61  155900
# 1  2016-01-05  2800  2800  2790  2790   226   630770 -0.36  155900
#
#           시가총액  ...          유동부채         비유동부채          부채총계  이익잉여금  \
# 0  42560011200  ...  1.120676e+09  2314816099.0  3.435492e+09    NaN
# 1  42408011160  ...  1.120676e+09  2314816099.0  3.435492e+09    NaN
#
#            자본총계           매출액         영업이익   법인세차감전 순이익        당기순이익  \
# 0  3.737060e+10  2.966331e+09  591200277.0  329090033.0  329090033.0
# 1  3.737060e+10  2.966331e+09  591200277.0  329090033.0  329090033.0
#
#             자본금
# 0  7.600002e+10
# 1  7.600002e+10
#
# [2 rows x 33 columns]

# %%
files = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/')

# %%
len(files)
# Out:
# 511

# %%
for file in files:
    col_df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/{file}')
    col_df = col_df[['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
       '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
       'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
       '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금']]
    col_df.to_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/{file}')

# %% [markdown]
# # 드디어 DB

# %%
import MySQLdb

db = MySQLdb.connect(host='localhost', port=3306, user='root', passwd = '1234')
cursor = db.cursor()

# %%
sql = 'show databases;'
pd.read_sql(sql, db)
# Out:
#               Database
# 0   information_schema
# 1            budongsan
# 2              chatbot
# 3            employees
# 4             falsk_db
# 5               fin_db
# 6                mysql
# 7   performance_schema
# 8               sakila
# 9               shopdb
# 10               sqlab
# 11               sqldb
# 12                 sys
# 13             tabledb
# 14               world

# %%
sql = 'use chatbot;'
cursor.execute(sql)
# Out:
# 0

# %%
stock_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/000430.csv', index_col=0)

# %%
stock_df.columns
# Out:
# Index(['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금'],
#       dtype='object')

# %%
name_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/kospi_목록_코드_종목코드.csv',index_col=0)

# %%
code_files = []
for code in files:
    code_files.append(code[:6])
# code_files
# Out:
# ['000040',
#  '000050',
#  '000080',
#  '000100',
#  '000120',
#  '000150',
#  '000180',
#  '000210',
#  '000230',
#  '000240',
#  '000270',
#  '000300',
#  '000320',
#  '000390',
#  '000430',
#  '000480',
#  '000490',
#  '000500',
#  '000520',
#  '000590',
#  '000640',
#  '000660',
#  '000670',
#  '000680',
#  '000700',
#  '000720',
#  '000850',
#  '000860',
#  '000880',
#  '000890',
#  '000910',
#  '000950',
#  '000990',
#  '001020',
#  '001040',
#  '001060',
#  '001070',
#  '001120',
#  '001130',
#  '001210',
#  '001230',
#  '001250',
#  '001260',
#  '001380',
#  '001390',
#  '001430',
#  '001440',
#  '001460',
#  '001470',
#  '001520',
#  '001530',
#  '001560',
#  '001570',
#  '001620',
#  '001630',
#  '001740',
#  '001780',
#  '001790',
#  '001800',
#  '001820',
#  '001940',
#  '002020',
#  '002030',
#  '002070',
#  '002100',
#  '002140',
#  '002150',
#  '002170',
#  '002200',
#  '002220',
#  '002240',
#  '002310',
#  '002320',
#  '002350',
#  '002390',
#  '002410',
# ...

# %%
name_df['stock_code'] = name_df['stock_code'].apply(lambda x:str(x).zfill(6))

# %%
name_df.head(2)
# Out:
#    corp_code corp_name stock_code
# 0     960641     한국패러랠     168490
# 1     600013    맵스리얼티1     094800

# %%
str(name_df[name_df['stock_code'] == '011150']['corp_name'].values)[2:-2]
# Out:
# 'CJ씨푸드'

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1534 non-null   object
#  1   시가          1534 non-null   int64
#  2   고가          1534 non-null   int64
#  3   저가          1534 non-null   int64
#  4   종가          1534 non-null   int64
#  5   거래량         1534 non-null   int64
#  6   거래대금        1534 non-null   int64
#  7   등락률         1534 non-null   float64
#  8   종목명         1534 non-null   int64
#  9   시가총액        1534 non-null   int64
#  10  상장주식수       1534 non-null   int64
#  11  수정종가        1534 non-null   int64
#  12  BPS         1534 non-null   int64
#  13  PER         1534 non-null   float64
#  14  PBR         1534 non-null   float64
#  15  EPS         1534 non-null   int64
#  16  DIV         1534 non-null   float64
#  17  DPS         1534 non-null   int64
#  18  month       1534 non-null   object
# ...

# %%
sql = """
create table test_4(
code char(6),
name char(10),
날짜 date,
시가 varchar(50),
고가 varchar(50),
저가 varchar(50),
종가 varchar(50),
거래량 varchar(50),
거래대금 varchar(50),
등락률 varchar(50),
시가총액 varchar(50),
상장주식수 varchar(50),
수정종가 varchar(50),
BPS varchar(50),
PER varchar(50),
PBR varchar(50),
EPS varchar(50),
DIV_ varchar(50),
DPS varchar(50),
quarter char(10),
유동자산 varchar(50),
비유동자산 varchar(50),
자산총계 varchar(50),
유동부채 varchar(50),
비유동부채 varchar(50),
부채총계 varchar(50),
이익잉여금 varchar(50),
자본총계 varchar(50),
매출액 varchar(50),
영업이익 varchar(50),
법인세차감전_순이익 varchar(50),
당기순이익 varchar(50),
자본금 varchar(50)
)
"""

cursor.execute(sql)
# Out:
# 0

# %%
# ['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금']

code = '000430'

for i in range(len(stock_df)):
    
    code = code
    name = str(name_df[name_df['stock_code'] == code]['corp_name'].values)[2:-2]
    date = stock_df.iloc[i,0]
    시가 = stock_df.iloc[i,1]
    고가 = stock_df.iloc[i,2]
    저가 = stock_df.iloc[i,3]
    종가 = stock_df.iloc[i,4]
    거래량 = stock_df.iloc[i,5]
    거래대금 = stock_df.iloc[i,6]
    등락률 = stock_df.iloc[i,7]
    시가총액 = stock_df.iloc[i,9]
    상장주식수 = stock_df.iloc[i,10]
    수정종가 = stock_df.iloc[i,11]
    BPS = stock_df.iloc[i,12]
    PER = stock_df.iloc[i,13]
    PBR = stock_df.iloc[i,14]
    EPS = stock_df.iloc[i,15]
    DIV = stock_df.iloc[i,16]
    DPS = stock_df.iloc[i,17]
    quarter = stock_df.iloc[i,19]
    유동자산 = stock_df.iloc[i,20]
    비유동자산 = stock_df.iloc[i,21]
    자산총계 = stock_df.iloc[i,22]
    유동부채 = stock_df.iloc[i,23]
    비유동부채 = stock_df.iloc[i,24]
    부채총계 = stock_df.iloc[i,25]
    이익잉여금 = stock_df.iloc[i,26]
    자본총계 = stock_df.iloc[i,27]
    매출액 = stock_df.iloc[i,28]
    영업이익 = stock_df.iloc[i,29]
    법인세차감전_순이익 = stock_df.iloc[i,30]
    당기순이익 = stock_df.iloc[i,31]
    자본금 = stock_df.iloc[i,32]

    sql = """
    insert into test_4 values('{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}',
    '{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}');
    """.format(code, name, date, 시가, 고가, 저가, 종가, 거래량, 거래대금, 등락률, 시가총액, 상장주식수, 수정종가, BPS, PER, PBR,
              EPS, DIV, DPS, quarter, 유동자산, 비유동자산, 자산총계, 유동부채, 비유동부채, 부채총계, 이익잉여금, 자본총계, 매출액,
              영업이익, 법인세차감전_순이익, 당기순이익, 자본금)

    cursor.execute(sql)

# %%
stock_df.iloc[1,:]
# Out:
# date               2016-01-05
# 시가                       4860
# 고가                       4905
# 저가                       4815
# 종가                       4905
# 거래량                     19285
# 거래대금                 93599965
# 등락률                      1.76
# 종목명                       430
# 시가총액             304110000000
# 상장주식수                62000000
# 수정종가                     4905
# BPS                      6698
# PER                     24.53
# PBR                      0.73
# EPS                       200
# DIV                      2.45
# DPS                       120
# month                 2016-01
# quarter                2016-1
# 유동자산           395104951665.0
# 비유동자산          776880859889.0
# 자산총계          1171985811554.0
# 유동부채           510665993022.0
# 비유동부채          153510656685.0
# 부채총계           664176649707.0
# 이익잉여금          368427354696.0
# 자본총계           507809161847.0
# 매출액            258555762391.0
# 영업이익            12127801310.0
# 법인세차감전 순이익      10181746705.0
# ...

# %% [markdown]
# # Test

# %%
stock_df['quarter'].isna().sum()
# Out:
# 0

# %%
test_df = stock_df[:10]

# %%
test_df
# Out:
#          date    시가    고가    저가    종가    거래량       거래대금   등락률  종목명  \
# 0  2016-01-04  4855  4865  4770  4820  23672  114461375 -0.41  430
# 1  2016-01-05  4860  4905  4815  4905  19285   93599965  1.76  430
# 2  2016-01-06  4910  4910  4810  4885  14438   70523310 -0.41  430
# 3  2016-01-07  4885  4900  4655  4820   7886   37794285 -1.33  430
# 4  2016-01-08  4820  4830  4765  4815   8210   39408625 -0.10  430
# 5  2016-01-11  4850  4850  4715  4715  19714   93452170 -2.08  430
# 6  2016-01-12  4715  4745  4670  4670  11713   55092400 -0.95  430
# 7  2016-01-13  4725  4725  4650  4690   5882   27441000  0.43  430
# 8  2016-01-14  4690  4700  4645  4680   8592   40153400 -0.21  430
# 9  2016-01-15  4790  4790  4700  4720    521    2461530  0.85  430
#
#            시가총액  ...          유동부채         비유동부채          부채총계         이익잉여금  \
# 0  298840000000  ...  5.106660e+11  1.535107e+11  6.641766e+11  3.684274e+11
# ...

# %%
# ['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금']

code = '000430'

for i in range(len(test_df)):
    
    code = code
    name = str(name_df[name_df['stock_code'] == code]['corp_name'].values)[2:-2]
    date = test_df.iloc[i,0]
    시가 = test_df.iloc[i,1]
    고가 = test_df.iloc[i,2]
    저가 = test_df.iloc[i,3]
    종가 = test_df.iloc[i,4]
    거래량 = test_df.iloc[i,5]
    거래대금 = test_df.iloc[i,6]
    등락률 = test_df.iloc[i,7]
    시가총액 = test_df.iloc[i,9]
    상장주식수 = test_df.iloc[i,10]
    수정종가 = test_df.iloc[i,11]
    BPS = test_df.iloc[i,12]
    PER = test_df.iloc[i,13]
    PBR = test_df.iloc[i,14]
    EPS = test_df.iloc[i,15]
    DIV = test_df.iloc[i,16]
    DPS = test_df.iloc[i,17]
    quarter = test_df.iloc[i,19]
    유동자산 = test_df.iloc[i,20]
    비유동자산 = test_df.iloc[i,21]
    자산총계 = test_df.iloc[i,22]
    유동부채 = test_df.iloc[i,23]
    비유동부채 = test_df.iloc[i,24]
    부채총계 = test_df.iloc[i,25]
    이익잉여금 = test_df.iloc[i,26]
    자본총계 = test_df.iloc[i,27]
    매출액 = test_df.iloc[i,28]
    영업이익 = test_df.iloc[i,29]
    법인세차감전_순이익 = test_df.iloc[i,30]
    당기순이익 = test_df.iloc[i,31]
    자본금 = test_df.iloc[i,32]

    sql = """
    insert into test_2 values('{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}',
    '{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}');
    """.format(code, name, date, 시가, 고가, 저가, 종가, 거래량, 거래대금, 등락률, 시가총액, 상장주식수, 수정종가, BPS, PER, PBR,
              EPS, DIV, DPS, quarter, 유동자산, 비유동자산, 자산총계, 유동부채, 비유동부채, 부채총계, 이익잉여금, 자본총계, 매출액,
              영업이익, 법인세차감전_순이익, 당기순이익, 자본금)

    cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14348/3791452742.py in <module>
#      49               영업이익, 법인세차감전_순이익, 당기순이익, 자본금)
#      50
# ---> 51     cursor.execute(sql)
#
# ~\Anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# ~\Anaconda3\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# ~\Anaconda3\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     252         if isinstance(query, bytearray):
#     253             query = bytes(query)
# ...

# %%
sql = 'select * from test_4;'

stock = pd.read_sql(sql, db)
stock
# Out:
#         code  name          날짜    시가    고가    저가    종가    거래량       거래대금  \
# 0     000430  대원강업  2016-01-04  4855  4865  4770  4820  23672  114461375
# 1     000430  대원강업  2016-01-05  4860  4905  4815  4905  19285   93599965
# 2     000430  대원강업  2016-01-06  4910  4910  4810  4885  14438   70523310
# 3     000430  대원강업  2016-01-07  4885  4900  4655  4820   7886   37794285
# 4     000430  대원강업  2016-01-08  4820  4830  4765  4815   8210   39408625
# ...      ...   ...         ...   ...   ...   ...   ...    ...        ...
# 1529  000430  대원강업  2022-03-25  3195  3210  3155  3175  40634  128924745
# 1530  000430  대원강업  2022-03-28  3175  3180  3145  3160  26961   85138030
# 1531  000430  대원강업  2022-03-29  3160  3200  3155  3190  29078   92452775
# 1532  000430  대원강업  2022-03-30  3190  3275  3190  3215  85766  276060615
# 1533  000430  대원강업  2022-03-31  3210  3235  3200  3205  34090  109608580
#
#         등락률  ...            유동부채           비유동부채            부채총계  \
# ...

# %%
stock
# Out:
# Index(['code', 'name'], dtype='object')

# %%
sql = """
create table yayabal(
code char(6),
name char(10)
)
"""

cursor.execute(sql)
# Out:
# 0

# %%
code = '005930'
name = np.nan

sql = """ insert into yayabal values('{}', '{}');
""".format(code, name)
cursor.execute(sql)
# Out:
# 1

# %%
sql = 'select * from yayabal;'

stock = pd.read_sql(sql, db)
stock
# Out:
#      code  name
# 0  005930  삼성전자
# 1  005930   nan

# %% [markdown]
# # 이번엔 제발 진짜 DB

# %%
files_li = os.listdir('c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/')
# files_li

# %%
name_df = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/kospi_목록_코드_종목코드.csv', index_col=0)
name_df['stock_code'] = name_df['stock_code'].apply(lambda x:str(x).zfill(6))
# name_df

# %%
sql = """
create table if not exists stock_table(
code char(6),
name char(10),
날짜 date,
시가 varchar(50),
고가 varchar(50),
저가 varchar(50),
종가 varchar(50),
거래량 varchar(50),
거래대금 varchar(50),
등락률 varchar(50),
시가총액 varchar(50),
상장주식수 varchar(50),
수정종가 varchar(50),
BPS varchar(50),
PER varchar(50),
PBR varchar(50),
EPS varchar(50),
DIV_ varchar(50),
DPS varchar(50),
quarter char(10),
유동자산 varchar(50),
비유동자산 varchar(50),
자산총계 varchar(50),
유동부채 varchar(50),
비유동부채 varchar(50),
부채총계 varchar(50),
이익잉여금 varchar(50),
자본총계 varchar(50),
매출액 varchar(50),
영업이익 varchar(50),
법인세차감전_순이익 varchar(50),
당기순이익 varchar(50),
자본금 varchar(50)
)
"""

cursor.execute(sql)
# Out:
# 0

# %%
# ['date', '시가', '고가', '저가', '종가', '거래량', '거래대금', '등락률', '종목명', '시가총액',
#        '상장주식수', '수정종가', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS', 'month',
#        'quarter', '유동자산', '비유동자산', '자산총계', '유동부채', '비유동부채', '부채총계', '이익잉여금',
#        '자본총계', '매출액', '영업이익', '법인세차감전 순이익', '당기순이익', '자본금']
ok_li = []

for file in files_li:
#     print(file[:6])
    stock_df = pd.read_csv(f'c:/Users/bitcamp/Desktop/final_data/DB/재무+주가_511_last/{file}', index_col=0)
    code = file[:6]

    for i in range(len(stock_df)):

        code = code
        name = str(name_df[name_df['stock_code'] == code]['corp_name'].values)[2:-2]
        date = stock_df.iloc[i,0]
        시가 = stock_df.iloc[i,1]
        고가 = stock_df.iloc[i,2]
        저가 = stock_df.iloc[i,3]
        종가 = stock_df.iloc[i,4]
        거래량 = stock_df.iloc[i,5]
        거래대금 = stock_df.iloc[i,6]
        등락률 = stock_df.iloc[i,7]
        시가총액 = stock_df.iloc[i,9]
        상장주식수 = stock_df.iloc[i,10]
        수정종가 = stock_df.iloc[i,11]
        BPS = stock_df.iloc[i,12]
        PER = stock_df.iloc[i,13]
        PBR = stock_df.iloc[i,14]
        EPS = stock_df.iloc[i,15]
        DIV = stock_df.iloc[i,16]
        DPS = stock_df.iloc[i,17]
        quarter = stock_df.iloc[i,19]
        유동자산 = stock_df.iloc[i,20]
        비유동자산 = stock_df.iloc[i,21]
        자산총계 = stock_df.iloc[i,22]
        유동부채 = stock_df.iloc[i,23]
        비유동부채 = stock_df.iloc[i,24]
        부채총계 = stock_df.iloc[i,25]
        이익잉여금 = stock_df.iloc[i,26]
        자본총계 = stock_df.iloc[i,27]
        매출액 = stock_df.iloc[i,28]
        영업이익 = stock_df.iloc[i,29]
        법인세차감전_순이익 = stock_df.iloc[i,30]
        당기순이익 = stock_df.iloc[i,31]
        자본금 = stock_df.iloc[i,32]

        sql = """
        insert into stock_table values('{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}',
        '{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}');
        """.format(code, name, date, 시가, 고가, 저가, 종가, 거래량, 거래대금, 등락률, 시가총액, 상장주식수, 수정종가, BPS, PER, PBR,
                  EPS, DIV, DPS, quarter, 유동자산, 비유동자산, 자산총계, 유동부채, 비유동부채, 부채총계, 이익잉여금, 자본총계, 매출액,
                  영업이익, 법인세차감전_순이익, 당기순이익, 자본금)

        cursor.execute(sql)
    print(file)
    ok_li.append(code)
# Out:
# 000040.csv
# 000050.csv
# 000080.csv
# 000100.csv
# 000120.csv
# 000150.csv
# 000180.csv
# 000210.csv
# 000230.csv
# 000240.csv
# 000270.csv
# 000300.csv
# 000320.csv
# 000390.csv
# 000430.csv
# 000480.csv
# 000490.csv
# 000500.csv
# 000520.csv
# 000590.csv
# 000640.csv
# 000660.csv
# 000670.csv
# 000680.csv
# 000700.csv
# 000720.csv
# 000850.csv
# 000860.csv
# 000880.csv
# 000890.csv
# 000910.csv
# 000950.csv
# 000990.csv
# 001020.csv
# 001040.csv
# 001060.csv
# 001070.csv
# 001120.csv
# 001130.csv
# 001210.csv
# 001230.csv
# 001250.csv
# 001260.csv
# 001380.csv
# 001390.csv
# 001430.csv
# 001440.csv
# 001460.csv
# 001470.csv
# 001520.csv
# 001530.csv
# 001560.csv
# 001570.csv
# 001620.csv
# 001630.csv
# 001740.csv
# 001780.csv
# 001790.csv
# 001800.csv
# 001820.csv
# 001940.csv
# 002020.csv
# 002030.csv
# 002070.csv
# 002100.csv
# 002140.csv
# 002150.csv
# 002170.csv
# 002200.csv
# 002220.csv
# 002240.csv
# 002310.csv
# 002320.csv
# 002350.csv
# 002390.csv
# 002410.csv
# ...

# %%
db.commit()

# %%
sql = 'select * from stock_table;'

stock = pd.read_sql(sql, db)
stock
# Out:
#           code   name          날짜     시가     고가     저가     종가      거래량  \
# 0       000040  KR모터스  2016-01-04   1295   1325   1255   1305  6053163
# 1       000040  KR모터스  2016-01-05   1285   1350   1280   1310  9674168
# 2       000040  KR모터스  2016-01-06   1320   1325   1205   1260  5368790
# 3       000040  KR모터스  2016-01-07   1265   1280   1210   1230  2538804
# 4       000040  KR모터스  2016-01-08   1200   1255   1155   1235  2977602
# ...        ...    ...         ...    ...    ...    ...    ...      ...
# 751572  161000  애경케미칼  2022-03-25  10650  10750  10400  10500   121781
# 751573  161000  애경케미칼  2022-03-28  10500  10550  10350  10400   143039
# 751574  161000  애경케미칼  2022-03-29  10500  10650  10450  10600   114618
# 751575  161000  애경케미칼  2022-03-30  10700  10700  10400  10400   121660
# 751576  161000  애경케미칼  2022-03-31  10400  10600  10350  10500    94771
#
#                거래대금    등락률  ...            유동부채          비유동부채  \
# ...

# %%
stock[stock['자본금'] == 'nan']
# Out:
#           code   name          날짜      시가      고가      저가      종가     거래량  \
# 1534    000050     경방  2016-01-04  187500  191000  180000  180000    3307
# 1535    000050     경방  2016-01-05  180000  186500  175500  182500    1004
# 1536    000050     경방  2016-01-06  178000  186500  177000  185500    1167
# 1537    000050     경방  2016-01-07  189500  189500  182500  184500     543
# 1538    000050     경방  2016-01-08  197000  197000  181500  188500     901
# ...        ...    ...         ...     ...     ...     ...     ...     ...
# 750406  161000  애경케미칼  2017-06-26   16100   16500   15850   16050  205688
# 750407  161000  애경케미칼  2017-06-27   16250   16250   15850   16000  112397
# 750408  161000  애경케미칼  2017-06-28   15900   16300   15700   15800  156749
# 750409  161000  애경케미칼  2017-06-29   15900   16100   15650   15700  128107
# 750410  161000  애경케미칼  2017-06-30   15650   15900   15500   15700  114550
#
#               거래대금    등락률  ...            유동부채           비유동부채  \
# ...

# %% [markdown]
# # 에이 왜그래 장난치지마

# %%
import MySQLdb

db = MySQLdb.connect(host='localhost', port=3306, user='root', passwd = '1234')
cursor = db.cursor()

# %%
sql = 'show databases;'
pd.read_sql(sql, db)
# Out:
#               Database
# 0   information_schema
# 1            budongsan
# 2              chatbot
# 3            employees
# 4             falsk_db
# 5               fin_db
# 6                mysql
# 7   performance_schema
# 8               sakila
# 9               shopdb
# 10               sqlab
# 11               sqldb
# 12                 sys
# 13             tabledb
# 14               world

# %%
sql = 'use chatbot;'
cursor.execute(sql)
# Out:
# 0

# %%
sql = 'select * from stock_table;'

stock = pd.read_sql(sql, db)
stock
# Out:
#           code   name          날짜     시가     고가     저가     종가      거래량  \
# 0       000040  KR모터스  2016-01-04   1295   1325   1255   1305  6053163
# 1       000040  KR모터스  2016-01-05   1285   1350   1280   1310  9674168
# 2       000040  KR모터스  2016-01-06   1320   1325   1205   1260  5368790
# 3       000040  KR모터스  2016-01-07   1265   1280   1210   1230  2538804
# 4       000040  KR모터스  2016-01-08   1200   1255   1155   1235  2977602
# ...        ...    ...         ...    ...    ...    ...    ...      ...
# 751572  161000  애경케미칼  2022-03-25  10650  10750  10400  10500   121781
# 751573  161000  애경케미칼  2022-03-28  10500  10550  10350  10400   143039
# 751574  161000  애경케미칼  2022-03-29  10500  10650  10450  10600   114618
# 751575  161000  애경케미칼  2022-03-30  10700  10700  10400  10400   121660
# 751576  161000  애경케미칼  2022-03-31  10400  10600  10350  10500    94771
#
#                거래대금    등락률  ...            유동부채          비유동부채  \
# ...

# %%
stock[stock.code == '000390']
# Out:
#          code     name          날짜     시가     고가     저가     종가      거래량  \
# 19942  000390  삼화페인트공업  2016-01-04  12700  12750  12100  12100    65461
# 19943  000390  삼화페인트공업  2016-01-05  12150  12450  12050  12300    74484
# 19944  000390  삼화페인트공업  2016-01-06  12350  12500  11800  12200    84893
# 19945  000390  삼화페인트공업  2016-01-07  12100  12250  11650  11650   112240
# 19946  000390  삼화페인트공업  2016-01-08  11450  12050  11400  12000    67575
# ...       ...      ...         ...    ...    ...    ...    ...      ...
# 21471  000390  삼화페인트공업  2022-03-25   9920  10000   9800   9860    50305
# 21472  000390  삼화페인트공업  2022-03-28   9940  10400   9940  10050   151502
# 21473  000390  삼화페인트공업  2022-03-29  10150  11600  10050  10900  2361089
# 21474  000390  삼화페인트공업  2022-03-30  11000  11050  10450  10550   467081
# 21475  000390  삼화페인트공업  2022-03-31  10550  10800  10400  10750   157516
#
#               거래대금    등락률  ...          유동부채         비유동부채          부채총계  \
# ...
