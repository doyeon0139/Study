# %%
import pandas as pd
import numpy as np
import os
import datetime as dt

# %%
df = pd.read_excel('c:/Users/bitcamp/Desktop/final_data/재무제표/134790.xlsx', index_col=0)
df
# Out:
#      [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)  \
# NaN                                          concept_id
# NaN                                                 NaN
# 0.0                                  ifrs_CurrentAssets
# 1.0                         ifrs_CashAndCashEquivalents
# 2.0   entity00852087_udf_BS_201232720144687_CurrentA...
# 3.0                ifrs_TradeAndOtherCurrentReceivables
# 4.0   entity00852087_udf_BS_2012327201436281_Current...
# 5.0   entity00852087_udf_BS_2012327201642390_Current...
# 6.0                    ifrs_OtherCurrentFinancialAssets
# 7.0                               ifrs_CurrentTaxAssets
# 8.0                                    ifrs_Inventories
# 9.0                               ifrs_NoncurrentAssets
# 10.0  entity00852087_udf_BS_201232720207546_Noncurre...
# 11.0                ifrs_OtherNoncurrentFinancialAssets
# 12.0                     ifrs_PropertyPlantAndEquipment
# ...

# %%
df.columns[df.apply(lambda x : x.iloc[0] == "('연결재무제표',)")][0][:4]=='2022'
# Out:
# False

# %%
file_li = os.listdir('c:/Users/bitcamp/Desktop/final_data/재무제표')
# file_li

# %%
file_li = os.listdir('c:/Users/bitcamp/Desktop/final_data/재무제표')
x_list = []

for file in file_li:
    
    df = pd.read_excel(f'c:/Users/bitcamp/Desktop/final_data/재무제표/{file}', index_col=0)
    if df.columns[df.apply(lambda x : x.iloc[0] == "('연결재무제표',)")][0][:4] != '2022':
        x_list.append(file)
        print(file)
    else:
        pass
len(x_list)
# Out:
# 000140.xlsx
# 000760.xlsx
# 001080.xlsx
# 001290.xlsx
# 001360.xlsx
# 002210.xlsx
# 002700.xlsx
# 002780.xlsx
# 002880.xlsx
# 003680.xlsx
# 004310.xlsx
# 004410.xlsx
# 004700.xlsx
# 005680.xlsx
# 005690.xlsx
# 006390.xlsx
# 007110.xlsx
# 007120.xlsx
# 009190.xlsx
# 009770.xlsx
# 010820.xlsx
# 011420.xlsx
# 012280.xlsx
# 014710.xlsx
# 015020.xlsx
# 015260.xlsx
# 015590.xlsx
# 019490.xlsx
# 024090.xlsx
# 033270.xlsx
# 034830.xlsx
# 067830.xlsx
# 069460.xlsx
# 071840.xlsx
# 134790.xlsx
# 267850.xlsx
# 298690.xlsx
# 900140.xlsx
# 38

# %%
pd.read_excel(f'c:/Users/bitcamp/Desktop/final_data/재무제표/{x_list[10]}', index_col=0)
# Out:
#      [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)  \
# NaN                                          concept_id
# NaN                                                 NaN
# 0.0                                  ifrs_CurrentAssets
# 1.0                         ifrs_CashAndCashEquivalents
# 2.0   dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 3.0   ifrs_CurrentFinancialAssetsAtFairValueThroughP...
# 4.0         dart_CurrentAvailableForSaleFinancialAssets
# 5.0                ifrs_TradeAndOtherCurrentReceivables
# 6.0                    ifrs_OtherCurrentFinancialAssets
# 7.0                                    ifrs_Inventories
# 8.0                               ifrs_CurrentTaxAssets
# 9.0   ifrs_NoncurrentAssetsOrDisposalGroupsClassifie...
# 10.0                              ifrs_NoncurrentAssets
# 11.0  dart_LongTermDepositsNotClassifiedAsCashEquiva...
# 12.0  ifrs_NoncurrentFinancialAssetsAtFairValueThrou...
# ...

# %%
x_list[10]
# Out:
# '024090.xlsx'

# %%
pd.read_xml()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11672/594022647.py in <module>
# ----> 1 pd.read_xml
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'read_xml'

# %%
pd.__version__
# Out:
# '1.2.5'

# %%
# !pip install upgrade pandas
# Out:
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade
# WARNING: There was an error checking the latest version of pip.

# %%
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

co = Options()
co.add_experimental_option('debuggerAddress', '127.0.0.1:9222')
driver = webdriver.Chrome(options=co)
driver.get('https://www.instagram.com/')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11672/3099954207.py in <module>
#       7 co = Options()
#       8 co.add_experimental_option('debuggerAddress', '127.0.0.1:9222')
# ----> 9 driver = webdriver.Chrome(options=co)
#      10 driver.get('https://www.instagram.com/')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# ...

# %%
pd.read_excel('c:/Users/bitcamp/Desktop/final_data/000150.xlsx', index_col=0).head(50)
# Out:
#      Statement of financial position(Unit: KWR)     Unnamed: 2  \
# NaN                                    label_ko        comment
# NaN                                         NaN            NaN
# 0.0                                          자산            NaN
# 1.0                                      Ⅰ.유동자산            NaN
# 2.0                                  1.현금및현금성자산      4,5,10,35
# 3.0                                    2.단기금융상품      4,5,10,33
# 4.0                                    3.단기투자증권      4,6,10,33
# 5.0                                      4.매출채권   4,7,10,33,34
# 6.0                                      5.기타채권      4,7,10,34
# 7.0                                     6.미청구공사           4,25
# 8.0                                  7.파생상품평가자산         4,9,10
# 9.0                                    8.확정계약자산              9
# 10.0                                     9.재고자산           8,33
# 11.0                                  10.매각예정자산             38
# ...

# %%
pd.read_excel('c:/Users/bitcamp/Desktop/final_data/DeepSearch-KB금융_IFRS_연결_분기_누적-20220526-171522.xlsx', sheet_name=2, index_col=0).head(50)
# Out:
#                 symbol entity_name type_id report_id  account_id  \
# date
# 2012-06-30  KRX:105560        KB금융       B        F1        1010
# 2012-06-30  KRX:105560        KB금융       B        F1        1020
# 2012-06-30  KRX:105560        KB금융       B        F1        1029
# 2012-06-30  KRX:105560        KB금융       B        F1        1110
# 2012-06-30  KRX:105560        KB금융       B        F1        1120
# 2012-06-30  KRX:105560        KB금융       B        F1        1170
# 2012-06-30  KRX:105560        KB금융       B        F1        1240
# 2012-06-30  KRX:105560        KB금융       B        F1        1250
# 2012-06-30  KRX:105560        KB금융       B        F1        1370
# 2012-06-30  KRX:105560        KB금융       B        F1        1380
# 2012-06-30  KRX:105560        KB금융       B        F1        1420
# 2012-06-30  KRX:105560        KB금융       B        F1        1425
# 2012-06-30  KRX:105560        KB금융       B        F1        1460
# ...

# %%
pd.read_csv('c:/Users/bitcamp/Desktop/final_data/temp.csv', index_col=0, encoding='euc-kr')
# Out:
#             2010/06 2010/09 2010/12  2011/03  2011/06  2011/09  2011/12  \
# 주가(원)        31,500  35,000  44,650   41,900   36,100   34,500   36,350
# 매출액(억원)       8,866   6,503   6,213    3,708    7,287   12,124    8,637
# 영업이익(억원)        329   1,024     646      301    1,089      743      857
# 당기순이익(억원)       242     812     562      139    1,031      575      708
# 지배주주순이익(억원)     241     812     562      140    1,031      576      708
# 자산총계(억원)          0       0       0  159,885  175,134  175,907  185,254
# 부채총계(억원)          0       0       0  137,076  151,895  152,236  160,742
# 자본총계(억원)          0       0       0   22,809   23,238   23,672   24,512
# 자본금(억원)           0       0       0    3,079    3,079    3,079    3,079
# 부채비율(%)        0.00    0.00    0.00   600.98   653.64   643.12   655.77
# 유보율(%)         0.00    0.00    0.00   655.54   669.58   683.51   709.24
# 영업이익률(%)       3.71   15.75   10.40     8.13    14.95     6.13     9.92
# ...
