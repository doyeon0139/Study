# %%
import pandas as pd
import numpy as np

from selenium import webdriver
import time

# %%
kospi = pd.read_csv('c:/Users/bitcamp/Desktop/final_data/kospi_목록_코드_종목코드.csv', index_col=0)
kospi
# Out:
#      corp_code corp_name  stock_code
# 0       960641     한국패러랠      168490
# 1       600013    맵스리얼티1       94800
# 2       435297    맥쿼리인프라       88980
# 3       159698    지역난방공사       71320
# 4       458234   아시아나IDT      267850
# ..         ...       ...         ...
# 815     131780    SK네트웍스        1740
# 816     217947     신세계건설       34300
# 817     117212        두산         150
# 818     150439      진양산업        3780
# 819     141626   오리엔트바이오        2630
#
# [820 rows x 3 columns]

# %%
kospi_li = list(kospi.corp_name)

# %%
driver = webdriver.Chrome()

# %%
url = 'https://deepsearch.com/analytics/company-analysis/KRX%3A005940'
driver.get(url)

# %%
url = 'https://deepsearch.com/analytics/company-analysis/KRX%3A005940/fs?c-symbol=KRX%253A005940&fs-list=IS%253A1000%253BIS%253A6000%253BIS%253A8200&fs-dtype=quarterly'
driver.get(url)

# %%
driver.find_elements_by_css_selector('div.date-range')[0].click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/3461496429.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('div.date-range')[0].click()

# %%
url='https://deepsearch.com/analytics/company-analysis/KRX%3A005940/fs?c-symbol=KRX%253A005940&fs-list=IS%253A1000%253BIS%253A6000%253BIS%253A8200&fs-dtype=quarterly&c-name=NH%25ED%2588%25AC%25EC%259E%2590%25EC%25A6%259D%25EA%25B6%258C&std-from=2012-03-31&std-to=2021-12-31'
driver.get(url)

# %%
driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/3435670111.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/3435670111.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()

# %%
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1203486666.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()

# %%
url='https://deepsearch.com/analytics/company-analysis/KRX%3A005940/fs?c-name=NH%25ED%2588%25AC%25EC%259E%2590%25EC%25A6%259D%25EA%25B6%258C&c-symbol=KRX%253A005940&fs-list=IS%253A1000%253BIS%253A6000%253BIS%253A8200&std-from=2012-03-31&std-to=2021-12-31&fs-dtype=quarterly'
driver.get(url)

# %%
driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/3435670111.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18212/3435670111.py in <module>
# ----> 1 driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
#       2 driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()
#
# IndexError: list index out of range

# %%
driver.find_element_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div.excel-export-view > div > button').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1104583505.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div.excel-export-view > div > button').click()

# %%
driver.find_element_by_css_selector('#ds-modal > div > div > div > div.base-modal-content > div.excel-export-buttons > button.ds.button.positive.excel-export-button').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/4231308510.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#ds-modal > div > div > div > div.base-modal-content > div.excel-export-buttons > button.ds.button.positive.excel-export-button').click()

# %%
url='https://deepsearch.com/analytics/company-analysis/KRX%3A005940/fs?c-name=NH%25ED%2588%25AC%25EC%259E%2590%25EC%25A6%259D%25EA%25B6%258C&c-symbol=KRX%253A005940&fs-list=IS%253A1000%253BIS%253A6000%253BIS%253A8200&std-from=2012-03-31&std-to=2021-12-31&fs-dtype=quarterly'
driver.get(url)
time.sleep(10)
driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()

driver.find_element_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div.excel-export-view > div > button').click()

driver.find_element_by_css_selector('#ds-modal > div > div > div > div.base-modal-content > div.excel-export-buttons > button.ds.button.positive.excel-export-button').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1034315341.py:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1034315341.py:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1034315341.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div.excel-export-view > div > button').click()
# ...

# %%
kospi_li = list(kospi.stock_code)
kospi_li
# Out:
# [168490,
#  94800,
#  88980,
#  71320,
#  267850,
#  4310,
#  192820,
#  12610,
#  5320,
#  4100,
#  14130,
#  71950,
#  1510,
#  227840,
#  90080,
#  8870,
#  8970,
#  11810,
#  2760,
#  8600,
#  4360,
#  3540,
#  10780,
#  78520,
#  3570,
#  6980,
#  19440,
#  1380,
#  5810,
#  175330,
#  85310,
#  7280,
#  136490,
#  1750,
#  760,
#  1550,
#  10140,
#  33530,
#  123690,
#  2310,
#  2820,
#  10640,
#  1680,
#  5180,
#  6650,
#  9290,
#  105840,
#  71970,
#  94280,
#  96760,
#  140,
#  68270,
#  35150,
#  5880,
#  15020,
#  1880,
#  100840,
#  402340,
#  18670,
#  128820,
#  79430,
#  17810,
#  3720,
#  4920,
#  83420,
#  134790,
#  370,
#  84010,
#  102460,
#  3030,
#  9970,
#  1140,
#  2960,
#  138040,
#  5390,
#  7210,
#  2210,
#  19490,
#  490,
#  10600,
#  12280,
#  210,
#  18880,
#  28670,
#  105630,
#  16450,
#  44450,
#  8490,
#  32640,
#  69460,
#  1200,
#  12160,
#  3410,
#  7660,
#  3280,
#  5800,
#  4720,
#  16710,
#  72710,
#  47810,
#  336370,
#  93050,
#  12450,
# ...

# %%
stock_code = []

for code in kospi_li:
    code = str(code)
    print(code.zfill(6))
    stock_code.append(code.zfill(6))
# Out:
# 168490
# 094800
# 088980
# 071320
# 267850
# 004310
# 192820
# 012610
# 005320
# 004100
# 014130
# 071950
# 001510
# 227840
# 090080
# 008870
# 008970
# 011810
# 002760
# 008600
# 004360
# 003540
# 010780
# 078520
# 003570
# 006980
# 019440
# 001380
# 005810
# 175330
# 085310
# 007280
# 136490
# 001750
# 000760
# 001550
# 010140
# 033530
# 123690
# 002310
# 002820
# 010640
# 001680
# 005180
# 006650
# 009290
# 105840
# 071970
# 094280
# 096760
# 000140
# 068270
# 035150
# 005880
# 015020
# 001880
# 100840
# 402340
# 018670
# 128820
# 079430
# 017810
# 003720
# 004920
# 083420
# 134790
# 000370
# 084010
# 102460
# 003030
# 009970
# 001140
# 002960
# 138040
# 005390
# 007210
# 002210
# 019490
# 000490
# 010600
# 012280
# 000210
# 018880
# 028670
# 105630
# 016450
# 044450
# 008490
# 032640
# 069460
# 001200
# 012160
# 003410
# 007660
# 003280
# 005800
# 004720
# 016710
# 072710
# 047810
# 336370
# 093050
# 012450
# 011230
# 014910
# 026940
# 077500
# 105560
# 000970
# 005940
# 329180
# ...

# %%
driver = webdriver.Chrome()

# %%
for code in stock_code[:3]:
    url=f'https://deepsearch.com/analytics/company-analysis/KRX%3A{code}/fs?c-name=NH%25ED%2588%25AC%25EC%259E%2590%25EC%25A6%259D%25EA%25B6%258C&c-symbol=KRX%253A005940&fs-list=IS%253A1000%253BIS%253A6000%253BIS%253A8200&std-from=2012-03-31&std-to=2021-12-31&fs-dtype=quarterly'
    driver.get(url)
    time.sleep(10)
    print(code)
    driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
    driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()

    driver.find_element_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div.excel-export-view > div > button').click()

    driver.find_element_by_css_selector('#ds-modal > div > div > div > div.base-modal-content > div.excel-export-buttons > button.ds.button.positive.excel-export-button').click()
    time.sleep(30)
# Out:
# 168490
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/2604377836.py:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18212/2604377836.py in <module>
#       4     time.sleep(10)
#       5     print(code)
# ----> 6     driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
#       7     driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()
#       8
#
# IndexError: list index out of range

# %%
# !pip install chromedriver_autoinstaller
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import chromedriver_autoinstaller
import subprocess
import shutil

try:
    shutil.rmtree(r"c:\chrometemp")  #쿠키 / 캐쉬파일 삭제
except FileNotFoundError:
    pass

subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chrometemp"') # 디버거 크롬 구동


option = Options()
option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")

chrome_ver = chromedriver_autoinstaller.get_chrome_version().split('.')[0]
try:
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
except:
    chromedriver_autoinstaller.install(True)
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
driver.implicitly_wait(10)
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1495113341.py:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)

# %%
for code in stock_code[:3]:
    url=f'https://deepsearch.com/analytics/company-analysis/KRX%3A{code}/fs?c-name=NH%25ED%2588%25AC%25EC%259E%2590%25EC%25A6%259D%25EA%25B6%258C&c-symbol=KRX%253A005940&fs-list=IS%253A1000%253BIS%253A6000%253BIS%253A8200&std-from=2012-03-31&std-to=2021-12-31&fs-dtype=quarterly'
    driver.get(url)
    time.sleep(10)
    print(code)
    driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
    driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()

    driver.find_element_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div.excel-export-view > div > button').click()

    driver.find_element_by_css_selector('#ds-modal > div > div > div > div.base-modal-content > div.excel-export-buttons > button.ds.button.positive.excel-export-button').click()
    time.sleep(30)
# Out:
# 168490
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/2604377836.py:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18212/2604377836.py in <module>
#       4     time.sleep(10)
#       5     print(code)
# ----> 6     driver.find_elements_by_css_selector('#deepsearch-content > div > div.ds.card-layout.financial-export-view > div:nth-child(3) > div > div.icon')[0].click()
#       7     driver.find_elements_by_css_selector('#deepsearch-dropdown-container > div > div>div:nth-child(2)')[0].click()
#       8
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")

chrome_driver = 'E:\Final_Project'
driver = webdriver.Chrome(chrome_driver, options= chrome_options)
# --------------------------------------------------------------------------------------------
driver.get("https://www.naver.com")
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_18212/1736840903.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver, options= chrome_options)
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# ...

# %%
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

co = Options()
co.add_experimental_option('debuggerAddress', '127.0.0.1:9222')
driver = webdriver.Chrome(options=co)
driver.get('https://www.instagram.com/')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18212/3099954207.py in <module>
#       7 co = Options()
#       8 co.add_experimental_option('debuggerAddress', '127.0.0.1:9222')
# ----> 9 driver = webdriver.Chrome(options=co)
#      10 driver.get('https://www.instagram.com/')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# ...

# %%
# !pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 59.0/59.0 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
# !pip install keyboard
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# ...
#      ---------------------------------------- 58.1/58.1 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import pyautogui
import keyboard
import time

# %%
for i in range(10):
    pyautogui.doubleClick(x=1369, y=272)
    time.sleep(0.1)
    pyautogui.typewrite('005930', interval=0.1)
    time.sleep(0.1)

# %%
import pyautogui
import keyboard
import time

while 1:
    position = pyautogui.position()
    if keyboard.is_pressed('enter'):
        print(position)
        time.sleep(0.2)
# Out:
# Point(x=801, y=778)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13468/1885679315.py in <module>
#       4
#       5 while 1:
# ----> 6     position = pyautogui.position()
#       7     if keyboard.is_pressed('enter'):
#       8         print(position)
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in position(x, y)
#     763     NOTE: The position() function doesn't check for failsafe.
#     764     """
# --> 765     posx, posy = platformModule._position()
#     766     posx = int(posx)
#     767     posy = int(posy)
#
# ~\Anaconda3\lib\site-packages\pyautogui\_pyautogui_win.py in _position()
#     342
#     343     cursor = ctypes.wintypes.POINT()
# --> 344     ctypes.windll.user32.GetCursorPos(ctypes.byref(cursor))
#     345     return (cursor.x, cursor.y)
#     346
#
# KeyboardInterrupt:

# %%
# pyautogui.click(x=802, y=492)
# time.sleep(0.1)



for i in range(3):
    pyautogui.doubleClick(x=801, y=778)
    time.sleep(0.1)
    pyautogui.typewrite('005930', interval=0.1)
    time.sleep(0.1)

# %%
# !pip install yfinance
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=287c55a312ede09a1a3d385ed2df8ad99445ac98c97de2fb198b4353341298d1
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\f2\b5\2c\59ba95dcf854e542944c75fe3da584e4e3833b319735a0546c
# Successfully built multitasking
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import yfinance as yf

# %%
samsung = yf.Ticker('')
print(samsung)
# Out:
# yfinance.Ticker object <A005930>

# %%
samsung = samsung.financials
samsung
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# !pip install pandas_datareader
# Out:
# ...
#      -------------------------------------- 109.5/109.5 kB 6.2 MB/s eta 0:00:00
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from pandas_datareader import data as pdr
yf.pdr_override()

# %%
data = pdr.get_data_yahoo('005930.KS' , start='2012-01-01', end='2022-03-02')
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2012-01-02  21400.0  21600.0  21300.0  21600.0  17500.316406  13151350
# 2012-01-03  21860.0  22100.0  21840.0  22100.0  17905.416016  16927750
# 2012-01-04  22100.0  22200.0  21500.0  21600.0  17500.316406  17103700
# 2012-01-05  21460.0  21580.0  21100.0  21100.0  17095.216797  17298400
# 2012-01-06  21120.0  21320.0  20600.0  20800.0  16852.158203  18816250
# ...             ...      ...      ...      ...           ...       ...
# 2022-02-22  74300.0  74300.0  74300.0  74300.0  73917.914062         0
# 2022-02-23  74300.0  74300.0  74300.0  74300.0  73917.914062         0
# 2022-02-24  72300.0  72300.0  71300.0  71500.0  71132.312500  15759283
# 2022-02-25  72100.0  72600.0  71900.0  71900.0  71530.257812  13168484
# 2022-02-28  71900.0  71900.0  71900.0  71900.0  71530.257812         0
#
# [2499 rows x 6 columns]

# %%
samsung = yf.Ticker('005930.KS')
samsung = samsung.financials
samsung
# Out:
#                                                2021-12-31         2020-12-31  \
# Research Development                     22401726000000.0   21111490000000.0
# Effect Of Accounting Charges                         None               None
# Income Before Tax                        53351827000000.0   36345117000000.0
# Minority Interest                         8662234000000.0    8277685000000.0
# Net Income                               39243791000000.0   26090846000000.0
# Selling General Administrative           37084824000000.0   33127647000000.0
# Gross Profit                            113193457000000.0   92318692000000.0
# Ebit                                     51633856000000.0   35993876000000.0
# Operating Income                         51633856000000.0   35993876000000.0
# Other Operating Expenses                             None               None
# Interest Expense                          -431540000000.0    -583013000000.0
# ...

# %%
df = pdr.DataReader('A005930', 'yahoo')
df

# %%
# !pip install pykrx
# Out:
# ...
#      ---------------------------------------- 93.4/93.4 kB 5.2 MB/s eta 0:00:00
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from pykrx import stock

data = stock.get_market_fundamental_by_date('20120101', '20220331', '005930')
data
# Out:
#                BPS    PER   PBR     EPS   DIV    DPS
# 날짜
# 2012-01-02  623257  10.19  1.73  105992  0.93  10000
# 2012-01-03  623257  10.43  1.77  105992  0.90  10000
# 2012-01-04  623257  10.19  1.73  105992  0.93  10000
# 2012-01-05  623257   9.95  1.69  105992  0.95  10000
# 2012-01-06  623257   9.81  1.67  105992  0.96  10000
# ...            ...    ...   ...     ...   ...    ...
# 2022-03-25   39406  18.17  1.77    3841  4.29   2994
# 2022-03-28   39406  18.15  1.77    3841  4.30   2994
# 2022-03-29   39406  18.28  1.78    3841  4.26   2994
# 2022-03-30   39406  18.20  1.77    3841  4.28   2994
# 2022-03-31   39406  18.12  1.77    3841  4.30   2994
#
# [2522 rows x 6 columns]

# %%
# !pip install OpenDartReader
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import OpenDartReader

api_key = 'f09cfd7f19a3c92c3f8ddeba0993187c4ca93674'
stock_names = ['005930'] # 삼성전자 종목코드
dart = OpenDartReader(api_key)

# %%
dart.finstate(corp='005930', bsns_year=2016, reprt_code=11013)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 1   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 2   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 3   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 4   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 5   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 6   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 7   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 8   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 9   20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# 10  20160516003174      11013      2016  00126380     005930    CFS  연결재무제표
# ...

# %%
dart.finstate(corp='005930', bsns_year=2016, reprt_code=11012)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 1   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 2   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 3   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 4   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 5   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 6   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 7   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 8   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 9   20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# 10  20160816001779      11012      2016  00126380     005930    CFS  연결재무제표
# ...

# %%
dart.finstate(corp='005930', bsns_year=2016, reprt_code=11014)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 1   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 2   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 3   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 4   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 5   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 6   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 7   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 8   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 9   20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# 10  20161114001491      11014      2016  00126380     005930    CFS  연결재무제표
# ...

# %%
dart.finstate(corp='005930', bsns_year=2016, reprt_code=11011)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 1   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 2   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 3   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 4   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 5   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 6   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 7   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 8   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 9   20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# 10  20170331004518      11011      2016  00126380     005930    CFS  연결재무제표
# ...
