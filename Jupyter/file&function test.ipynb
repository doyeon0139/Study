# %% [markdown]
# ### File

# %%
# 뉴스 텍스트를 'news.txt'파일로 저장하시오 ( 4가지 방법)

# 'news.txt' 파일을 4가지 다른 방식으로 열어서 출력하시오

# ban.txt를 열어서 내용을 dict로 저장하시오

# ban_student.txt를 열어서 내용을 dict로 저장하시오
# {'2':[Alice Paul David Bob], '3':[John Joe Tom]...}

# 'stockcode.txt'에서 모든 코드번호와 종목명을 출력하시오

# 'stockcode.txt'에서 키 코드번호와 value종목명을 출력하시오

#  종목명에 '건설'이 포함된 종목명과 코드번호를 출력...

# 문자열을 입력받은 후 이를 파일에 기록하는 코드를 작성하시오

# stockcode.txt 파일을 복사해서 stokcode_copy.txt 파일을 만드시오

# 'bird-2695678_1920.jpg' 파일을 복사해서 'bird_copy.jpg'파일을 만드시오

# f = open('./python_data_files/bird_copy.jpg', 'rb')
# g = open('./python_data_files/bird_copy1.jpg', 'wb')

# bufsize = 1023
# img = f.read(bufsize)

# while img:
#     g.write(img)
#     img = f.read(bufsize)
    
# f.close()


# g.wirte(img)
# g.close()

# %%
# ./python_data_files/
# 뉴스 텍스트를 'news.txt'파일로 저장하시오 
news1 = """
16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램 
'스트레이트'를 시청하고 있다. 뉴스1

윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와 
유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.

"정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸 
필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.

다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고, 
녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.

윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에 
문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게 
있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.

이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지 
(MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고 
김씨의 녹취록 논란을 차단하는데 주력했다.

필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘
"""

f = open('./python_data_files/news1.txt', 'w')
f.write(news1)
f.close()

with open('./python_data_files/news1.txt', 'w')as f:
    f.write(news1)

# %%
# 'news.txt' 파일을 4가지 다른 방식으로 열어서 출력하시오
f = open('./python_data_files/news1.txt', 'r')
text = f.read()
f.close()

print(text)
# Out:
# 16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램
# '스트레이트'를 시청하고 있다. 뉴스1
#
# 윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와
# 유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.
#
# "정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸
# 필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.
#
# 다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고,
# 녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.
#
# 윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에
# 문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게
# 있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.
#
# 이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지
# (MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고
# 김씨의 녹취록 논란을 차단하는데 주력했다.
#
# 필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘

# %%
with open('./python_data_files/news1.txt', 'r')as f:
    text = f.read()

print(text)
# Out:
# 16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램
# '스트레이트'를 시청하고 있다. 뉴스1
#
# 윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와
# 유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.
#
# "정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸
# 필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.
#
# 다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고,
# 녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.
#
# 윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에
# 문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게
# 있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.
#
# 이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지
# (MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고
# 김씨의 녹취록 논란을 차단하는데 주력했다.
#
# 필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘

# %%
f = open('./python_data_files/news1.txt', 'r')
text = f.readlines()
f.close()

print(text)
# Out:
# ['\n', "16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램 \n", "'스트레이트'를 시청하고 있다. 뉴스1\n", '\n', '윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와 \n', '유튜브 채널 서울의소리 기자의 \'7시간 통화\' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.\n', '\n', '"정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸 \n', '필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.\n', '\n', '다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고, \n', '녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.\n', '\n', '윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 \'김종배의 시선집중\'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에 \n', '문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게 \n', '있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.\n', '\n', '이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지 \n', '(MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고 \n', '김씨의 녹취록 논란을 차단하는데 주력했다.\n', '\n', '필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘\n']

# %%
f = open('./python_data_files/news1.txt', 'r')

for _ in f:
    text = f.readline()
    print(text)
    
f.close()
# Out:
# 16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램
#
#
#
# 유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.
#
# "정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸
#
#
#
# 녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.
#
# 윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에
#
# 있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.
#
# 이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지
#
# 김씨의 녹취록 논란을 차단하는데 주력했다.
#
# 필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘

# %%
# ban.txt를 열어서 내용을 dict로 저장하시오

d = {}

f = open('./python_data_files/ban.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:
    d[i.split()[0]]=i.split()[1]
    
d
# Out:
# {'2': '45', '4': '39', '1': '41', '3': '40'}

# %%
# ban_student.txt를 열어서 내용을 dict로 저장하시오
# {'2':[Alice Paul David Bob], '3':[John Joe Tom]...}
d ={}

f = open('./python_data_files/ban_student.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:
    d[i.split()[0]] = i.split()[1:]
    
d

# %%
# 'stockcode.txt'에서 모든 코드번호와 종목명을 출력하시오

f = open('./python_data_files/stockcode.txt','r')
lines = f.readlines()

for i in lines:
    print(i.split())
f.close()

# %%
# 'stockcode.txt'에서 키 코드번호와 value종목명을 출력하시오

d = {}

f = open('./python_data_files/stockcode.txt', 'r')
lines = f.readlines()

for i in lines:
    d[i.split()[0]] = i.split()[1]
    
d

# %%
d.value('삼성전자')

# %%
#  종목명에 '건설'이 포함된 종목명과 코드번호를 출력...

d = {}

f = open('./python_data_files/stockcode.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:
    d[i.split()[1]]=i.split()[0]
    
# d
    
for j in lines:
    if '건설' in j:
        print(j)
# Out:
# 000720 현대건설
#
# 000721 현대건설우
#
# 000860 건설화학
#
# 001600 서광건설
#
# 001970 신성건설
#
# 001971 신성건설우
#
# 002530 벽산건설
#
# 002531 벽산건설우
#
# 003070 코오롱건설
#
# 005900 동양건설
#
# 005960 동부건설
#
# 005961 동부건설우
#
# 005980 성지건설
#
# 006360 GS건설
#
# 006440 한일건설
#
# 009410 태영건설
#
# 009411 태영건설우
#
# 011160 두산건설
#
# 012090 성원건설
#
# 012091 성원건설우
#
# 013360 일성건설
#
# 013361 일성건설우B
#
# 013362 일성건설2우B
#
# 013580 계룡건설
#
# 014790 한라건설
#
# 015110 중앙건설
#
# 034300 신세계건설
#
# 047040 대우건설

# %%
# 문자열을 입력받은 후 이를 파일에 기록하는 코드를 작성하시오

s = input('문자열')

f = open('./python_data_files/words_1.txt', 'w')
f.write(s)
f.close

g = open('./python_data_files/words_1.txt', 'r')
t = g.read()
g.close

print(t)

# %%
# stockcode.txt 파일을 복사해서 stokcode_copy.txt 파일을 만드시오

f = open('./python_data_files/stockcode.txt', 'r')
text = f.read()
f.close()

g = open('./python_data_files/stokcode_copy_1.txt', 'w')
g.write(text)
g.close()

# %%
# 'bird-2695678_1920.jpg' 파일을 복사해서 'bird_copy.jpg'파일을 만드시오
from IPython.display import Image
Image('./python_data_files/bird-2695678_1920.jpg')

# %%
f = open('./python_data_files/bird-2695678_1920.jpg', 'rb')
img = f.read()
f.close()

m = open('./python_data_files/bird_copy.jpg', 'wb')
m.write(img)
m.close()

# %%
#  종목명에 '건설'이 포함된 종목명과 코드번호를 출력...

d = {}


f = open('./python_data_files/stockcode.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:
    d[i.split()[1]] = i.split()[0]

for j in d.keys():
    if '건설' in j:
        print(j, d[j])
# Out:
# 현대건설 000720
# 현대건설우 000721
# 건설화학 000860
# 서광건설 001600
# 신성건설 001970
# 신성건설우 001971
# 벽산건설 002530
# 벽산건설우 002531
# 코오롱건설 003070
# 동양건설 005900
# 동부건설 005960
# 동부건설우 005961
# 성지건설 005980
# GS건설 006360
# 한일건설 006440
# 태영건설 009410
# 태영건설우 009411
# 두산건설 011160
# 성원건설 012090
# 성원건설우 012091
# 일성건설 013360
# 일성건설우B 013361
# 일성건설2우B 013362
# 계룡건설 013580
# 한라건설 014790
# 중앙건설 015110
# 신세계건설 034300
# 대우건설 047040

# %%
from IPython.display import Image
Image('./python_data_files/bird-2695678_1920.jpg')

# %%
# 'bird-2695678_1920.jpg' 파일을 복사해서 'bird_copy.jpg'파일을 만드시오
f = open('./python_data_files/bird-2695678_1920.jpg', 'rb')
img = f.read()
f.close()

print(img)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00CC"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1e\x00\x01\x01\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x04\x05\x06\x07\x08\t\n\x0b\x01\x03\xff\xc4\x00m\x10\x00\x01\x00\x05\x08\x06\x05\x08\x06\x06\x04\x06\r\t\x06\x07\x00\x01\x03\x04\x05\x06\x11\x13!1a\x81\xa1\xf0\x07\x14\x15A\xc1\xe1\x08$Qq\x91\x16%45D\xb1\xd1\xf1\x02\t#ET\xa2&3
# ...

# %%
# ./python_data_files/
# 뉴스 텍스트를 'news.txt'파일로 저장하시오 
news1 = """
16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램 
'스트레이트'를 시청하고 있다. 뉴스1

윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와 
유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.

"정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸 
필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.

다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고, 
녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.

윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에 
문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게 
있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.

이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지 
(MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고 
김씨의 녹취록 논란을 차단하는데 주력했다.

필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘
"""

f = open('./python_data_files/news_2', 'w')
f.write(news1)
f.close()

with open('./python_data_files/news_2.txt','w')as f:
    f.write(news1)

# %%
# 뉴스 텍스트를 'news.txt'파일로 저장하시오 ( 4가지 방법)
f = open('./python_data_files/news_2.txt', 'r')
text = f.read()
f.close()

print(text)
# Out:
# 16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램
# '스트레이트'를 시청하고 있다. 뉴스1
#
# 윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와
# 유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.
#
# "정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸
# 필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.
#
# 다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고,
# 녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.
#
# 윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에
# 문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게
# 있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.
#
# 이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지
# (MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고
# 김씨의 녹취록 논란을 차단하는데 주력했다.
#
# 필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘

# %%
with open('./python_data_files/news_2.txt', 'r')as f:
    text = f.read()
print(text)
# Out:
# 16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램
# '스트레이트'를 시청하고 있다. 뉴스1
#
# 윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와
# 유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.
#
# "정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸
# 필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.
#
# 다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고,
# 녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.
#
# 윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에
# 문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게
# 있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.
#
# 이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지
# (MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고
# 김씨의 녹취록 논란을 차단하는데 주력했다.
#
# 필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘

# %%
f = open('./python_data_files/news_2.txt', 'r')
text = f.readlines()
f.close()

print(text)
# Out:
# ['\n', "16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램 \n", "'스트레이트'를 시청하고 있다. 뉴스1\n", '\n', '윤석열 국민의힘 대선후보 측이 전날 MBC가 보도한 윤 후보 배우자 김건희씨와 \n', '유튜브 채널 서울의소리 기자의 \'7시간 통화\' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.\n', '\n', '"정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸 \n', '필사적으로 막으려했던 수세적 대응 기조를 버리고 재빨리 태세 전환에 나선 것이다.\n', '\n', '다만 파장이 가라앉을지는 미지수다. 앞서 방송을 내보낸 MBC 스트레이트 팀은 녹취록 관련 추가 보도에 나설 가능성을 열어뒀고, \n', '녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.\n', '\n', '윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 \'김종배의 시선집중\'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에 \n', '문제가 있다며 방송을 하겠다고 밝혔는데, 도대체 어떤 부분이 문제가 있었길래 공영방송이 일요일 황금시간에 20분 넘게 내보낼 만한 게 \n', '있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.\n', '\n', '이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지 \n', '(MBC가) 조금 더 명확하게 지적했으면 한다. 본인이 가진 관점을 드러내고, 선거를 위해 가족이 활동하는 건 전혀 문제될 일이 없다"고 \n', '김씨의 녹취록 논란을 차단하는데 주력했다.\n', '\n', '필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘\n']

# %%
f = open('./python_data_files/news_2.txt', 'r')
for i in f:
    text = f.readline()
    print(text)
# Out:
# 16일 서울역 대합실에서 시민들이 윤석열 국민의힘 대선후보 부인 김건희씨의 '7시간 통화 녹음' 내용을 다룬 MBC 시사프로그램
#
#
#
# 유튜브 채널 서울의소리 기자의 '7시간 통화' 녹취록 방송과 관련해 "이런 방송을 왜 했는지 MBC에 묻고 싶다"며 목소리를 높였다.
#
# "정치적으로 문제 될 게 없다"는 정면돌파 의지도 내비쳤다. 법원에 방송금지 가처분 신청까지 제기해 김씨의 육성이 전파를 타는 걸
#
#
#
# 녹취록 파일을 넘긴 서울의소리 측은 7시간 45분 원본 파일 전체를 공개하겠다는 뜻도 밝힌 상태다.
#
# 윤희석 국민의힘 선대본부 상임공보특보는 17일 MBC 라디오 '김종배의 시선집중'과의 인터뷰에서 "MBC는 공인인 김건희씨의 발언 중에
#
# 있었는가 싶다"며 "지켜보신 국민들 마음도 같은 공감대가 있었다고 믿는다"고 주장했다.
#
# 이준석 국민의힘 대표 역시 김씨를 옹호했다. 전날 방송 이후 사회관계망서비스(SNS) 페이스북에 "정확히 어떤 부분이 문제되는지
#
# 김씨의 녹취록 논란을 차단하는데 주력했다.
#
# 필사적으로 막더니, "김씨 발언 문제될 것 없다"는 국민의힘

# %%
# 'news.txt' 파일을 4가지 다른 방식으로 열어서 출력하시오

# %%
# ban.txt를 열어서 내용을 dict로 저장하시오

d = {}

f = open('./python_data_files/ban.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:

    d[i.split()[0]] = i.split()[1]
    
d
# Out:
# {'2': '45', '4': '39', '1': '41', '3': '40'}

# %%
# ban_student.txt를 열어서 내용을 dict로 저장하시오
# {'2':[Alice Paul David Bob], '3':[John Joe Tom]...}

d = {}
f = open('./python_data_files/ban_student.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:
    d[i.split()[0]] = i.split()[1:]
    
d
# Out:
# {'2': ['Alice', 'Paul', 'David', 'Bob'],
#  '4': ['Cindy', 'Stella', 'Bill'],
#  '1': ['Henry', 'Jenny', 'Jessica', 'Eric', 'Tim'],
#  '3': ['John', 'Joe', 'Tom']}

# %%
# 'stockcode.txt'에서 모든 코드번호와 종목명을 출력하시오
f = open('./python_data_files/stockcode.txt', 'r')
text = f.read()
f.close()

print(text.split('\n'))
# Out:
# ['000020 동화약품', '000040 S&T모터스', '000050 경방', '000060 메리츠화재', '000070 삼양사', '000071 삼양사우', '000100 유한양행', '000101 유한양행우', '000120 대한통운', '000140 하이트홀딩스', '000141 하이트홀딩스우', '000150 두산', '000151 두산우', '000152 두산2우B', '000180 성창기업지주', '000210 대림산업', '000211 대림산업우', '000220 유유제약', '000221 유유제약1우', '000222 유유제약2우B', '000230 일동제약', '000240 한국타이어', '000270 기아차', '000300 대유신소재', '000320 디피아이홀딩스', '000321 디피아이홀딩스우', '000322 디피아이홀딩스2B', '000360 삼환기업', '000361 삼환기업우', '000370 한화손해보험', '000390 삼화페인트', '000400 롯데손해보험', '000420 로케트전기', '000421 로케트전우', '000430 대원강업', '000470 그린손해보험', '000480 조선내화', '000490 대동공업', '000500 가온전선', '000520 삼일제약', '000540 흥국쌍용화재', '000541 흥국쌍용화재우', '000542 흥국쌍용화재2우B', '000590 조선선재', '000610 제일화재', '000640 동아제약', '000650 천일고속', '000660 하이닉스', '000670 영풍', '000680 LS네트웍스', '000681 LS네트웍스우', '000700 한진해운', '000720 현대건설', '000721 현대건설우', '000760 이화산업', '000790 C&상선', '000800 경남기업', '000810 삼성화재', '000811 삼성화재우', '000830 삼성물산', '000831 삼성물산우', '000850 화천기공', '000860 건설화학', '
# ...

# %%
# 'stockcode.txt'에서 키 코드번호와 value종목명을 출력하시오

d = {}
f = open('./python_data_files/stockcode.txt', 'r')
lines = f.readlines()
f.close()

for i in lines:
    d[i.split()[0]] = i.split()[1]
    
d
# Out:
# {'000020': '동화약품',
#  '000040': 'S&T모터스',
#  '000050': '경방',
#  '000060': '메리츠화재',
#  '000070': '삼양사',
#  '000071': '삼양사우',
#  '000100': '유한양행',
#  '000101': '유한양행우',
#  '000120': '대한통운',
#  '000140': '하이트홀딩스',
#  '000141': '하이트홀딩스우',
#  '000150': '두산',
#  '000151': '두산우',
#  '000152': '두산2우B',
#  '000180': '성창기업지주',
#  '000210': '대림산업',
#  '000211': '대림산업우',
#  '000220': '유유제약',
#  '000221': '유유제약1우',
#  '000222': '유유제약2우B',
#  '000230': '일동제약',
#  '000240': '한국타이어',
#  '000270': '기아차',
#  '000300': '대유신소재',
#  '000320': '디피아이홀딩스',
#  '000321': '디피아이홀딩스우',
#  '000322': '디피아이홀딩스2B',
#  '000360': '삼환기업',
#  '000361': '삼환기업우',
#  '000370': '한화손해보험',
#  '000390': '삼화페인트',
#  '000400': '롯데손해보험',
#  '000420': '로케트전기',
#  '000421': '로케트전우',
#  '000430': '대원강업',
#  '000470': '그린손해보험',
#  '000480': '조선내화',
#  '000490': '대동공업',
#  '000500': '가온전선',
#  '000520': '삼일제약',
#  '000540': '흥국쌍용화재',
#  '000541': '흥국쌍용화재우',
#  '000542': '흥국쌍용화재2우B',
#  '000590': '조선선재',
#  '000610': '제일화재',
# ...

# %%
#  종목명에 '건설'이 포함된 종목명과 코드번호를 출력...
d = {}
f = open('./python_data_files/stockcode.txt', 'r')
lines = f.readlines()
f.close()

# for i in lines:
#     d[i.split()[0]] = i.split()[1]
    
for j in lines:
    if '건설' in j:
        print(j)
# Out:
# 000720 현대건설
#
# 000721 현대건설우
#
# 000860 건설화학
#
# 001600 서광건설
#
# 001970 신성건설
#
# 001971 신성건설우
#
# 002530 벽산건설
#
# 002531 벽산건설우
#
# 003070 코오롱건설
#
# 005900 동양건설
#
# 005960 동부건설
#
# 005961 동부건설우
#
# 005980 성지건설
#
# 006360 GS건설
#
# 006440 한일건설
#
# 009410 태영건설
#
# 009411 태영건설우
#
# 011160 두산건설
#
# 012090 성원건설
#
# 012091 성원건설우
#
# 013360 일성건설
#
# 013361 일성건설우B
#
# 013362 일성건설2우B
#
# 013580 계룡건설
#
# 014790 한라건설
#
# 015110 중앙건설
#
# 034300 신세계건설
#
# 047040 대우건설

# %%
# 문자열을 입력받은 후 이를 파일에 기록하는 코드를 작성하시오
s = input('문자열')
with open('./python_data_files/file_s.txt', 'w')as f:
    f.write(s)
    
with open('./python_data_files/file_s.txt', 'r')as f:
    t = f.read()

print(t)
# Out:
# 문자열hello
# hello

# %%
# stockcode.txt 파일을 복사해서 stokcode_copy.txt 파일을 만드시오
with open('./python_data_files/stockcode.txt', 'r')as f:
    text = f.read()
with open('./python_data_files/stockcode_c.txt', 'w')as f:
    f.write(text)
    
with open('./python_data_files/stockcode_c.txt', 'r')as f:
    te = f.read()
    
print(te)
# Out:
# 000020 동화약품
# 000040 S&T모터스
# 000050 경방
# 000060 메리츠화재
# 000070 삼양사
# 000071 삼양사우
# 000100 유한양행
# 000101 유한양행우
# 000120 대한통운
# 000140 하이트홀딩스
# 000141 하이트홀딩스우
# 000150 두산
# 000151 두산우
# 000152 두산2우B
# 000180 성창기업지주
# 000210 대림산업
# 000211 대림산업우
# 000220 유유제약
# 000221 유유제약1우
# 000222 유유제약2우B
# 000230 일동제약
# 000240 한국타이어
# 000270 기아차
# 000300 대유신소재
# 000320 디피아이홀딩스
# 000321 디피아이홀딩스우
# 000322 디피아이홀딩스2B
# 000360 삼환기업
# 000361 삼환기업우
# 000370 한화손해보험
# 000390 삼화페인트
# 000400 롯데손해보험
# 000420 로케트전기
# 000421 로케트전우
# 000430 대원강업
# 000470 그린손해보험
# 000480 조선내화
# 000490 대동공업
# 000500 가온전선
# 000520 삼일제약
# 000540 흥국쌍용화재
# 000541 흥국쌍용화재우
# 000542 흥국쌍용화재2우B
# 000590 조선선재
# 000610 제일화재
# 000640 동아제약
# 000650 천일고속
# 000660 하이닉스
# 000670 영풍
# 000680 LS네트웍스
# 000681 LS네트웍스우
# 000700 한진해운
# 000720 현대건설
# 000721 현대건설우
# 000760 이화산업
# 000790 C&상선
# 000800 경남기업
# 000810 삼성화재
# 000811 삼성화재우
# 000830 삼성물산
# 000831 삼성물산우
# 000850 화천기공
# 000860 건설화학
# 000880 한화
# 000881 한화우
# 000890 보해양조
# 000891 보해양조우
# 000910 유니온
# ...

# %%
# 'bird-2695678_1920.jpg' 파일을 복사해서 'bird_copy.jpg'파일을 만드시오

with open('./python_data_files/bird-2695678_1920.jpg', 'rb')as f:
    img = f.read()
    
with open('./python_data_files/bird_copy_1.jpg', 'wb')as f:
    f.write(img)
    
with open('./python_data_files/bird_copy_1.jpg', 'rb')as g:
    img_1 = g.read()
    
img_1
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00CC"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1e\x00\x01\x01\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x04\x05\x06\x07\x08\t\n\x0b\x01\x03\xff\xc4\x00m\x10\x00\x01\x00\x05\x08\x06\x05\x08\x06\x06\x04\x06\r\t\x06\x07\x00\x01\x03\x04\x05\x06\x11\x13!1a\x81\xa1\xf0\x07\x14\x15A\xc1\xe1\x08$Qq\x91\x16%45D\xb1\xd1\xf1\x02\t#ET\xa2&3
# ...

# %%
f = open('./python_data_files/bird_copy.jpg', 'rb')
g = open('./python_data_files/bird_copy1.jpg', 'wb')

bufsize = 1023
img = f.read(bufsize)

while img:
    g.write(img)
    img = f.read(bufsize)
    
f.close()


# g.wirte(img)
g.close()
