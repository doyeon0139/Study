# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore') 

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

import requests
from bs4 import BeautifulSoup 
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
url = "http://search.danawa.com/dsearch.php?query='무선청소기'&tab=main"

# %%
driver.get(url)

# %%
html = driver.page_source
html
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko" class=" js no-touch"><head>\n<title>\'무선청소기\' : 다나와 통합검색</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="title" content="\'무선청소기\' 통합검색 : 다나와 통합검색">\n<meta name="description" content="\'\'무선청소기\'\'의 다나와 통합검색 결과입니다.">\n<meta name="keywords" content="\'무선청소기\', 다나와, 최저가, 가격비교, 검색, 통합검색, 상품 추천, 가격비교사이트, 가격비교 사이트, 가격비교 싸이트, 가격 검색, 추천, 인터넷쇼핑, 온라인쇼핑, 쇼핑, 쇼핑몰, 싸게 파는 곳, 지식쇼핑">\n<meta property="og:title" content="\'무선청소기\' 통합검색 : 다나와 통합검색">\n<meta property="og:description" content="\'\'무선청소기\'\'의 다나와 통합검색 결과입니다.">\n<meta property="og:image" content="http://img.danawa.com/new/tour/img/logo/sns_danawa.jpg">\n<meta content="width=1280" name="viewport">\n<link rel="shortcut icon" href="//img.danawa.com/new/danawa_main/v1/img/danawa_favicon.ico">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/css/common.css?v=2201051636">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/css/navigation.css?v=2201051636">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/wish_pop.css?v=2201051636">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/dictionary.css?v=2111171357">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/search_renew.css?v=2111171357">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/dpg_stamp.css?v=2111171357">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/globaljs/external/nouislider/nouislider.min.css">\n<link rel="canonical" href="http://search.danawa.com/dsearch.php?query=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B">\n<link rel="alternate" href="http://search.danawa.com/mobile/dsearch.php?keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B" media="only screen and (max-width: 640px)">\n<script type="text/javascript" async="" src="http://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="http://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" charset="utf-8" src="//static.dable.io/dist/plugin.min.js"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=AW-631507961&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=AW-963914956&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=G-XWC0NNEPX2&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=G-287B75YQDL&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="http://www.googletagmanager.com/gtag/js?id=G-GESPG2060V&amp;l=dataLayer&amp;cx=c"></script><script defer="" src="https://cdn.megadata.co.kr/dist/prod/enp_tracker_self_hosted.min.js"></script><script type="text/javascript" src="//static.danawa.com/globaljs/external/jquery/core/last/jquery-last.min.js?v=21112315300"></script>\n<script type="text/javascript" charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/gnb_ui.js?v=21112315300"></script>\n<script type="text/javascript" charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/jquery.addProductToWishList.js?v=21112315300"></script>\n<script type="text/javascript" src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.cookie/jquery.cookie.js"></script>\n<script type="text/javascript" charset="utf-8" src="//static.danawa.com/globaljs/com/danawa/common/searchAutocompleteLayer_UTF8.js?v=21112315300"></script>\n<script src="//rum.beusable.net/script/b200115e112333u798/1937c2a118" async="" type="text/javascript"></script><i ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
path = '#productListArea > div.main_prodlist.main_prodlist_list > ul > li'

# %%
tt = soup.select(path)

# %%
len(tt)
# Out:
# 44

# %%
tt
# Out:
# [<li class="prod_item" id="productItem15170459">
#  <input id="productItem_categoryInfo_15170459" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_15170459" type="hidden" value="577830"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="http://prod.danawa.com/info/?pcode=15170459&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" id="thumbLink_15170459" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="제트 VS20A956A3" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/459/170/img/15170459_1.jpg?shrink=130:130&amp;_v=20210906145322"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_15170459" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  						</a>
#  <input id="hidden_cate_sub_c1" type="hidden" value="72"/>
#  <input id="hidden_cate_sub_c2" type="hidden" value="80"/>
#  <input id="hidden_cate_sub_c3" type="hidden" value="81"/>
#  <div class="img_selector">
#  <a class="sel_item" href="#" onclick="return false;" title="상품 색상"><span class="hide_indent sub_color_w100" style="background-color:#1C4587;">상품 색상</span></a><a class="sel_item" href="#" onclick="return false;" title="상품 색상"><span class="hide_indent sub_color_w100" style="background-color:#FFFFFF;">상품 색상</span></a><a class="sel_item" href="#" onclick="return false;" title="상품 색상"><span class="hide_indent sub_color_w100" style="background-color:#6AA84F;">상품 색상</span></a> </div> </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=15170459&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170459',1);" target="_blank">삼성전자 비스포크 제트 VS20A956A3</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">배터리 1개+물걸레, 침구, 펫브러쉬 제외 액세서리 4종 구성 (청소기+청정스테이션 합포장)</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list"><a class="view_dic" href="#" onclick="$.termDicViewLink(8501,'view',this,0,72,80); return false;">핸디/스틱<b>청소기</b></a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(7445,'view',this,0,72,80); return false;">핸디+스틱형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14900,'view',this,0,72,80); return false;">무선형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(217536,'view',this,0,72,80); return false;">흡입+걸레겸용</a> / <br/><b>[성능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">흡입력</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">210W</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(4000,'view',this,0,72,80); return false;">제트싸이클론</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27442,'view',this,0,72,80); return false;">디지털인버터모터</a> / <br/><b>[배터리]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">충전시간</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">3시간30분</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">사용시간(개당)</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">1시간</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(217578,'view',this,0,72,80); return false;">분리형 (1개)</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27314,'view',this,0,72,80); return false;">리튬이온</a> / <br/><b>[필터]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(30024,'view',this,0,72,80); return false;">5단계여과</a> / <br/><b>[기능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(216261,'view',this,0,72,80); return false;">자동물공급</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(30484,'view',this,0,72,80); return false;">디스플레이표시창</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27321,'view',this,0,72,80); return false;">배터리잔량표시</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(219165,'view',this,0,72,80); return false;">자동먼지비움</a> / <br/><b>[구성]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(18333,'view',this,0,72,80); return false;">바닥</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18442,'view',this,0,72,80); return false;">솔형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18436,'view',this,0,72,80); return false;">틈새</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27313,'view',this,0,72,80); return false;">연장툴</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(218109,'view',this,0,72,80); return false;">청정스테이션</a> / <br/><b>[부가]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(214653,'view',this,0,72,80); return false;">먼지통용량</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(214653,'view',this,0,72,80); return false;">0.5L</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">색상</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">미스티화이트</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">무게</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">2.5kg</a> / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm								</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_15170459"><dl class="unit_goods_list"><dt class="title_unit">관련용품▶</dt><dd class="unit_lists"><a class="unit_link view_dic" data-relationcode="14407868" href="#" onclick="return false;">리튬이온배터리</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="14407970" href="#" onclick="return false;">물걸레브러쉬</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="14415326" href="#" onclick="return false;">펫브러쉬</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="15103583" href="#" onclick="return false;">청정스테이션먼지봉투</a></dd></dl></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2021.09.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:97%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.8</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=15170459&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>140</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '15170459', 'search_bundle', '', '', '577830');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170459',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_15170459" type="hidden" value="미드나잇블루^15170318**미스티화이트^15170459**우디그린^15170501//삼성전자 비스포크 제트 VS20A956A3//15170459"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170459',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li id="productInfoDetail_15170318" style="">
#  <p class="chk_sect">
#  										425몰
#  										<label for="prodCompareCheck_15170318">
#  <input id="prodCompareCheck_15170318" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="15170318"/>
#  <input name="compareRepValue" type="hidden" value="15170459"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=15170318&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170318',1);" target="_blank"><strong>562,720</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_15170318"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect"><span class="rank">2위</span>																				미드나잇블루																				<a href="http://prod.danawa.com/info/?pcode=15170318&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170318',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li class="rank_one" id="productInfoDetail_15170459" style="">
#  <p class="chk_sect">
#  										358몰
#  										<label for="prodCompareCheck_15170459">
#  <input id="prodCompareCheck_15170459" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="15170459"/>
#  <input name="compareRepValue" type="hidden" value="15170459"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=15170459&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170459',1);" target="_blank"><strong>577,830</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_15170459"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect"><span class="rank">1위</span>																				미스티화이트																				<a href="http://prod.danawa.com/info/?pcode=15170459&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170459',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_15170501" style="">
#  <p class="chk_sect">
#  										78몰
#  										<label for="prodCompareCheck_15170501">
#  <input id="prodCompareCheck_15170501" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="15170501"/>
#  <input name="compareRepValue" type="hidden" value="15170459"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=15170501&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170501',1);" target="_blank"><strong>623,030</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_15170501"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">																				우디그린																				<a href="http://prod.danawa.com/info/?pcode=15170501&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170501',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem13327520">
#  <input id="productItem_categoryInfo_13327520" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_13327520" type="hidden" value="1078930"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="http://prod.danawa.com/info/?pcode=13327520&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" id="thumbLink_13327520" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="코드제로 ThinQ A9S AO9571" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/520/327/img/13327520_1.jpg?shrink=130:130&amp;_v=20210406161021"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_13327520" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  						</a>
#  <div class="img_selector">
#  <a class="sel_item" href="#" onclick="return false;" title="상품 색상"><span class="hide_indent sub_color_w100" style="background-color:#FCE5CD;">상품 색상</span></a><a class="sel_item" href="#" onclick="return false;" title="상품 색상"><span class="hide_indent sub_color_w100" style="background-color:#274E13;">상품 색상</span></a> </div> </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=13327520&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13327520',1);" target="_blank">LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">올인원타워로 비움, 충전, 보관을 한번에!</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list"><a class="view_dic" href="#" onclick="$.termDicViewLink(8501,'view',this,0,72,80); return false;">핸디/스틱<b>청소기</b></a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(7445,'view',this,0,72,80); return false;">핸디+스틱형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14900,'view',this,0,72,80); return false;">무선형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(217536,'view',this,0,72,80); return false;">흡입+걸레겸용</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(1743,'view',this,0,72,80); return false;">소비전력</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(1743,'view',this,0,72,80); return false;">590W</a> / <br/><b>[성능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">흡입력</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">210W</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(213820,'view',this,0,72,80); return false;">2중터보싸이클론</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27442,'view',this,0,72,80); return false;">스마트인버터모터</a> / <br/><b>[배터리]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">충전시간</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">4시간</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">사용시간(개당)</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">1시간</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(217578,'view',this,0,72,80); return false;">분리형 (2개)</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27314,'view',this,0,72,80); return false;">리튬이온</a> / <br/><b>[필터]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14801,'view',this,0,72,80); return false;">분리형배기필터 / 헤파필터</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14801,'view',this,0,72,80); return false;">H13급</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(30024,'view',this,0,72,80); return false;">5단계여과</a> / <br/><b>[기능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(216261,'view',this,0,72,80); return false;">자동물공급</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27321,'view',this,0,72,80); return false;">배터리잔량표시</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(214680,'view',this,0,72,80); return false;">IoT기능</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(219165,'view',this,0,72,80); return false;">자동먼지비움</a> / <br/><b>[구성]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(18333,'view',this,0,72,80); return false;">바닥</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(9440,'view',this,0,72,80); return false;">물걸레</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18453,'view',this,0,72,80); return false;">침구</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18442,'view',this,0,72,80); return false;">솔형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18436,'view',this,0,72,80); return false;">틈새</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(218112,'view',this,0,72,80); return false;">올인원타워</a> / <br/><b>[부가]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">색상</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">카밍베이지</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">무게</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">2.6kg</a> / 크기(가로x세로x깊이): 250x1120x260mm								</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_13327520"><dl class="unit_goods_list"><dt class="title_unit">관련용품▶</dt><dd class="unit_lists"><a class="unit_link view_dic" data-relationcode="5843801" href="#" onclick="return false;">리튬이온배터리</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="6421059" href="#" onclick="return false;">바닥브러쉬</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="8944010" href="#" onclick="return false;">물걸레브러쉬</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="13321037" href="#" onclick="return false;">펫브러쉬</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="13442471" href="#" onclick="return false;">침구브러쉬</a><span class="ucomma">,</span><a class="unit_link view_dic" data-relationcode="14083475" href="#" onclick="return false;">올인원타워먼지봉투</a></dd></dl></div>
#  <div class="prod_rel_content">
#  <dl class="rel_item rel_event">
#  <dt>기획전</dt>
#  <dd><a href="http://plan.danawa.com/info/?nPlanSeq=4931" rel="noopener" target="_blank">한눈에 보는
#  LG전자 코드제로 청소기</a></dd>
#  </dl>
#  <dl class="rel_item rel_review">
#  <dt>사용기</dt>
#  <dd><a href="http://prod.danawa.com/community/ProdBoardView.php?nSeq=4748086&amp;nBlogCateSeq1=264&amp;prod_c=13327520" rel="noopener" target="_blank">무선청소기 추천 LG코드제로 A9S 칭찬해요</a></dd>
#  </dl>
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2021.02.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:94%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.6</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=13327520&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>1,393</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '13327520', 'search_bundle', '', '', '1078930');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13327520',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_13327520" type="hidden" value="카밍베이지^13327520**카밍그린^13328039//LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571//13327520"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13327520',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_13327520" style="">
#  <p class="chk_sect">
#  										669몰
#  										<label for="prodCompareCheck_13327520">
#  <input id="prodCompareCheck_13327520" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="13327520"/>
#  <input name="compareRepValue" type="hidden" value="13327520"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=13327520&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13327520',1);" target="_blank"><strong>1,078,930</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_13327520"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect"><span class="rank">1위</span>																				카밍베이지																				<a href="http://prod.danawa.com/info/?pcode=13327520&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13327520',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_13328039" style="">
#  <p class="chk_sect">
#  										506몰
#  										<label for="prodCompareCheck_13328039">
#  <input id="prodCompareCheck_13328039" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="13328039"/>
#  <input name="compareRepValue" type="hidden" value="13327520"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=13328039&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13328039',1);" target="_blank"><strong>1,075,930</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_13328039"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect"><span class="rank">2위</span>																				카밍그린																				<a href="http://prod.danawa.com/info/?pcode=13328039&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13328039',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem14884709">
#  <input id="productItem_categoryInfo_14884709" type="hidden" value="자동차 용품_차량용전자제품"/>
#  <input id="min_price_14884709" type="hidden" value="61340"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="http://prod.danawa.com/info/?pcode=14884709&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" id="thumbLink_14884709" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/709/884/img/14884709_1.jpg?shrink=130:130&amp;_v=20210730142109"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_14884709" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  						</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=14884709&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14884709',1);" target="_blank">샤오미 CLEANFLY 차량용 <b>무선</b> <b>청소기</b> 4세대 H2 (해외구매)</a>
#  </p>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">차량용<b>청소기</b> / <a class="view_dic" href="#" onclick="$.termDicViewLink(214056,'view',this,0,1840,59152); return false;"><b>무선</b></a> / 흡입력: <a class="view_dic" href="#" onclick="$.termDicViewLink(214065,'view',this,0,1840,59152); return false;">16,800Pa</a> / 최대출력: 120W / 헤파필터 / 스테인리스 필터 / 추가노즐: <a class="view_dic" href="#" onclick="$.termDicViewLink(214068,'view',this,0,1840,59152); return false;">틈새</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(214071,'view',this,0,1840,59152); return false;">솔브러쉬</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(214074,'view',this,0,1840,59152); return false;">연장호스</a> / 사용시간: <a class="view_dic" href="#" onclick="$.termDicViewLink(214167,'view',this,0,1840,59152); return false;">30분</a> / 소음: 73.8dB / 충전방식: USB C타입 / 배터리용량: 2,000mAh / 색상: 블랙, 화이트 / 크기: 369x72mm / 무게: 560g								</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_14884709"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2020.02.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:95%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.7</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=14884709&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>41</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '14884709', 'search', '', '', '61340');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14884709',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_14884709" type="hidden" value="//샤오미 CLEANFLY 차량용 &lt;b&gt;무선&lt;/b&gt; &lt;b&gt;청소기&lt;/b&gt; 4세대 H2 (해외구매)"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=14237761" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14884709',3);" target="_blank"><span>블박/내비/전자제품</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="1840|59152|59189|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_14884709">
#  <p class="chk_sect">
#  										14몰
#  																					<label for="prodCompareCheck_14884709">
#  <input id="prodCompareCheck_14884709" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="14884709"/>
#  <input name="compareRepValue" type="hidden" value="14884709"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=14884709&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14884709',1);; _trkEventLog('통합검색_상품블로그_유입'); " target="_blank"><strong>61,340</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_14884709"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <a class="" href="http://prod.danawa.com/info/?pcode=14884709&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14884709',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem14574131">
#  <input id="productItem_categoryInfo_14574131" type="hidden" value="자동차 용품_차량용전자제품"/>
#  <input id="min_price_14574131" type="hidden" value="49260"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="http://prod.danawa.com/info/?pcode=14574131&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" id="thumbLink_14574131" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="차량용 청소기 A3 (해외구매)" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/131/574/img/14574131_1.jpg?shrink=130:130&amp;_v=20210624142008"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_14574131" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  						</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=14574131&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14574131',1);" target="_blank">베이스어스 차량용 <b>청소기</b> A3 (해외구매)</a>
#  </p>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">차량용<b>청소기</b> / <a class="view_dic" href="#" onclick="$.termDicViewLink(214056,'view',this,0,1840,59152); return false;"><b>무선</b></a> / 흡입력: <a class="view_dic" href="#" onclick="$.termDicViewLink(214065,'view',this,0,1840,59152); return false;">15,000Pa</a> / 최대출력: 135W / 헤파필터 / 추가노즐: <a class="view_dic" href="#" onclick="$.termDicViewLink(214068,'view',this,0,1840,59152); return false;">틈새</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(214071,'view',this,0,1840,59152); return false;">솔브러쉬</a> / LED라이트 / 사용시간: <a class="view_dic" href="#" onclick="$.termDicViewLink(214167,'view',this,0,1840,59152); return false;">45분</a> / 배터리 잔량표시 / 소음: 75dB / 충전방식: USB C타입 / 충전시간: 3~5시간 / 색상: 그린, 실버 / 크기: 296x56.5mm								</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_14574131"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2021.05.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:91%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.5</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=14574131&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>123</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '14574131', 'search', '', '', '49260');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14574131',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_14574131" type="hidden" value="//베이스어스 차량용 &lt;b&gt;청소기&lt;/b&gt; A3 (해외구매)"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=14237761" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14574131',3);" target="_blank"><span>블박/내비/전자제품</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="1840|59152|59189|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_14574131">
#  <p class="chk_sect">
#  										47몰
#  																					<label for="prodCompareCheck_14574131">
#  <input id="prodCompareCheck_14574131" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="14574131"/>
#  <input name="compareRepValue" type="hidden" value="14574131"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=14574131&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14574131',1);; _trkEventLog('통합검색_상품블로그_유입'); " target="_blank"><strong>49,260</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_14574131"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <a class="" href="http://prod.danawa.com/info/?pcode=14574131&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=14237761" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','14574131',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem13157417">
#  <input id="productItem_categoryInfo_13157417" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_13157417" type="hidden" value="79050"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="http://prod.danawa.com/info/?pcode=13157417&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" id="thumbLink_13157417" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="TROUVER POWER 11" class="image_lazy" data-original="//img.danawa.com/prod_img/500000/417/157/img/13157417_1.jpg?shrink=130:130&amp;_v=20210324093050" src="//img.danawa.com/prod_img/500000/417/157/img/13157417_1.jpg?shrink=130:130&amp;_v=20210324093050" style="display: inline;"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_13157417" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  						</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=13157417&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13157417',1);" target="_blank">샤오미 TROUVER POWER 11</a>
#  </p>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list"><a class="view_dic" href="#" onclick="$.termDicViewLink(8501,'view',this,0,72,80); return false;">핸디/스틱<b>청소기</b></a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(7445,'view',this,0,72,80); return false;">핸디+스틱형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14900,'view',this,0,72,80); return false;">무선형</a> / 흡입전용 / <a class="view_dic" href="#" onclick="$.termDicViewLink(1743,'view',this,0,72,80); return false;">소비전력</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(1743,'view',this,0,72,80); return false;">400W</a> / <br/><b>[성능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">흡입력</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">20000Pa</a> / <br/><b>[배터리]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">충전시간</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">4시간</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">사용시간(개당)</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">1시간</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(217578,'view',this,0,72,80); return false;">분리형 (1개)</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27314,'view',this,0,72,80); return false;">리튬이온</a> / <br/><b>[필터]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14801,'view',this,0,72,80); return false;">헤파필터</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(30024,'view',this,0,72,80); return false;">5단계여과</a> / <br/><b>[기능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(30484,'view',this,0,72,80); return false;">디스플레이표시창</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27321,'view',this,0,72,80); return false;">배터리잔량표시</a> / <br/><b>[구성]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(18333,'view',this,0,72,80); return false;">바닥</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(216342,'view',this,0,72,80); return false;">카펫</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18442,'view',this,0,72,80); return false;">솔형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18436,'view',this,0,72,80); return false;">틈새</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(30019,'view',this,0,72,80); return false;">거치대</a> / <br/><b>[부가]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(214653,'view',this,0,72,80); return false;">먼지통용량</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(214653,'view',this,0,72,80); return false;">0.4L</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">색상</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">화이트+오렌지</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">무게</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">1.45kg</a> / 크기(가로x세로): 227x1227mm								</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_13157417"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2021.01.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:92%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.5</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=13157417&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>118</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '13157417', 'search', '', '', '79050');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13157417',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_13157417" type="hidden" value="//샤오미 TROUVER POWER 11"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13157417',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_13157417">
#  <p class="chk_sect">
#  										128몰
#  																					<label for="prodCompareCheck_13157417">
#  <input id="prodCompareCheck_13157417" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="13157417"/>
#  <input name="compareRepValue" type="hidden" value="13157417"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=13157417&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13157417',1);; _trkEventLog('통합검색_상품블로그_유입'); " target="_blank"><strong>79,050</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_13157417"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  																							해외구매																						<a class="" href="http://prod.danawa.com/info/?pcode=13157417&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13157417',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item product-pot">
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a href="/ajax/productPot.ajax.php?key=MU5tpszM6s" target="_blank">
#  <img onerror="this.onerror=null;" src="//img.danawa.com/new/noData/img/noImg_160.gif"/>
#  </a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a href="/ajax/productPot.ajax.php?key=MU5tpszM6s" target="_blank">MU5tpszM6s</a>
#  </p>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  								MU5tpszM6s470302
#  							</div>
#  </dd>
#  </dl>
#  </div>
#  <div class="prod_pricelist">
#  <ul>
#  <li class="rank_one">
#  <p class="price_sect">
#  <a href="/ajax/productPot.ajax.php?key=MU5tpszM6s" target="_blank"><strong>470302</strong>원</a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item">
#  <div class="ad_nvista main_ad_prodlist ad_section">
#  <strong class="prod_title">
#  <span class="txt_img">애드스마트</span>
#  <img alt="광고" class="ad_ico" src="//img.danawa.com/new/ad/img/ico_ad.png"/>
#                                  광고상품이며, 검색결과와 다를 수 있습니다.
#                              </strong>
#  <a class="btn ad_head" href="https://adsmart.kr/" target="_blank">광고신청</a>
#  <div class="ad_nvista_list">
#  <ul> <li class="ad_body ad_body_divide">
#  <div class="ad_body_sect ad_prod_item">
#  <div class="ad_thumb_info">
#  <a class="thumb_link" href="https://display.adsmart.kr/adCnt/?q=ew0KICAgICJhZGtleSI6IDE0ODM4MSwNCiAgICAiY2xpZW50a2V5IjogMTQ0OCwNCiAgICAi%0AY2FtcGFpZ25rZXkiOiAxMTE4LA0KICAgICJzaXRla2V5IjogMjQ3OCwNCiAgICAiYWRwcmlj%0AZSI6IDExMCwNCiAgICAib3JncHJpY2UiOiAxMTAsDQogICAgImNoYW5uZWxpZCI6ICJDMDFQ%0AMDAxMDAxIiwNCiAgICAicmVzdWx0Y250IjogNiwNCiAgICAicmFua2luZyI6IDEsDQogICAg%0AIm5jaWQiOiAiNTIxQzY1QzVDQTIxNDc1RDkyM0Y4MEYwNDY4RkUzNkQiLA0KICAgICJkZXZp%0AY2UiOiAwLA0KICAgICJxdWVyeWtleSI6IDgxOTQyMywNCiAgICAiZGVzdHVybCI6ICIiLA0K%0AICAgICJyeW4iOiAxLA0KICAgICJjYXRlZ29yeWlkIjogIiINCn0%3D&amp;q4=ew0KICAgICJwcm9kbnVtX2NwIjogIjYyNTUwMzU3MjMtMTI3MDE5NTUyNjUiLA0KICAgICJr%0Ad2RfY3AiOiAiJTI2JTIzMzklM0IlRUIlQUMlQjQlRUMlODQlQTAlRUMlQjIlQUQlRUMlODYl%0AOEMlRUElQjglQjAlMjYlMjMzOSUzQiINCn0%3D&amp;q3=http%3A%2F%2Fad.planbplus.co.kr%2Fweb_landing%2F%3Fcompany_uid%3D74DAFDE272FA497F8F223BEFA9BAA398%26landing_url%3Dhttps%253A%252F%252Flink.coupang.com%252Fre%252FAFFSDP%253Flptag%253DAF0831180%2526subid%253DDanawaSearch%2526pageKey%253D6255035723%2526itemId%253D12701955265%2526vendorItemId%253D79968779319%2526traceid%253DV0-153-17100036963db7af" onmousedown="_trkEventLog('통합검색_애드스마트');" target="_blank">
#  <img alt="흡입력 좋은 차량용 무선 청소기 틈새먼지 싹쓰리 핸디형 다용도 진공 청소기 개털청소 원룸 캠핑용 초강력 실내용 휴대용 39, 협력사, 무선 블랙" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="https://static.coupangcdn.com/image/vendor_inventory/355c/fc3afaaefa224a9a668814f6513351e5d64c2faff5877e5c5f1b07ea95dc.jpeg?shrink=160:160"/>
#  </a>
#  </div>
#  <div class="ad_main_info">
#  <div class="ad_head_info">
#  <a class="prod_name" href="https://display.adsmart.kr/adCnt/?q=ew0KICAgICJhZGtleSI6IDE0ODM4MSwNCiAgICAiY2xpZW50a2V5IjogMTQ0OCwNCiAgICAi%0AY2FtcGFpZ25rZXkiOiAxMTE4LA0KICAgICJzaXRla2V5IjogMjQ3OCwNCiAgICAiYWRwcmlj%0AZSI6IDExMCwNCiAgICAib3JncHJpY2UiOiAxMTAsDQogICAgImNoYW5uZWxpZCI6ICJDMDFQ%0AMDAxMDAxIiwNCiAgICAicmVzdWx0Y250IjogNiwNCiAgICAicmFua2luZyI6IDEsDQogICAg%0AIm5jaWQiOiAiNTIxQzY1QzVDQTIxNDc1RDkyM0Y4MEYwNDY4RkUzNkQiLA0KICAgICJkZXZp%0AY2UiOiAwLA0KICAgICJxdWVyeWtleSI6IDgxOTQyMywNCiAgICAiZGVzdHVybCI6ICIiLA0K%0AICAgICJyeW4iOiAxLA0KICAgICJjYXRlZ29yeWlkIjogIiINCn0%3D&amp;q4=ew0KICAgICJwcm9kbnVtX2NwIjogIjYyNTUwMzU3MjMtMTI3MDE5NTUyNjUiLA0KICAgICJr%0Ad2RfY3AiOiAiJTI2JTIzMzklM0IlRUIlQUMlQjQlRUMlODQlQTAlRUMlQjIlQUQlRUMlODYl%0AOEMlRUElQjglQjAlMjYlMjMzOSUzQiINCn0%3D&amp;q3=http%3A%2F%2Fad.planbplus.co.kr%2Fweb_landing%2F%3Fcompany_uid%3D74DAFDE272FA497F8F223BEFA9BAA398%26landing_url%3Dhttps%253A%252F%252Flink.coupang.com%252Fre%252FAFFSDP%253Flptag%253DAF0831180%2526subid%253DDanawaSearch%2526pageKey%253D6255035723%2526itemId%253D12701955265%2526vendorItemId%253D79968779319%2526traceid%253DV0-153-17100036963db7af" onmousedown="_trkEventLog('통합검색_애드스마트');" target="_blank">흡입력 좋은 차량용 무선 청소기 틈새먼지 싹쓰리 핸디형 다용도 진공 청소기 개털청소 원룸 캠핑용 초강력 실내용 휴대용 39, 협력사, 무선 블랙</a>
#  </div>
#  <div class="ad_price_info">
#  <div class="prod_price_set clear">
#  <div class="shop">
#  <img alt="쿠팡" class="shop_logo" src="http://img.danawa.com/cmpny_info/images/TP40F_logo.gif"/>
#  </div>
#  <dl class="price">
#  <dt class="screen_out">판매가</dt>
#  <dd><span class="num">56,000</span>원</dd>
#  </dl>
#  </div>
#  <div class="prod_side_set clear">
#  <span class="date">등록일 2022.02.02.</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ad_body_sect ad_prod_item">
#  <div class="ad_thumb_info">
# ...
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_13863905"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2021.03.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:99%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.9</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=13863905&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>366</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '13863905', 'search_bundle', '', '', '778640');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13863905',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_13863905" type="hidden" value="미드나잇블루^13733942**미스티화이트^13864112**우디그린^13863905//삼성전자 비스포크 제트 VS20A957D2P//13863905"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13863905',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li id="productInfoDetail_13733942" style="">
#  <p class="chk_sect">
#  										15몰
#  										<label for="prodCompareCheck_13733942">
#  <input id="prodCompareCheck_13733942" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="13733942"/>
#  <input name="compareRepValue" type="hidden" value="13863905"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=13733942&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13733942',1);" target="_blank"><strong>1,194,990</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_13733942"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">																				미드나잇블루																				<a href="http://prod.danawa.com/info/?pcode=13733942&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13733942',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_13864112" style="">
#  <p class="chk_sect">
#  										113몰
#  										<label for="prodCompareCheck_13864112">
#  <input id="prodCompareCheck_13864112" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="13864112"/>
#  <input name="compareRepValue" type="hidden" value="13863905"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=13864112&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13864112',1);" target="_blank"><strong>815,520</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_13864112"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect"><span class="rank">2위</span>																				미스티화이트																				<a href="http://prod.danawa.com/info/?pcode=13864112&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13864112',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li class="rank_one" id="productInfoDetail_13863905" style="">
#  <p class="chk_sect">
#  										121몰
#  										<label for="prodCompareCheck_13863905">
#  <input id="prodCompareCheck_13863905" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="13863905"/>
#  <input name="compareRepValue" type="hidden" value="13863905"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=13863905&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13863905',1);" target="_blank"><strong>778,640</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_13863905"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect"><span class="rank">1위</span>																				우디그린																				<a href="http://prod.danawa.com/info/?pcode=13863905&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','13863905',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem12176966">
#  <input id="productItem_categoryInfo_12176966" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_12176966" type="hidden" value="220500"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="http://prod.danawa.com/info/?pcode=12176966&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" id="thumbLink_12176966" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="WELL Q7 WQ71-2BSWF" class="image_lazy" data-original="//img.danawa.com/prod_img/500000/966/176/img/12176966_1.jpg?shrink=130:130&amp;_v=20210122104605" src="//img.danawa.com/new/noData/img/noImg_160.gif"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_12176966" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  						</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=12176966&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','12176966',1);" target="_blank">일렉트로룩스 WELL Q7 WQ71-2BSWF</a>
#  </p>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list"><a class="view_dic" href="#" onclick="$.termDicViewLink(8501,'view',this,0,72,80); return false;">핸디/스틱<b>청소기</b></a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(7445,'view',this,0,72,80); return false;">핸디+스틱형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14900,'view',this,0,72,80); return false;">무선형</a> / 흡입전용 / <br/><b>[성능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(4000,'view',this,0,72,80); return false;">싸이클론</a> / <br/><b>[배터리]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">충전시간</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14921,'view',this,0,72,80); return false;">4시간30분</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">사용시간(개당)</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(8515,'view',this,0,72,80); return false;">50분</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(220584,'view',this,0,72,80); return false;">내장형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27314,'view',this,0,72,80); return false;">리튬이온</a> / <br/><b>[필터]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(30024,'view',this,0,72,80); return false;">5단계여과</a> / <br/><b>[기능]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(27318,'view',this,0,72,80); return false;">셀프스탠딩</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27323,'view',this,0,72,80); return false;">LED라이트</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27321,'view',this,0,72,80); return false;">배터리잔량표시</a> / <br/><b>[구성]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(18333,'view',this,0,72,80); return false;">바닥</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18453,'view',this,0,72,80); return false;">침구</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(18442,'view',this,0,72,80); return false;">솔형</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(216354,'view',this,0,72,80); return false;">더스팅</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(216348,'view',this,0,72,80); return false;">긴틈새</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(30019,'view',this,0,72,80); return false;">거치대</a> / <br/><b>[부가]</b> <a class="view_dic" href="#" onclick="$.termDicViewLink(214653,'view',this,0,72,80); return false;">먼지통용량</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(214653,'view',this,0,72,80); return false;">0.3L</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">색상</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(14771,'view',this,0,72,80); return false;">사틴화이트</a> / <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">무게</a>: <a class="view_dic" href="#" onclick="$.termDicViewLink(27312,'view',this,0,72,80); return false;">2.8kg</a> / 크기(가로x세로x깊이): 386x692x146mm								</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_12176966"></div>
#  <div class="prod_rel_content">
#  <dl class="rel_item rel_event">
#  <dt>기획전</dt>
#  <dd><a href="http://plan.danawa.com/info/?nPlanSeq=4029" rel="noopener" target="_blank">강력해진 밀착 흡입력
#  일렉트로룩스 무선청소기!</a></dd>
#  </dl>
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2020.09.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:93%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.6</strong>점
#  														</div>
#  </div>
#  <div class="cnt_opinion">
#  														(<a class="click_log_prod_content_count" href="http://prod.danawa.com/info/?pcode=12176966&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>48</strong></a>건)
#  													</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_log_wishList" href="#" onclick="javascript:$.danawaAddProductToWishList(this, '12176966', 'search', '', '', '220500');return false;" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','12176966',4);" title="관심상품에 담기">관심상품</a>
#  </dd>
#  <input id="wishListBundleVal_12176966" type="hidden" value="//일렉트로룩스 WELL Q7 WQ71-2BSWF"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="http://prod.danawa.com/list/?cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','12176966',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_12176966">
#  <p class="chk_sect">
#  										98몰
#  																					<label for="prodCompareCheck_12176966">
#  <input id="prodCompareCheck_12176966" type="checkbox"/><strong>상품비교</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="12176966"/>
#  <input name="compareRepValue" type="hidden" value="12176966"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="http://prod.danawa.com/info/?pcode=12176966&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','12176966',1);; _trkEventLog('통합검색_상품블로그_유입'); " target="_blank"><strong>220,500</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_12176966"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <a class="" href="http://prod.danawa.com/info/?pcode=12176966&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','12176966',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>]

# %%
title = soup.select('#productItem15170459 > div > div.prod_info > p > a')
title
# Out:
# [<a class="click_log_product_standard_title_" href="http://prod.danawa.com/info/?pcode=15170459&amp;keyword=%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B&amp;cate=102207" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%26%2339%3B%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0%26%2339%3B','15170459',1);" target="_blank">삼성전자 비스포크 제트 VS20A956A3</a>]

# %%
for i in range(100):
    title = soup.select('#productItem15170459 > div > div> p > a').text
    print(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31788/962663857.py in <module>
#       1 for i in range(100):
# ----> 2     title = soup.select('#productItem15170459 > div > div> p > a').text
#       3     print(title)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2251     def __getattr__(self, key):
#    2252         """Raise a helpful exception to explain a common code fix."""
# -> 2253         raise AttributeError(
#    2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
